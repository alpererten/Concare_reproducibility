# %%
# Use external ConCare architecture from the uploaded file
import sys, os
sys.path.append('/mnt/data')  # Ensure the uploaded model file is importable
from ConCare_Model_v2 import ConCare  # noqa: F401
print('Imported ConCare from ConCare_Model_v2.py successfully')
# Out:
# Imported ConCare from ConCare_Model_v2.py successfully

# %%
# Quick sanity check of ConCare signature
try:
    _sig = ConCare.__init__.__code__.co_varnames
    print('ConCare init args:', _sig)
except Exception as e:
    print('Warning reading ConCare signature:', e)
# Out:
# ConCare init args: ('self', 'input_dim', 'hidden_dim', 'd_model', 'MHD_num_head', 'd_ff', 'output_dim', 'keep_prob', 'demographic_dim')

# %%
import numpy as np
import argparse
import os
import importlib
import re
import pickle
import datetime
import random
import math
import copy


import torch
from torch import nn
import torch.nn.utils.rnn as rnn_utils
from torch.utils import data
from torch.autograd import Variable
import torch.nn.functional as F


from utils import utils
from utils.readers import InHospitalMortalityReader
from utils.preprocessing import Discretizer, Normalizer
from utils import metrics
from utils import common_utils

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Prepare

# %%
data_path = './data/'
file_name = './model/concare_v1'
small_part = False
arg_timestep = 1.0
batch_size = 256
epochs = 100

# %%
# Build readers, discretizers, normalizers
train_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'train'),
                                         listfile=os.path.join(data_path, 'train_listfile.csv'),
                                         period_length=48.0)

val_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'train'),
                                       listfile=os.path.join(data_path, 'val_listfile.csv'),
                                       period_length=48.0)

discretizer = Discretizer(timestep=arg_timestep,
                          store_masks=True,
                          impute_strategy='previous',
                          start_time='zero')

# %%
discretizer_header = discretizer.transform(train_reader.read_example(0)["X"])[1].split(',')
cont_channels = [i for (i, x) in enumerate(discretizer_header) if x.find("->") == -1]

normalizer = Normalizer(fields=cont_channels)  # choose here which columns to standardize
normalizer_state = 'ihm_normalizer'
normalizer_state = os.path.join(os.path.dirname(data_path), normalizer_state)
normalizer.load_params(normalizer_state)

# %%
n_trained_chunks = 0
train_raw = utils.load_data(train_reader, discretizer, normalizer, small_part, return_names=True)
val_raw = utils.load_data(val_reader, discretizer, normalizer, small_part, return_names=True)

# %%
demographic_data = []
diagnosis_data = []
idx_list = []

demo_path = data_path + 'demographic/'
for cur_name in os.listdir(demo_path):
    cur_id, cur_episode = cur_name.split('_', 1)
    cur_episode = cur_episode[:-4]
    cur_file = demo_path + cur_name

    with open(cur_file, "r") as tsfile:
        header = tsfile.readline().strip().split(',')
        if header[0] != "Icustay":
            continue
        cur_data = tsfile.readline().strip().split(',')
        
    if len(cur_data) == 1:
        cur_demo = np.zeros(12)
        cur_diag = np.zeros(128)
    else:
        if cur_data[3] == '':
            cur_data[3] = 60.0
        if cur_data[4] == '':
            cur_data[4] = 160
        if cur_data[5] == '':
            cur_data[5] = 60

        cur_demo = np.zeros(12)
        cur_demo[int(cur_data[1])] = 1
        cur_demo[5 + int(cur_data[2])] = 1
        cur_demo[9:] = cur_data[3:6]
        cur_diag = np.array(cur_data[8:], dtype=int)

    demographic_data.append(cur_demo)
    diagnosis_data.append(cur_diag)
    idx_list.append(cur_id+'_'+cur_episode)

for each_idx in range(9,12):
    cur_val = []
    for i in range(len(demographic_data)):
        cur_val.append(demographic_data[i][each_idx])
    cur_val = np.array(cur_val)
    _mean = np.mean(cur_val)
    _std = np.std(cur_val)
    _std = _std if _std > 1e-7 else 1e-7
    for i in range(len(demographic_data)):
        demographic_data[i][each_idx] = (demographic_data[i][each_idx] - _mean) / _std

# %% [markdown]
# ### model

# %%
def get_loss(y_pred, y_true):
    loss = torch.nn.BCELoss()
    return loss(y_pred, y_true)

# %%
class Dataset(data.Dataset):
    def __init__(self, x, y, name):
        self.x = x
        self.y = y
        self.name = name

    def __getitem__(self, index):#返回的是tensor
        return self.x[index], self.y[index], self.name[index]

    def __len__(self):
        return len(self.x)

# %%
train_dataset = Dataset(train_raw['data'][0], train_raw['data'][1], train_raw['names'])
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_dataset = Dataset(val_raw['data'][0], val_raw['data'][1], val_raw['names'])
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Run

# %%
try:
    DEM_DIM = len(demographic_data[0])
except Exception:
    DEM_DIM = 12  # fallback; adjust if your demographics vector has a different size

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)  # numpy
random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)  # cpu
torch.cuda.manual_seed(RANDOM_SEED)  # gpu
torch.backends.cudnn.deterministic = True  # cudnn


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = ConCare(input_dim=76, hidden_dim=64, d_model=64, MHD_num_head=4, d_ff=256, output_dim=1, keep_prob=0.8, demographic_dim=DEM_DIM).to(device)
# input_dim, d_model, d_k, d_v, MHD_num_head, d_ff, output_dim
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

max_roc = 0
max_prc = 0
train_loss = []
train_model_loss = []
train_decov_loss = []
valid_loss = []
valid_model_loss = []
valid_decov_loss = []
history = []
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=2)
np.set_printoptions(suppress=True)

# Build once for O(1) demographic lookup
demo_map = {idx_list[i]: torch.tensor(demographic_data[i], dtype=torch.float32) for i in range(len(idx_list))}

for each_epoch in range(100):
    batch_loss = []
    model_batch_loss = []
    decov_batch_loss = []

    model.train()

    for step, (batch_x, batch_y, batch_name) in enumerate(train_loader):
        optimizer.zero_grad()
        batch_x = batch_x.float().to(device)
        batch_y = batch_y.float().to(device)

        # Fast demographic batch build
        batch_demo = [demo_map[f"{batch_name[i].split('_', 2)[0]}_{batch_name[i].split('_', 2)[1]}"] for i in range(len(batch_name))]
        batch_demo = torch.stack(batch_demo).to(device)

        output, decov_loss = model(batch_x, batch_demo)

        model_loss = get_loss(output, batch_y.unsqueeze(-1))
        loss = model_loss + 800 * decov_loss

        batch_loss.append(loss.item())
        model_batch_loss.append(model_loss.item())
        decov_batch_loss.append(decov_loss.item())
        loss.backward()
        optimizer.step()

        if step % 30 == 0:
            print('Epoch %d Batch %d: Train Loss = %.4f' % (each_epoch, step, np.mean(np.array(batch_loss))))
            print('Model Loss = %.4f, Decov Loss = %.4f' % (np.mean(np.array(model_batch_loss)), np.mean(np.array(decov_batch_loss))))
    train_loss.append(np.mean(np.array(batch_loss)))
    train_model_loss.append(np.mean(np.array(model_batch_loss)))
    train_decov_loss.append(np.mean(np.array(decov_batch_loss)))

    batch_loss = []
    model_batch_loss = []
    decov_batch_loss = []

    y_true = []
    y_pred = []
    with torch.no_grad():
        model.eval()
        for step, (batch_x, batch_y, batch_name) in enumerate(valid_loader):
            batch_x = batch_x.float().to(device)
            batch_y = batch_y.float().to(device)

            # Fast demographic batch build
            batch_demo = [demo_map[f"{batch_name[i].split('_', 2)[0]}_{batch_name[i].split('_', 2)[1]}"] for i in range(len(batch_name))]
            batch_demo = torch.stack(batch_demo).to(device)

            output, decov_loss = model(batch_x, batch_demo)

            model_loss = get_loss(output, batch_y.unsqueeze(-1))

            loss = model_loss + 10 * decov_loss
            batch_loss.append(loss.item())
            model_batch_loss.append(model_loss.item())
            decov_batch_loss.append(decov_loss.item())
            y_pred += list(output.cpu().detach().numpy().flatten())
            y_true += list(batch_y.cpu().numpy().flatten())

    valid_loss.append(np.mean(np.array(batch_loss)))
    valid_model_loss.append(np.mean(np.array(model_batch_loss)))
    valid_decov_loss.append(np.mean(np.array(decov_batch_loss)))

    print("\n==>Predicting on validation")
    print('Valid Loss = %.4f' % (valid_loss[-1]))
    print('valid_model Loss = %.4f' % (valid_model_loss[-1]))
    print('valid_decov Loss = %.4f' % (valid_decov_loss[-1]))
    y_pred = np.array(y_pred)
    y_pred = np.stack([1 - y_pred, y_pred], axis=1)
    ret = metrics.print_metrics_binary(y_true, y_pred)
    history.append(ret)
    print()

    cur_auroc = ret['auroc']

    if cur_auroc > max_roc:
        max_roc = cur_auroc
        state = {
            'net': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epoch': each_epoch
        }
        # Ensure parent directory exists before saving
        import os
        os.makedirs(os.path.dirname(file_name), exist_ok=True)
        torch.save(state, file_name)
        print('\n------------ Save best model ------------\n')
# Out:
# Using device: cuda
# Epoch 0 Batch 0: Train Loss = 0.7042
# Model Loss = 0.7026, Decov Loss = 0.0000
# Epoch 0 Batch 30: Train Loss = 0.4978
# Model Loss = 0.4947, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3906
# valid_model Loss = 0.3906
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2786    0]
#  [ 436    0]]
# accuracy = 0.8646803227808815
# precision class 0 = 0.8646803227808815
# precision class 1 = 0.0
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.6441356520479198
# AUC of PRC = 0.2092614488638167
# min(+P, Se) = 0.2356687898089172
# f1_score = 0.0
#
#
# ------------ Save best model ------------
#
# Epoch 1 Batch 0: Train Loss = 0.4358
# Model Loss = 0.4353, Decov Loss = 0.0000
# Epoch 1 Batch 30: Train Loss = 0.3906
# Model Loss = 0.3900, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3534
# valid_model Loss = 0.3534
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2784    2]
#  [ 436    0]]
# accuracy = 0.8640595903165735
# precision class 0 = 0.8645962732919255
# precision class 1 = 0.0
# recall class 0 = 0.9992821249102656
# recall class 1 = 0.0
# AUC of ROC = 0.7478496677357956
# AUC of PRC = 0.3094287676228881
# min(+P, Se) = 0.37028824833702884
# f1_score = 0.0
#
#
# ------------ Save best model ------------
#
# Epoch 2 Batch 0: Train Loss = 0.3812
# Model Loss = 0.3807, Decov Loss = 0.0000
# Epoch 2 Batch 30: Train Loss = 0.3502
# Model Loss = 0.3498, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3257
# valid_model Loss = 0.3257
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2771   15]
#  [ 402   34]]
# accuracy = 0.8705772811918063
# precision class 0 = 0.8733060195398676
# precision class 1 = 0.6938775510204082
# recall class 0 = 0.9946159368269921
# recall class 1 = 0.0779816513761468
# AUC of ROC = 0.8052590936333041
# AUC of PRC = 0.4013773152392935
# min(+P, Se) = 0.40976645435244163
# f1_score = 0.14020618556701034
#
#
# ------------ Save best model ------------
#
# Epoch 3 Batch 0: Train Loss = 0.3283
# Model Loss = 0.3280, Decov Loss = 0.0000
# Epoch 3 Batch 30: Train Loss = 0.3333
# Model Loss = 0.3330, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3184
# valid_model Loss = 0.3184
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2739   47]
#  [ 367   69]]
# accuracy = 0.8715083798882681
# precision class 0 = 0.8818415969092079
# precision class 1 = 0.5948275862068966
# recall class 0 = 0.9831299353912419
# recall class 1 = 0.15825688073394495
# AUC of ROC = 0.8126008482780877
# AUC of PRC = 0.42211313386148447
# min(+P, Se) = 0.4337606837606838
# f1_score = 0.25
#
#
# ------------ Save best model ------------
#
# Epoch 4 Batch 0: Train Loss = 0.3268
# Model Loss = 0.3266, Decov Loss = 0.0000
# Epoch 4 Batch 30: Train Loss = 0.3194
# Model Loss = 0.3192, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3128
# valid_model Loss = 0.3128
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2693   93]
#  [ 316  120]]
# accuracy = 0.8730602110490379
# precision class 0 = 0.8949817215021602
# precision class 1 = 0.5633802816901409
# recall class 0 = 0.966618808327351
# recall class 1 = 0.27522935779816515
# AUC of ROC = 0.8247586227335892
# AUC of PRC = 0.46726600565913706
# min(+P, Se) = 0.47216035634743875
# f1_score = 0.3697996918335901
#
#
# ------------ Save best model ------------
#
# Epoch 5 Batch 0: Train Loss = 0.3974
# Model Loss = 0.3970, Decov Loss = 0.0000
# Epoch 5 Batch 30: Train Loss = 0.3195
# Model Loss = 0.3191, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3058
# valid_model Loss = 0.3058
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2754   32]
#  [ 371   65]]
# accuracy = 0.8749224084419616
# precision class 0 = 0.88128
# precision class 1 = 0.6701030927835051
# recall class 0 = 0.9885139985642498
# recall class 1 = 0.14908256880733944
# AUC of ROC = 0.8377503507050323
# AUC of PRC = 0.48590629758536585
# min(+P, Se) = 0.5022935779816514
# f1_score = 0.2439024390243902
#
#
# ------------ Save best model ------------
#
# Epoch 6 Batch 0: Train Loss = 0.3003
# Model Loss = 0.3001, Decov Loss = 0.0000
# Epoch 6 Batch 30: Train Loss = 0.3145
# Model Loss = 0.3143, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3015
# valid_model Loss = 0.3015
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2733   53]
#  [ 349   87]]
# accuracy = 0.8752327746741154
# precision class 0 = 0.8867618429591174
# precision class 1 = 0.6214285714285714
# recall class 0 = 0.9809763101220388
# recall class 1 = 0.19954128440366972
# AUC of ROC = 0.8356983969651665
# AUC of PRC = 0.4862665301904022
# min(+P, Se) = 0.4794520547945205
# f1_score = 0.3020833333333333
#
# Epoch 7 Batch 0: Train Loss = 0.2938
# Model Loss = 0.2932, Decov Loss = 0.0000
# Epoch 7 Batch 30: Train Loss = 0.3132
# Model Loss = 0.3128, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3081
# valid_model Loss = 0.3081
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2743   43]
#  [ 345   91]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.8882772020725389
# precision class 1 = 0.6791044776119403
# recall class 0 = 0.9845656855707107
# recall class 1 = 0.20871559633027523
# AUC of ROC = 0.8285595737534328
# AUC of PRC = 0.4876097118347741
# min(+P, Se) = 0.48623853211009177
# f1_score = 0.3192982456140351
#
# Epoch 8 Batch 0: Train Loss = 0.3512
# Model Loss = 0.3507, Decov Loss = 0.0000
# Epoch 8 Batch 30: Train Loss = 0.3107
# Model Loss = 0.3103, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2950
# valid_model Loss = 0.2950
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2740   46]
#  [ 344   92]]
# accuracy = 0.8789571694599627
# precision class 0 = 0.8884565499351491
# precision class 1 = 0.6666666666666666
# recall class 0 = 0.9834888729361091
# recall class 1 = 0.21100917431192662
# AUC of ROC = 0.8423177486383424
# AUC of PRC = 0.5008323928676253
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.32055749128919864
#
#
# ------------ Save best model ------------
#
# Epoch 9 Batch 0: Train Loss = 0.3122
# Model Loss = 0.3119, Decov Loss = 0.0000
# Epoch 9 Batch 30: Train Loss = 0.3017
# Model Loss = 0.3011, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2962
# valid_model Loss = 0.2962
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2716   70]
#  [ 321  115]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.8943035890681593
# precision class 1 = 0.6216216216216216
# recall class 0 = 0.9748743718592965
# recall class 1 = 0.26376146788990823
# AUC of ROC = 0.8398051858242721
# AUC of PRC = 0.49469387879058624
# min(+P, Se) = 0.4954337899543379
# f1_score = 0.37037037037037035
#
# Epoch 10 Batch 0: Train Loss = 0.2331
# Model Loss = 0.2323, Decov Loss = 0.0000
# Epoch 10 Batch 30: Train Loss = 0.3086
# Model Loss = 0.3080, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2927
# valid_model Loss = 0.2927
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2736   50]
#  [ 347   89]]
# accuracy = 0.8767846058348852
# precision class 0 = 0.8874472915990917
# precision class 1 = 0.6402877697841727
# recall class 0 = 0.9820531227566404
# recall class 1 = 0.20412844036697247
# AUC of ROC = 0.844232631045134
# AUC of PRC = 0.4938567530329221
# min(+P, Se) = 0.5080091533180778
# f1_score = 0.3095652173913043
#
#
# ------------ Save best model ------------
#
# Epoch 11 Batch 0: Train Loss = 0.2987
# Model Loss = 0.2982, Decov Loss = 0.0000
# Epoch 11 Batch 30: Train Loss = 0.2879
# Model Loss = 0.2874, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2974
# valid_model Loss = 0.2974
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2716   70]
#  [ 319  117]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.8948929159802307
# precision class 1 = 0.6256684491978609
# recall class 0 = 0.9748743718592965
# recall class 1 = 0.268348623853211
# AUC of ROC = 0.8461096438944395
# AUC of PRC = 0.5026299582922907
# min(+P, Se) = 0.4988662131519274
# f1_score = 0.3756019261637239
#
#
# ------------ Save best model ------------
#
# Epoch 12 Batch 0: Train Loss = 0.2851
# Model Loss = 0.2843, Decov Loss = 0.0000
# Epoch 12 Batch 30: Train Loss = 0.2940
# Model Loss = 0.2932, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2914
# valid_model Loss = 0.2914
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2743   43]
#  [ 344   92]]
# accuracy = 0.8798882681564246
# precision class 0 = 0.8885649497894396
# precision class 1 = 0.6814814814814815
# recall class 0 = 0.9845656855707107
# recall class 1 = 0.21100917431192662
# AUC of ROC = 0.847308297713996
# AUC of PRC = 0.5131727844816188
# min(+P, Se) = 0.49107142857142855
# f1_score = 0.3222416812609457
#
#
# ------------ Save best model ------------
#
# Epoch 13 Batch 0: Train Loss = 0.2761
# Model Loss = 0.2759, Decov Loss = 0.0000
# Epoch 13 Batch 30: Train Loss = 0.2941
# Model Loss = 0.2937, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2955
# valid_model Loss = 0.2955
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2755   31]
#  [ 346   90]]
# accuracy = 0.882991930477964
# precision class 0 = 0.8884230893260239
# precision class 1 = 0.743801652892562
# recall class 0 = 0.988872936109117
# recall class 1 = 0.20642201834862386
# AUC of ROC = 0.8442128730151413
# AUC of PRC = 0.5222971880307251
# min(+P, Se) = 0.5
# f1_score = 0.32315978456014366
#
# Epoch 14 Batch 0: Train Loss = 0.2694
# Model Loss = 0.2691, Decov Loss = 0.0000
# Epoch 14 Batch 30: Train Loss = 0.2950
# Model Loss = 0.2945, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2937
# valid_model Loss = 0.2937
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2704   82]
#  [ 296  140]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9013333333333333
# precision class 1 = 0.6306306306306306
# recall class 0 = 0.9705671213208902
# recall class 1 = 0.3211009174311927
# AUC of ROC = 0.8434595981216698
# AUC of PRC = 0.5073618384213273
# min(+P, Se) = 0.48623853211009177
# f1_score = 0.425531914893617
#
# Epoch 15 Batch 0: Train Loss = 0.3128
# Model Loss = 0.3099, Decov Loss = 0.0000
# Epoch 15 Batch 30: Train Loss = 0.2900
# Model Loss = 0.2895, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2966
# valid_model Loss = 0.2966
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2652  134]
#  [ 261  175]]
# accuracy = 0.8774053382991931
# precision class 0 = 0.9104016477857878
# precision class 1 = 0.5663430420711975
# recall class 0 = 0.9519023689877961
# recall class 1 = 0.4013761467889908
# AUC of ROC = 0.8499616364917643
# AUC of PRC = 0.5065169477016787
# min(+P, Se) = 0.4908256880733945
# f1_score = 0.4697986577181208
#
#
# ------------ Save best model ------------
#
# Epoch 16 Batch 0: Train Loss = 0.3412
# Model Loss = 0.3409, Decov Loss = 0.0000
# Epoch 16 Batch 30: Train Loss = 0.2884
# Model Loss = 0.2881, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2874
# valid_model Loss = 0.2874
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2712   74]
#  [ 305  131]]
# accuracy = 0.8823711980136562
# precision class 0 = 0.8989061982101425
# precision class 1 = 0.6390243902439025
# recall class 0 = 0.9734386216798278
# recall class 1 = 0.30045871559633025
# AUC of ROC = 0.8517826682560905
# AUC of PRC = 0.5138963077069186
# min(+P, Se) = 0.5045871559633027
# f1_score = 0.4087363494539782
#
#
# ------------ Save best model ------------
#
# Epoch 17 Batch 0: Train Loss = 0.3398
# Model Loss = 0.3393, Decov Loss = 0.0000
# Epoch 17 Batch 30: Train Loss = 0.2883
# Model Loss = 0.2875, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2902
# valid_model Loss = 0.2902
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2724   62]
#  [ 328  108]]
# accuracy = 0.8789571694599627
# precision class 0 = 0.8925294888597641
# precision class 1 = 0.6352941176470588
# recall class 0 = 0.9777458722182341
# recall class 1 = 0.24770642201834864
# AUC of ROC = 0.8472852466790045
# AUC of PRC = 0.5069457513701636
# min(+P, Se) = 0.49209932279909707
# f1_score = 0.3564356435643564
#
# Epoch 18 Batch 0: Train Loss = 0.3223
# Model Loss = 0.3220, Decov Loss = 0.0000
# Epoch 18 Batch 30: Train Loss = 0.2869
# Model Loss = 0.2864, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2963
# valid_model Loss = 0.2963
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2744   42]
#  [ 336  100]]
# accuracy = 0.88268156424581
# precision class 0 = 0.8909090909090909
# precision class 1 = 0.704225352112676
# recall class 0 = 0.9849246231155779
# recall class 1 = 0.22935779816513763
# AUC of ROC = 0.8517958402760857
# AUC of PRC = 0.522159671449054
# min(+P, Se) = 0.4908675799086758
# f1_score = 0.34602076124567477
#
#
# ------------ Save best model ------------
#
# Epoch 19 Batch 0: Train Loss = 0.2818
# Model Loss = 0.2814, Decov Loss = 0.0000
# Epoch 19 Batch 30: Train Loss = 0.2902
# Model Loss = 0.2891, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2861
# valid_model Loss = 0.2861
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2728   58]
#  [ 314  122]]
# accuracy = 0.8845437616387337
# precision class 0 = 0.8967784352399737
# precision class 1 = 0.6777777777777778
# recall class 0 = 0.9791816223977028
# recall class 1 = 0.2798165137614679
# AUC of ROC = 0.8519110954510427
# AUC of PRC = 0.5236280075924173
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.39610389610389607
#
#
# ------------ Save best model ------------
#
# Epoch 20 Batch 0: Train Loss = 0.2539
# Model Loss = 0.2535, Decov Loss = 0.0000
# Epoch 20 Batch 30: Train Loss = 0.2878
# Model Loss = 0.2872, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2842
# valid_model Loss = 0.2842
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2755   31]
#  [ 344   92]]
# accuracy = 0.8836126629422719
# precision class 0 = 0.8889964504678929
# precision class 1 = 0.7479674796747967
# recall class 0 = 0.988872936109117
# recall class 1 = 0.21100917431192662
# AUC of ROC = 0.855132477591101
# AUC of PRC = 0.5366668383184925
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.32915921288014316
#
#
# ------------ Save best model ------------
#
# Epoch 21 Batch 0: Train Loss = 0.2572
# Model Loss = 0.2567, Decov Loss = 0.0000
# Epoch 21 Batch 30: Train Loss = 0.2772
# Model Loss = 0.2769, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2842
# valid_model Loss = 0.2842
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2736   50]
#  [ 308  128]]
# accuracy = 0.8888888888888888
# precision class 0 = 0.8988173455978975
# precision class 1 = 0.7191011235955056
# recall class 0 = 0.9820531227566404
# recall class 1 = 0.29357798165137616
# AUC of ROC = 0.8552139794648209
# AUC of PRC = 0.5414848006762705
# min(+P, Se) = 0.5113636363636364
# f1_score = 0.41693811074918563
#
#
# ------------ Save best model ------------
#
# Epoch 22 Batch 0: Train Loss = 0.2935
# Model Loss = 0.2930, Decov Loss = 0.0000
# Epoch 22 Batch 30: Train Loss = 0.2807
# Model Loss = 0.2800, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2833
# valid_model Loss = 0.2833
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2699   87]
#  [ 287  149]]
# accuracy = 0.8839230291744258
# precision class 0 = 0.9038847957133289
# precision class 1 = 0.6313559322033898
# recall class 0 = 0.9687724335965542
# recall class 1 = 0.34174311926605505
# AUC of ROC = 0.8572910423678024
# AUC of PRC = 0.53098313462834
# min(+P, Se) = 0.49887133182844245
# f1_score = 0.44345238095238093
#
#
# ------------ Save best model ------------
#
# Epoch 23 Batch 0: Train Loss = 0.2540
# Model Loss = 0.2533, Decov Loss = 0.0000
# Epoch 23 Batch 30: Train Loss = 0.2758
# Model Loss = 0.2753, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2908
# valid_model Loss = 0.2908
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2682  104]
#  [ 277  159]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.9063872930043934
# precision class 1 = 0.6045627376425855
# recall class 0 = 0.9626704953338119
# recall class 1 = 0.3646788990825688
# AUC of ROC = 0.8525976869932889
# AUC of PRC = 0.5308452824441693
# min(+P, Se) = 0.505720823798627
# f1_score = 0.45493562231759654
#
# Epoch 24 Batch 0: Train Loss = 0.2632
# Model Loss = 0.2627, Decov Loss = 0.0000
# Epoch 24 Batch 30: Train Loss = 0.2758
# Model Loss = 0.2753, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2872
# valid_model Loss = 0.2872
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2663  123]
#  [ 256  180]]
# accuracy = 0.8823711980136562
# precision class 0 = 0.9122987324426174
# precision class 1 = 0.594059405940594
# recall class 0 = 0.9558506819813353
# recall class 1 = 0.41284403669724773
# AUC of ROC = 0.8561450766282264
# AUC of PRC = 0.5389563104171027
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.48714479025710417
#
# Epoch 25 Batch 0: Train Loss = 0.2926
# Model Loss = 0.2922, Decov Loss = 0.0000
# Epoch 25 Batch 30: Train Loss = 0.2826
# Model Loss = 0.2820, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2848
# valid_model Loss = 0.2848
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2692   94]
#  [ 278  158]]
# accuracy = 0.8845437616387337
# precision class 0 = 0.9063973063973064
# precision class 1 = 0.626984126984127
# recall class 0 = 0.9662598707824839
# recall class 1 = 0.3623853211009174
# AUC of ROC = 0.8557532090333714
# AUC of PRC = 0.5297978851688467
# min(+P, Se) = 0.5194508009153318
# f1_score = 0.45930232558139533
#
# Epoch 26 Batch 0: Train Loss = 0.2643
# Model Loss = 0.2635, Decov Loss = 0.0000
# Epoch 26 Batch 30: Train Loss = 0.2767
# Model Loss = 0.2760, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2829
# valid_model Loss = 0.2829
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2705   81]
#  [ 286  150]]
# accuracy = 0.8860955927995035
# precision class 0 = 0.9043798060849214
# precision class 1 = 0.6493506493506493
# recall class 0 = 0.9709260588657573
# recall class 1 = 0.3440366972477064
# AUC of ROC = 0.8546442896000316
# AUC of PRC = 0.534931406052903
# min(+P, Se) = 0.49891540130151846
# f1_score = 0.44977511244377805
#
# Epoch 27 Batch 0: Train Loss = 0.2144
# Model Loss = 0.2128, Decov Loss = 0.0000
# Epoch 27 Batch 30: Train Loss = 0.2743
# Model Loss = 0.2736, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2842
# valid_model Loss = 0.2842
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2734   52]
#  [ 321  115]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.8949263502454992
# precision class 1 = 0.688622754491018
# recall class 0 = 0.9813352476669059
# recall class 1 = 0.26376146788990823
# AUC of ROC = 0.8543207518589014
# AUC of PRC = 0.5315136181055982
# min(+P, Se) = 0.5180995475113123
# f1_score = 0.38142620232172464
#
# Epoch 28 Batch 0: Train Loss = 0.2016
# Model Loss = 0.2002, Decov Loss = 0.0000
# Epoch 28 Batch 30: Train Loss = 0.2763
# Model Loss = 0.2757, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2798
# valid_model Loss = 0.2798
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2705   81]
#  [ 290  146]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.9031719532554258
# precision class 1 = 0.6431718061674009
# recall class 0 = 0.9709260588657573
# recall class 1 = 0.3348623853211009
# AUC of ROC = 0.8591301856596218
# AUC of PRC = 0.5476500778319237
# min(+P, Se) = 0.5091743119266054
# f1_score = 0.44042232277526394
#
#
# ------------ Save best model ------------
#
# Epoch 29 Batch 0: Train Loss = 0.2152
# Model Loss = 0.2146, Decov Loss = 0.0000
# Epoch 29 Batch 30: Train Loss = 0.2700
# Model Loss = 0.2693, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2809
# valid_model Loss = 0.2808
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2706   80]
#  [ 285  151]]
# accuracy = 0.8867163252638113
# precision class 0 = 0.9047141424272819
# precision class 1 = 0.6536796536796536
# recall class 0 = 0.9712849964106246
# recall class 1 = 0.3463302752293578
# AUC of ROC = 0.8585357982573418
# AUC of PRC = 0.5492898999506522
# min(+P, Se) = 0.5148063781321185
# f1_score = 0.45277361319340326
#
# Epoch 30 Batch 0: Train Loss = 0.2345
# Model Loss = 0.2332, Decov Loss = 0.0000
# Epoch 30 Batch 30: Train Loss = 0.2715
# Model Loss = 0.2708, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2863
# valid_model Loss = 0.2863
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2715   71]
#  [ 309  127]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.8978174603174603
# precision class 1 = 0.6414141414141414
# recall class 0 = 0.9745154343144293
# recall class 1 = 0.29128440366972475
# AUC of ROC = 0.8532159486818102
# AUC of PRC = 0.5305416443908235
# min(+P, Se) = 0.5102974828375286
# f1_score = 0.4006309148264984
#
# Epoch 31 Batch 0: Train Loss = 0.2940
# Model Loss = 0.2935, Decov Loss = 0.0000
# Epoch 31 Batch 30: Train Loss = 0.2726
# Model Loss = 0.2719, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2812
# valid_model Loss = 0.2812
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2705   81]
#  [ 277  159]]
# accuracy = 0.8888888888888888
# precision class 0 = 0.9071093226022804
# precision class 1 = 0.6625
# recall class 0 = 0.9709260588657573
# recall class 1 = 0.3646788990825688
# AUC of ROC = 0.8597204568056535
# AUC of PRC = 0.5454439474751998
# min(+P, Se) = 0.5125858123569794
# f1_score = 0.4704142011834319
#
#
# ------------ Save best model ------------
#
# Epoch 32 Batch 0: Train Loss = 0.3422
# Model Loss = 0.3413, Decov Loss = 0.0000
# Epoch 32 Batch 30: Train Loss = 0.2698
# Model Loss = 0.2691, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2799
# valid_model Loss = 0.2799
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2676  110]
#  [ 271  165]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.9080420766881574
# precision class 1 = 0.6
# recall class 0 = 0.9605168700646087
# recall class 1 = 0.37844036697247707
# AUC of ROC = 0.8615875906399626
# AUC of PRC = 0.5461620800104996
# min(+P, Se) = 0.5240274599542334
# f1_score = 0.4641350210970464
#
#
# ------------ Save best model ------------
#
# Epoch 33 Batch 0: Train Loss = 0.2877
# Model Loss = 0.2873, Decov Loss = 0.0000
# Epoch 33 Batch 30: Train Loss = 0.2667
# Model Loss = 0.2660, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2944
# valid_model Loss = 0.2944
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2608  178]
#  [ 226  210]]
# accuracy = 0.8746120422098076
# precision class 0 = 0.9202540578687368
# precision class 1 = 0.5412371134020618
# recall class 0 = 0.9361091170136396
# recall class 1 = 0.481651376146789
# AUC of ROC = 0.8587481970797632
# AUC of PRC = 0.5434548776885653
# min(+P, Se) = 0.530751708428246
# f1_score = 0.5097087378640777
#
# Epoch 34 Batch 0: Train Loss = 0.3087
# Model Loss = 0.3079, Decov Loss = 0.0000
# Epoch 34 Batch 30: Train Loss = 0.2608
# Model Loss = 0.2598, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2785
# valid_model Loss = 0.2785
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2736   50]
#  [ 316  120]]
# accuracy = 0.8864059590316573
# precision class 0 = 0.8964613368283093
# precision class 1 = 0.7058823529411765
# recall class 0 = 0.9820531227566404
# recall class 1 = 0.27522935779816515
# AUC of ROC = 0.8621976198159869
# AUC of PRC = 0.5506329369026525
# min(+P, Se) = 0.5344036697247706
# f1_score = 0.39603960396039606
#
#
# ------------ Save best model ------------
#
# Epoch 35 Batch 0: Train Loss = 0.2454
# Model Loss = 0.2449, Decov Loss = 0.0000
# Epoch 35 Batch 30: Train Loss = 0.2613
# Model Loss = 0.2605, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2855
# valid_model Loss = 0.2855
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2659  127]
#  [ 248  188]]
# accuracy = 0.8836126629422719
# precision class 0 = 0.91468868249054
# precision class 1 = 0.5968253968253968
# recall class 0 = 0.9544149318018664
# recall class 1 = 0.43119266055045874
# AUC of ROC = 0.8590371582684063
# AUC of PRC = 0.5479283581079246
# min(+P, Se) = 0.5331807780320366
# f1_score = 0.5006657789613849
#
# Epoch 36 Batch 0: Train Loss = 0.2947
# Model Loss = 0.2938, Decov Loss = 0.0000
# Epoch 36 Batch 30: Train Loss = 0.2583
# Model Loss = 0.2575, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2851
# valid_model Loss = 0.2851
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2686  100]
#  [ 278  158]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9062078272604588
# precision class 1 = 0.6124031007751938
# recall class 0 = 0.9641062455132807
# recall class 1 = 0.3623853211009174
# AUC of ROC = 0.8553325276447771
# AUC of PRC = 0.5312665058696175
# min(+P, Se) = 0.5022935779816514
# f1_score = 0.4553314121037464
#
# Epoch 37 Batch 0: Train Loss = 0.2712
# Model Loss = 0.2707, Decov Loss = 0.0000
# Epoch 37 Batch 30: Train Loss = 0.2637
# Model Loss = 0.2630, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2877
# valid_model Loss = 0.2877
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2728   58]
#  [ 314  122]]
# accuracy = 0.8845437616387337
# precision class 0 = 0.8967784352399737
# precision class 1 = 0.6777777777777778
# recall class 0 = 0.9791816223977028
# recall class 1 = 0.2798165137614679
# AUC of ROC = 0.8551736401535858
# AUC of PRC = 0.5367672356713805
# min(+P, Se) = 0.5321100917431193
# f1_score = 0.39610389610389607
#
# Epoch 38 Batch 0: Train Loss = 0.3140
# Model Loss = 0.3130, Decov Loss = 0.0000
# Epoch 38 Batch 30: Train Loss = 0.2586
# Model Loss = 0.2578, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2793
# valid_model Loss = 0.2793
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2715   71]
#  [ 297  139]]
# accuracy = 0.8857852265673495
# precision class 0 = 0.901394422310757
# precision class 1 = 0.6619047619047619
# recall class 0 = 0.9745154343144293
# recall class 1 = 0.31880733944954126
# AUC of ROC = 0.8623359260259358
# AUC of PRC = 0.5501575928251631
# min(+P, Se) = 0.5294117647058824
# f1_score = 0.43034055727554177
#
#
# ------------ Save best model ------------
#
# Epoch 39 Batch 0: Train Loss = 0.2211
# Model Loss = 0.2205, Decov Loss = 0.0000
# Epoch 39 Batch 30: Train Loss = 0.2677
# Model Loss = 0.2667, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2807
# valid_model Loss = 0.2807
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2711   75]
#  [ 301  135]]
# accuracy = 0.883302296710118
# precision class 0 = 0.900066401062417
# precision class 1 = 0.6428571428571429
# recall class 0 = 0.9730796841349605
# recall class 1 = 0.30963302752293576
# AUC of ROC = 0.8589128473297022
# AUC of PRC = 0.536580988522546
# min(+P, Se) = 0.5308924485125858
# f1_score = 0.41795665634674917
#
# Epoch 40 Batch 0: Train Loss = 0.2610
# Model Loss = 0.2604, Decov Loss = 0.0000
# Epoch 40 Batch 30: Train Loss = 0.2599
# Model Loss = 0.2590, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2846
# valid_model Loss = 0.2846
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2720   66]
#  [ 302  134]]
# accuracy = 0.8857852265673495
# precision class 0 = 0.900066181336863
# precision class 1 = 0.67
# recall class 0 = 0.9763101220387652
# recall class 1 = 0.3073394495412844
# AUC of ROC = 0.8603551835191686
# AUC of PRC = 0.5374530238876966
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.42138364779874216
#
# Epoch 41 Batch 0: Train Loss = 0.2027
# Model Loss = 0.2014, Decov Loss = 0.0000
# Epoch 41 Batch 30: Train Loss = 0.2568
# Model Loss = 0.2558, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2913
# valid_model Loss = 0.2913
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2730   56]
#  [ 315  121]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.896551724137931
# precision class 1 = 0.6836158192090396
# recall class 0 = 0.9798994974874372
# recall class 1 = 0.2775229357798165
# AUC of ROC = 0.857835211443851
# AUC of PRC = 0.537558507803188
# min(+P, Se) = 0.536697247706422
# f1_score = 0.39477977161500816
#
# Epoch 42 Batch 0: Train Loss = 0.3091
# Model Loss = 0.3083, Decov Loss = 0.0000
# Epoch 42 Batch 30: Train Loss = 0.2609
# Model Loss = 0.2595, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2810
# valid_model Loss = 0.2810
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2685  101]
#  [ 275  161]]
# accuracy = 0.883302296710118
# precision class 0 = 0.9070945945945946
# precision class 1 = 0.6145038167938931
# recall class 0 = 0.9637473079684135
# recall class 1 = 0.36926605504587157
# AUC of ROC = 0.8581727444562259
# AUC of PRC = 0.5521288142641002
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.4613180515759312
#
# Epoch 43 Batch 0: Train Loss = 0.2457
# Model Loss = 0.2451, Decov Loss = 0.0000
# Epoch 43 Batch 30: Train Loss = 0.2541
# Model Loss = 0.2533, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2837
# valid_model Loss = 0.2837
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2696   90]
#  [ 286  150]]
# accuracy = 0.883302296710118
# precision class 0 = 0.9040912139503688
# precision class 1 = 0.625
# recall class 0 = 0.9676956209619526
# recall class 1 = 0.3440366972477064
# AUC of ROC = 0.8584575893886206
# AUC of PRC = 0.5385473266713648
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.4437869822485207
#
# Epoch 44 Batch 0: Train Loss = 0.2395
# Model Loss = 0.2391, Decov Loss = 0.0000
# Epoch 44 Batch 30: Train Loss = 0.2608
# Model Loss = 0.2601, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2836
# valid_model Loss = 0.2836
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2676  110]
#  [ 261  175]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.9111338100102145
# precision class 1 = 0.6140350877192983
# recall class 0 = 0.9605168700646087
# recall class 1 = 0.4013761467889908
# AUC of ROC = 0.8584987519511055
# AUC of PRC = 0.5376489235574645
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.48543689320388345
#
# Epoch 45 Batch 0: Train Loss = 0.3102
# Model Loss = 0.3092, Decov Loss = 0.0000
# Epoch 45 Batch 30: Train Loss = 0.2545
# Model Loss = 0.2536, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2842
# valid_model Loss = 0.2842
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2680  106]
#  [ 274  162]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.9072444143534191
# precision class 1 = 0.6044776119402985
# recall class 0 = 0.9619526202440776
# recall class 1 = 0.37155963302752293
# AUC of ROC = 0.8598324189756121
# AUC of PRC = 0.5347993368993696
# min(+P, Se) = 0.5389908256880734
# f1_score = 0.4602272727272727
#
# Epoch 46 Batch 0: Train Loss = 0.2860
# Model Loss = 0.2852, Decov Loss = 0.0000
# Epoch 46 Batch 30: Train Loss = 0.2595
# Model Loss = 0.2586, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2909
# valid_model Loss = 0.2909
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2734   52]
#  [ 329  107]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.8925889650669279
# precision class 1 = 0.6729559748427673
# recall class 0 = 0.9813352476669059
# recall class 1 = 0.24541284403669725
# AUC of ROC = 0.8589169635859507
# AUC of PRC = 0.5361200340598115
# min(+P, Se) = 0.5125858123569794
# f1_score = 0.3596638655462185
#
# Epoch 47 Batch 0: Train Loss = 0.2947
# Model Loss = 0.2940, Decov Loss = 0.0000
# Epoch 47 Batch 30: Train Loss = 0.2523
# Model Loss = 0.2514, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2933
# valid_model Loss = 0.2933
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2743   43]
#  [ 330  106]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.8926130816791409
# precision class 1 = 0.7114093959731543
# recall class 0 = 0.9845656855707107
# recall class 1 = 0.24311926605504589
# AUC of ROC = 0.8608664225452293
# AUC of PRC = 0.531710790676753
# min(+P, Se) = 0.5114678899082569
# f1_score = 0.36239316239316244
#
# Epoch 48 Batch 0: Train Loss = 0.2392
# Model Loss = 0.2386, Decov Loss = 0.0000
# Epoch 48 Batch 30: Train Loss = 0.2506
# Model Loss = 0.2499, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2872
# valid_model Loss = 0.2872
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2706   80]
#  [ 298  138]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9007989347536618
# precision class 1 = 0.6330275229357798
# recall class 0 = 0.9712849964106246
# recall class 1 = 0.3165137614678899
# AUC of ROC = 0.8544277745213618
# AUC of PRC = 0.5309349622583832
# min(+P, Se) = 0.5102974828375286
# f1_score = 0.4220183486238532
#
# Epoch 49 Batch 0: Train Loss = 0.2669
# Model Loss = 0.2658, Decov Loss = 0.0000
# Epoch 49 Batch 30: Train Loss = 0.2476
# Model Loss = 0.2466, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2885
# valid_model Loss = 0.2885
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2673  113]
#  [ 278  158]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.9057946458827516
# precision class 1 = 0.5830258302583026
# recall class 0 = 0.9594400574300072
# recall class 1 = 0.3623853211009174
# AUC of ROC = 0.8578278021826037
# AUC of PRC = 0.5141924657633103
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.4469589816124469
#
# Epoch 50 Batch 0: Train Loss = 0.2909
# Model Loss = 0.2893, Decov Loss = 0.0000
# Epoch 50 Batch 30: Train Loss = 0.2484
# Model Loss = 0.2473, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2920
# valid_model Loss = 0.2920
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2669  117]
#  [ 273  163]]
# accuracy = 0.8789571694599627
# precision class 0 = 0.907205982324949
# precision class 1 = 0.5821428571428572
# recall class 0 = 0.9580043072505384
# recall class 1 = 0.3738532110091743
# AUC of ROC = 0.8531550280893326
# AUC of PRC = 0.5224127772650845
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.45530726256983245
#
# Epoch 51 Batch 0: Train Loss = 0.2333
# Model Loss = 0.2326, Decov Loss = 0.0000
# Epoch 51 Batch 30: Train Loss = 0.2528
# Model Loss = 0.2520, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2892
# valid_model Loss = 0.2892
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2697   89]
#  [ 289  147]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9032150033489619
# precision class 1 = 0.6228813559322034
# recall class 0 = 0.9680545585068198
# recall class 1 = 0.33715596330275227
# AUC of ROC = 0.8576335148876756
# AUC of PRC = 0.5121620933826927
# min(+P, Se) = 0.5080091533180778
# f1_score = 0.4375
#
# Epoch 52 Batch 0: Train Loss = 0.2060
# Model Loss = 0.2052, Decov Loss = 0.0000
# Epoch 52 Batch 30: Train Loss = 0.2553
# Model Loss = 0.2543, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2956
# valid_model Loss = 0.2956
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2703   83]
#  [ 290  146]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9031072502505847
# precision class 1 = 0.6375545851528385
# recall class 0 = 0.970208183776023
# recall class 1 = 0.3348623853211009
# AUC of ROC = 0.8562949083556709
# AUC of PRC = 0.51699780638719
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.43909774436090226
#
# Epoch 53 Batch 0: Train Loss = 0.3066
# Model Loss = 0.3056, Decov Loss = 0.0000
# Epoch 53 Batch 30: Train Loss = 0.2488
# Model Loss = 0.2480, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2829
# valid_model Loss = 0.2829
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2690   96]
#  [ 285  151]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.9042016806722689
# precision class 1 = 0.611336032388664
# recall class 0 = 0.9655419956927495
# recall class 1 = 0.3463302752293578
# AUC of ROC = 0.8634851847705104
# AUC of PRC = 0.5209085020676215
# min(+P, Se) = 0.5298165137614679
# f1_score = 0.44216691068814057
#
#
# ------------ Save best model ------------
#
# Epoch 54 Batch 0: Train Loss = 0.2652
# Model Loss = 0.2647, Decov Loss = 0.0000
# Epoch 54 Batch 30: Train Loss = 0.2427
# Model Loss = 0.2418, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2837
# valid_model Loss = 0.2837
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2692   94]
#  [ 274  162]]
# accuracy = 0.8857852265673495
# precision class 0 = 0.9076196898179366
# precision class 1 = 0.6328125
# recall class 0 = 0.9662598707824839
# recall class 1 = 0.37155963302752293
# AUC of ROC = 0.8619127748835923
# AUC of PRC = 0.5290173187439509
# min(+P, Se) = 0.518348623853211
# f1_score = 0.4682080924855492
#
# Epoch 55 Batch 0: Train Loss = 0.1542
# Model Loss = 0.1537, Decov Loss = 0.0000
# Epoch 55 Batch 30: Train Loss = 0.2371
# Model Loss = 0.2363, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2938
# valid_model Loss = 0.2938
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2698   88]
#  [ 289  147]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9032474054235018
# precision class 1 = 0.625531914893617
# recall class 0 = 0.968413496051687
# recall class 1 = 0.33715596330275227
# AUC of ROC = 0.8569469233454295
# AUC of PRC = 0.5207618170413112
# min(+P, Se) = 0.5252293577981652
# f1_score = 0.43815201192250375
#
# Epoch 56 Batch 0: Train Loss = 0.2258
# Model Loss = 0.2251, Decov Loss = 0.0000
# Epoch 56 Batch 30: Train Loss = 0.2380
# Model Loss = 0.2371, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2814
# valid_model Loss = 0.2814
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2708   78]
#  [ 295  141]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9017649017649018
# precision class 1 = 0.6438356164383562
# recall class 0 = 0.9720028715003589
# recall class 1 = 0.32339449541284404
# AUC of ROC = 0.8637996667478942
# AUC of PRC = 0.5360629309140843
# min(+P, Se) = 0.5295454545454545
# f1_score = 0.4305343511450382
#
#
# ------------ Save best model ------------
#
# Epoch 57 Batch 0: Train Loss = 0.3163
# Model Loss = 0.3155, Decov Loss = 0.0000
# Epoch 57 Batch 30: Train Loss = 0.2449
# Model Loss = 0.2437, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2865
# valid_model Loss = 0.2865
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2698   88]
#  [ 293  143]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.9020394516883985
# precision class 1 = 0.6190476190476191
# recall class 0 = 0.968413496051687
# recall class 1 = 0.32798165137614677
# AUC of ROC = 0.8590667953133954
# AUC of PRC = 0.5281984148608181
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.4287856071964018
#
# Epoch 58 Batch 0: Train Loss = 0.2896
# Model Loss = 0.2883, Decov Loss = 0.0000
# Epoch 58 Batch 30: Train Loss = 0.2552
# Model Loss = 0.2544, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2901
# valid_model Loss = 0.2901
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2695   91]
#  [ 285  151]]
# accuracy = 0.883302296710118
# precision class 0 = 0.9043624161073825
# precision class 1 = 0.6239669421487604
# recall class 0 = 0.9673366834170855
# recall class 1 = 0.3463302752293578
# AUC of ROC = 0.8577248957763918
# AUC of PRC = 0.5377562365463252
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.44542772861356933
#
# Epoch 59 Batch 0: Train Loss = 0.1986
# Model Loss = 0.1970, Decov Loss = 0.0000
# Epoch 59 Batch 30: Train Loss = 0.2441
# Model Loss = 0.2429, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2982
# valid_model Loss = 0.2982
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2680  106]
#  [ 280  156]]
# accuracy = 0.8801986343885785
# precision class 0 = 0.9054054054054054
# precision class 1 = 0.5954198473282443
# recall class 0 = 0.9619526202440776
# recall class 1 = 0.3577981651376147
# AUC of ROC = 0.8582954088924308
# AUC of PRC = 0.5213049062932616
# min(+P, Se) = 0.5067873303167421
# f1_score = 0.44699140401146137
#
# Epoch 60 Batch 0: Train Loss = 0.2383
# Model Loss = 0.2373, Decov Loss = 0.0000
# Epoch 60 Batch 30: Train Loss = 0.2407
# Model Loss = 0.2400, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3010
# valid_model Loss = 0.3009
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2660  126]
#  [ 252  184]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9134615384615384
# precision class 1 = 0.5935483870967742
# recall class 0 = 0.9547738693467337
# recall class 1 = 0.42201834862385323
# AUC of ROC = 0.8590462140321529
# AUC of PRC = 0.5209584079228431
# min(+P, Se) = 0.5179372197309418
# f1_score = 0.4932975871313673
#
# Epoch 61 Batch 0: Train Loss = 0.2250
# Model Loss = 0.2240, Decov Loss = 0.0000
# Epoch 61 Batch 30: Train Loss = 0.2453
# Model Loss = 0.2442, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2840
# valid_model Loss = 0.2840
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2661  125]
#  [ 257  179]]
# accuracy = 0.8814400993171942
# precision class 0 = 0.9119259766963673
# precision class 1 = 0.5888157894736842
# recall class 0 = 0.9551328068916008
# recall class 1 = 0.4105504587155963
# AUC of ROC = 0.8620025092698089
# AUC of PRC = 0.5253144459703505
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.4837837837837838
#
# Epoch 62 Batch 0: Train Loss = 0.2601
# Model Loss = 0.2577, Decov Loss = 0.0000
# Epoch 62 Batch 30: Train Loss = 0.2362
# Model Loss = 0.2350, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2904
# valid_model Loss = 0.2903
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2664  122]
#  [ 256  180]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9123287671232877
# precision class 1 = 0.5960264900662252
# recall class 0 = 0.9562096195262024
# recall class 1 = 0.41284403669724773
# AUC of ROC = 0.8612072485626034
# AUC of PRC = 0.5153516099129699
# min(+P, Se) = 0.5240274599542334
# f1_score = 0.4878048780487805
#
# Epoch 63 Batch 0: Train Loss = 0.2146
# Model Loss = 0.2139, Decov Loss = 0.0000
# Epoch 63 Batch 30: Train Loss = 0.2365
# Model Loss = 0.2353, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2942
# valid_model Loss = 0.2942
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2667  119]
#  [ 256  180]]
# accuracy = 0.8836126629422719
# precision class 0 = 0.9124187478617858
# precision class 1 = 0.6020066889632107
# recall class 0 = 0.957286432160804
# recall class 1 = 0.41284403669724773
# AUC of ROC = 0.8566423203830423
# AUC of PRC = 0.5182374275587435
# min(+P, Se) = 0.518348623853211
# f1_score = 0.489795918367347
#
# Epoch 64 Batch 0: Train Loss = 0.2310
# Model Loss = 0.2304, Decov Loss = 0.0000
# Epoch 64 Batch 30: Train Loss = 0.2314
# Model Loss = 0.2303, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3035
# valid_model Loss = 0.3035
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2700   86]
#  [ 304  132]]
# accuracy = 0.8789571694599627
# precision class 0 = 0.8988015978695073
# precision class 1 = 0.6055045871559633
# recall class 0 = 0.9691313711414213
# recall class 1 = 0.30275229357798167
# AUC of ROC = 0.8559433800720511
# AUC of PRC = 0.5064064325945767
# min(+P, Se) = 0.4954128440366973
# f1_score = 0.4036697247706422
#
# Epoch 65 Batch 0: Train Loss = 0.2110
# Model Loss = 0.2097, Decov Loss = 0.0000
# Epoch 65 Batch 30: Train Loss = 0.2384
# Model Loss = 0.2374, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2910
# valid_model Loss = 0.2910
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2671  115]
#  [ 275  161]]
# accuracy = 0.8789571694599627
# precision class 0 = 0.906653088934148
# precision class 1 = 0.5833333333333334
# recall class 0 = 0.9587221823402728
# recall class 1 = 0.36926605504587157
# AUC of ROC = 0.8573289119252883
# AUC of PRC = 0.507567598916606
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.45224719101123595
#
# Epoch 66 Batch 0: Train Loss = 0.2308
# Model Loss = 0.2299, Decov Loss = 0.0000
# Epoch 66 Batch 30: Train Loss = 0.2357
# Model Loss = 0.2346, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2915
# valid_model Loss = 0.2915
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2682  104]
#  [ 266  170]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.9097693351424695
# precision class 1 = 0.6204379562043796
# recall class 0 = 0.9626704953338119
# recall class 1 = 0.38990825688073394
# AUC of ROC = 0.8604984292366156
# AUC of PRC = 0.5252855275421516
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.47887323943661975
#
# Epoch 67 Batch 0: Train Loss = 0.2127
# Model Loss = 0.2123, Decov Loss = 0.0000
# Epoch 67 Batch 30: Train Loss = 0.2286
# Model Loss = 0.2278, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2991
# valid_model Loss = 0.2991
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2611  175]
#  [ 232  204]]
# accuracy = 0.8736809435133458
# precision class 0 = 0.9183960604994724
# precision class 1 = 0.5382585751978892
# recall class 0 = 0.9371859296482412
# recall class 1 = 0.46788990825688076
# AUC of ROC = 0.8540523719515005
# AUC of PRC = 0.5108222805321694
# min(+P, Se) = 0.5068493150684932
# f1_score = 0.5006134969325153
#
# Epoch 68 Batch 0: Train Loss = 0.2624
# Model Loss = 0.2612, Decov Loss = 0.0000
# Epoch 68 Batch 30: Train Loss = 0.2336
# Model Loss = 0.2326, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3064
# valid_model Loss = 0.3064
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2698   88]
#  [ 304  132]]
# accuracy = 0.8783364369956549
# precision class 0 = 0.8987341772151899
# precision class 1 = 0.6
# recall class 0 = 0.968413496051687
# recall class 1 = 0.30275229357798167
# AUC of ROC = 0.8498208605280663
# AUC of PRC = 0.5002861817632641
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.4024390243902439
#
# Epoch 69 Batch 0: Train Loss = 0.2047
# Model Loss = 0.2036, Decov Loss = 0.0000
# Epoch 69 Batch 30: Train Loss = 0.2252
# Model Loss = 0.2238, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3135
# valid_model Loss = 0.3135
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2533  253]
#  [ 197  239]]
# accuracy = 0.8603351955307262
# precision class 0 = 0.9278388278388279
# precision class 1 = 0.48577235772357724
# recall class 0 = 0.9091888011486001
# recall class 1 = 0.5481651376146789
# AUC of ROC = 0.8569082305366938
# AUC of PRC = 0.5157471506893053
# min(+P, Se) = 0.5114678899082569
# f1_score = 0.5150862068965518
#
# Epoch 70 Batch 0: Train Loss = 0.2434
# Model Loss = 0.2429, Decov Loss = 0.0000
# Epoch 70 Batch 30: Train Loss = 0.2287
# Model Loss = 0.2278, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2987
# valid_model Loss = 0.2987
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2669  117]
#  [ 275  161]]
# accuracy = 0.8783364369956549
# precision class 0 = 0.9065896739130435
# precision class 1 = 0.579136690647482
# recall class 0 = 0.9580043072505384
# recall class 1 = 0.36926605504587157
# AUC of ROC = 0.8533781291780003
# AUC of PRC = 0.49849799372453785
# min(+P, Se) = 0.5045454545454545
# f1_score = 0.45098039215686275
#
# Epoch 71 Batch 0: Train Loss = 0.1966
# Model Loss = 0.1954, Decov Loss = 0.0000
# Epoch 71 Batch 30: Train Loss = 0.2180
# Model Loss = 0.2167, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2997
# valid_model Loss = 0.2997
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2647  139]
#  [ 261  175]]
# accuracy = 0.8758535071384234
# precision class 0 = 0.9102475928473177
# precision class 1 = 0.5573248407643312
# recall class 0 = 0.9501076812634601
# recall class 1 = 0.4013761467889908
# AUC of ROC = 0.8540153256452643
# AUC of PRC = 0.5030465397120717
# min(+P, Se) = 0.5148741418764302
# f1_score = 0.4666666666666666
#
# Epoch 72 Batch 0: Train Loss = 0.1734
# Model Loss = 0.1723, Decov Loss = 0.0000
# Epoch 72 Batch 30: Train Loss = 0.2182
# Model Loss = 0.2169, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3011
# valid_model Loss = 0.3011
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2686  100]
#  [ 292  144]]
# accuracy = 0.8783364369956549
# precision class 0 = 0.9019476158495635
# precision class 1 = 0.5901639344262295
# recall class 0 = 0.9641062455132807
# recall class 1 = 0.3302752293577982
# AUC of ROC = 0.8563154896369133
# AUC of PRC = 0.5035518020744157
# min(+P, Se) = 0.505720823798627
# f1_score = 0.4235294117647059
#
# Epoch 73 Batch 0: Train Loss = 0.2170
# Model Loss = 0.2158, Decov Loss = 0.0000
# Epoch 73 Batch 30: Train Loss = 0.2145
# Model Loss = 0.2134, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3051
# valid_model Loss = 0.3051
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2628  158]
#  [ 251  185]]
# accuracy = 0.8730602110490379
# precision class 0 = 0.9128169503299757
# precision class 1 = 0.5393586005830904
# recall class 0 = 0.9432878679109835
# recall class 1 = 0.4243119266055046
# AUC of ROC = 0.8522412192021709
# AUC of PRC = 0.5045047642559966
# min(+P, Se) = 0.518348623853211
# f1_score = 0.4749679075738126
#
# Epoch 74 Batch 0: Train Loss = 0.2565
# Model Loss = 0.2549, Decov Loss = 0.0000
# Epoch 74 Batch 30: Train Loss = 0.2213
# Model Loss = 0.2201, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3066
# valid_model Loss = 0.3066
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2670  116]
#  [ 274  162]]
# accuracy = 0.8789571694599627
# precision class 0 = 0.9069293478260869
# precision class 1 = 0.5827338129496403
# recall class 0 = 0.9583632447954056
# recall class 1 = 0.37155963302752293
# AUC of ROC = 0.8533797756804995
# AUC of PRC = 0.5062543005011161
# min(+P, Se) = 0.5080091533180778
# f1_score = 0.453781512605042
#
# Epoch 75 Batch 0: Train Loss = 0.2153
# Model Loss = 0.2146, Decov Loss = 0.0000
# Epoch 75 Batch 30: Train Loss = 0.2152
# Model Loss = 0.2140, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3033
# valid_model Loss = 0.3032
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2698   88]
#  [ 292  144]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.9023411371237459
# precision class 1 = 0.6206896551724138
# recall class 0 = 0.968413496051687
# recall class 1 = 0.3302752293577982
# AUC of ROC = 0.8534258777504826
# AUC of PRC = 0.49110158155704126
# min(+P, Se) = 0.49770642201834864
# f1_score = 0.4311377245508982
#
# Epoch 76 Batch 0: Train Loss = 0.2053
# Model Loss = 0.2043, Decov Loss = 0.0000
# Epoch 76 Batch 30: Train Loss = 0.2253
# Model Loss = 0.2238, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3035
# valid_model Loss = 0.3035
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2683  103]
#  [ 291  145]]
# accuracy = 0.877715704531347
# precision class 0 = 0.9021519838601211
# precision class 1 = 0.5846774193548387
# recall class 0 = 0.9630294328786791
# recall class 1 = 0.33256880733944955
# AUC of ROC = 0.8541602178652108
# AUC of PRC = 0.5006535357890064
# min(+P, Se) = 0.5034324942791762
# f1_score = 0.4239766081871345
#
# Epoch 77 Batch 0: Train Loss = 0.2427
# Model Loss = 0.2418, Decov Loss = 0.0000
# Epoch 77 Batch 30: Train Loss = 0.2203
# Model Loss = 0.2195, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3099
# valid_model Loss = 0.3099
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2614  172]
#  [ 232  204]]
# accuracy = 0.8746120422098076
# precision class 0 = 0.9184820801124385
# precision class 1 = 0.5425531914893617
# recall class 0 = 0.9382627422828428
# recall class 1 = 0.46788990825688076
# AUC of ROC = 0.855176109907335
# AUC of PRC = 0.507583664765487
# min(+P, Se) = 0.5252293577981652
# f1_score = 0.5024630541871921
#
# Epoch 78 Batch 0: Train Loss = 0.2061
# Model Loss = 0.2052, Decov Loss = 0.0000
# Epoch 78 Batch 30: Train Loss = 0.2192
# Model Loss = 0.2178, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3087
# valid_model Loss = 0.3087
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2662  124]
#  [ 268  168]]
# accuracy = 0.8783364369956549
# precision class 0 = 0.9085324232081912
# precision class 1 = 0.5753424657534246
# recall class 0 = 0.955491744436468
# recall class 1 = 0.3853211009174312
# AUC of ROC = 0.8544664673300975
# AUC of PRC = 0.5009258001208785
# min(+P, Se) = 0.5056689342403629
# f1_score = 0.4615384615384615
#
# Epoch 79 Batch 0: Train Loss = 0.2089
# Model Loss = 0.2080, Decov Loss = 0.0000
# Epoch 79 Batch 30: Train Loss = 0.2166
# Model Loss = 0.2154, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3125
# valid_model Loss = 0.3125
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2691   95]
#  [ 299  137]]
# accuracy = 0.877715704531347
# precision class 0 = 0.9
# precision class 1 = 0.5905172413793104
# recall class 0 = 0.9659009332376166
# recall class 1 = 0.31422018348623854
# AUC of ROC = 0.8541174088002267
# AUC of PRC = 0.4902475062794318
# min(+P, Se) = 0.49770642201834864
# f1_score = 0.4101796407185629
#
# Epoch 80 Batch 0: Train Loss = 0.1860
# Model Loss = 0.1852, Decov Loss = 0.0000
# Epoch 80 Batch 30: Train Loss = 0.2066
# Model Loss = 0.2055, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3343
# valid_model Loss = 0.3343
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2683  103]
#  [ 288  148]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.9030629417704477
# precision class 1 = 0.5896414342629482
# recall class 0 = 0.9630294328786791
# recall class 1 = 0.3394495412844037
# AUC of ROC = 0.8485522303522856
# AUC of PRC = 0.491246272514829
# min(+P, Se) = 0.5045871559633027
# f1_score = 0.43085880640465796
#
# Epoch 81 Batch 0: Train Loss = 0.2065
# Model Loss = 0.2054, Decov Loss = 0.0000
# Epoch 81 Batch 30: Train Loss = 0.2116
# Model Loss = 0.2104, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3130
# valid_model Loss = 0.3129
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2657  129]
#  [ 259  177]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.9111796982167353
# precision class 1 = 0.5784313725490197
# recall class 0 = 0.9536970567121321
# recall class 1 = 0.4059633027522936
# AUC of ROC = 0.8463418007468535
# AUC of PRC = 0.49570497101845884
# min(+P, Se) = 0.501123595505618
# f1_score = 0.47708894878706204
#
# Epoch 82 Batch 0: Train Loss = 0.1919
# Model Loss = 0.1911, Decov Loss = 0.0000
# Epoch 82 Batch 30: Train Loss = 0.2072
# Model Loss = 0.2061, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3153
# valid_model Loss = 0.3153
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2665  121]
#  [ 263  173]]
# accuracy = 0.8808193668528864
# precision class 0 = 0.9101775956284153
# precision class 1 = 0.5884353741496599
# recall class 0 = 0.9565685570710696
# recall class 1 = 0.3967889908256881
# AUC of ROC = 0.8521358430422098
# AUC of PRC = 0.508398507802713
# min(+P, Se) = 0.5091743119266054
# f1_score = 0.473972602739726
#
# Epoch 83 Batch 0: Train Loss = 0.2345
# Model Loss = 0.2324, Decov Loss = 0.0000
# Epoch 83 Batch 30: Train Loss = 0.1992
# Model Loss = 0.1977, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3204
# valid_model Loss = 0.3204
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2605  181]
#  [ 229  207]]
# accuracy = 0.8727498448168839
# precision class 0 = 0.9191954834156669
# precision class 1 = 0.5335051546391752
# recall class 0 = 0.9350323043790381
# recall class 1 = 0.47477064220183485
# AUC of ROC = 0.8469806437166172
# AUC of PRC = 0.4917599770117018
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.5024271844660194
#
# Epoch 84 Batch 0: Train Loss = 0.2177
# Model Loss = 0.2170, Decov Loss = 0.0000
# Epoch 84 Batch 30: Train Loss = 0.2098
# Model Loss = 0.2085, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3109
# valid_model Loss = 0.3109
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2662  124]
#  [ 276  160]]
# accuracy = 0.8758535071384234
# precision class 0 = 0.9060585432266848
# precision class 1 = 0.5633802816901409
# recall class 0 = 0.955491744436468
# recall class 1 = 0.3669724770642202
# AUC of ROC = 0.8486716017834915
# AUC of PRC = 0.488631979445921
# min(+P, Se) = 0.5045871559633027
# f1_score = 0.4444444444444445
#
# Epoch 85 Batch 0: Train Loss = 0.2158
# Model Loss = 0.2151, Decov Loss = 0.0000
# Epoch 85 Batch 30: Train Loss = 0.2096
# Model Loss = 0.2084, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3242
# valid_model Loss = 0.3241
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2722   64]
#  [ 320  116]]
# accuracy = 0.8808193668528864
# precision class 0 = 0.8948060486522025
# precision class 1 = 0.6444444444444445
# recall class 0 = 0.9770279971284996
# recall class 1 = 0.26605504587155965
# AUC of ROC = 0.8491811943070529
# AUC of PRC = 0.5005993620228899
# min(+P, Se) = 0.518348623853211
# f1_score = 0.37662337662337664
#
# Epoch 86 Batch 0: Train Loss = 0.2728
# Model Loss = 0.2579, Decov Loss = 0.0000
# Epoch 86 Batch 30: Train Loss = 0.2179
# Model Loss = 0.2148, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3271
# valid_model Loss = 0.3271
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2696   90]
#  [ 303  133]]
# accuracy = 0.8780260707635009
# precision class 0 = 0.8989663221073692
# precision class 1 = 0.5964125560538116
# recall class 0 = 0.9676956209619526
# recall class 1 = 0.30504587155963303
# AUC of ROC = 0.8464603489268095
# AUC of PRC = 0.48186781401139095
# min(+P, Se) = 0.48623853211009177
# f1_score = 0.40364188163884673
#
# Epoch 87 Batch 0: Train Loss = 0.2203
# Model Loss = 0.2196, Decov Loss = 0.0000
# Epoch 87 Batch 30: Train Loss = 0.2141
# Model Loss = 0.2134, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3307
# valid_model Loss = 0.3307
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2655  131]
#  [ 256  180]]
# accuracy = 0.8798882681564246
# precision class 0 = 0.9120577121264171
# precision class 1 = 0.5787781350482315
# recall class 0 = 0.9529791816223977
# recall class 1 = 0.41284403669724773
# AUC of ROC = 0.8470555595803395
# AUC of PRC = 0.48311046651280665
# min(+P, Se) = 0.5045871559633027
# f1_score = 0.48192771084337355
#
# Epoch 88 Batch 0: Train Loss = 0.1712
# Model Loss = 0.1705, Decov Loss = 0.0000
# Epoch 88 Batch 30: Train Loss = 0.2081
# Model Loss = 0.2073, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3328
# valid_model Loss = 0.3327
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2640  146]
#  [ 260  176]]
# accuracy = 0.8739913097454997
# precision class 0 = 0.9103448275862069
# precision class 1 = 0.546583850931677
# recall class 0 = 0.9475951184493898
# recall class 1 = 0.4036697247706422
# AUC of ROC = 0.8465311485342836
# AUC of PRC = 0.4805241145914219
# min(+P, Se) = 0.4977168949771689
# f1_score = 0.46437994722955145
#
# Epoch 89 Batch 0: Train Loss = 0.2697
# Model Loss = 0.2688, Decov Loss = 0.0000
# Epoch 89 Batch 30: Train Loss = 0.2097
# Model Loss = 0.2086, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3200
# valid_model Loss = 0.3200
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2668  118]
#  [ 270  166]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.9081007488087134
# precision class 1 = 0.5845070422535211
# recall class 0 = 0.9576453697056713
# recall class 1 = 0.38073394495412843
# AUC of ROC = 0.8510466816388629
# AUC of PRC = 0.5029135963614012
# min(+P, Se) = 0.5125858123569794
# f1_score = 0.46111111111111114
#
# Epoch 90 Batch 0: Train Loss = 0.1801
# Model Loss = 0.1793, Decov Loss = 0.0000
# Epoch 90 Batch 30: Train Loss = 0.1978
# Model Loss = 0.1967, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3323
# valid_model Loss = 0.3323
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2658  128]
#  [ 261  175]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.9105858170606372
# precision class 1 = 0.5775577557755776
# recall class 0 = 0.9540559942569993
# recall class 1 = 0.4013761467889908
# AUC of ROC = 0.8484863702523102
# AUC of PRC = 0.49079365358131455
# min(+P, Se) = 0.5080091533180778
# f1_score = 0.4736129905277402
#
# Epoch 91 Batch 0: Train Loss = 0.2377
# Model Loss = 0.2370, Decov Loss = 0.0000
# Epoch 91 Batch 30: Train Loss = 0.1981
# Model Loss = 0.1971, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3243
# valid_model Loss = 0.3243
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2641  145]
#  [ 262  174]]
# accuracy = 0.8736809435133458
# precision class 0 = 0.9097485359972443
# precision class 1 = 0.5454545454545454
# recall class 0 = 0.947954055994257
# recall class 1 = 0.39908256880733944
# AUC of ROC = 0.8456980182695917
# AUC of PRC = 0.48482630190511034
# min(+P, Se) = 0.5080091533180778
# f1_score = 0.4609271523178808
#
# Epoch 92 Batch 0: Train Loss = 0.2195
# Model Loss = 0.2184, Decov Loss = 0.0000
# Epoch 92 Batch 30: Train Loss = 0.1925
# Model Loss = 0.1916, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3290
# valid_model Loss = 0.3290
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2659  127]
#  [ 264  172]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.9096818337324667
# precision class 1 = 0.5752508361204013
# recall class 0 = 0.9544149318018664
# recall class 1 = 0.3944954128440367
# AUC of ROC = 0.8465122137555404
# AUC of PRC = 0.5008551808157977
# min(+P, Se) = 0.5114678899082569
# f1_score = 0.4680272108843538
#
# Epoch 93 Batch 0: Train Loss = 0.1708
# Model Loss = 0.1697, Decov Loss = 0.0000
# Epoch 93 Batch 30: Train Loss = 0.1983
# Model Loss = 0.1973, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3306
# valid_model Loss = 0.3306
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2620  166]
#  [ 254  182]]
# accuracy = 0.8696461824953445
# precision class 0 = 0.9116214335421016
# precision class 1 = 0.5229885057471264
# recall class 0 = 0.9404163675520459
# recall class 1 = 0.41743119266055045
# AUC of ROC = 0.84405398552395
# AUC of PRC = 0.4769581170239159
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.46428571428571425
#
# Epoch 94 Batch 0: Train Loss = 0.1951
# Model Loss = 0.1944, Decov Loss = 0.0000
# Epoch 94 Batch 30: Train Loss = 0.2012
# Model Loss = 0.2004, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3486
# valid_model Loss = 0.3486
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2615  171]
#  [ 249  187]]
# accuracy = 0.8696461824953445
# precision class 0 = 0.9130586592178771
# precision class 1 = 0.5223463687150838
# recall class 0 = 0.9386216798277099
# recall class 1 = 0.4288990825688073
# AUC of ROC = 0.8438152426615384
# AUC of PRC = 0.4835947867056849
# min(+P, Se) = 0.49770642201834864
# f1_score = 0.4710327455919396
#
# Epoch 95 Batch 0: Train Loss = 0.2290
# Model Loss = 0.2283, Decov Loss = 0.0000
# Epoch 95 Batch 30: Train Loss = 0.2049
# Model Loss = 0.2041, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3512
# valid_model Loss = 0.3512
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2578  208]
#  [ 233  203]]
# accuracy = 0.8631284916201117
# precision class 0 = 0.9171113482746354
# precision class 1 = 0.49391727493917276
# recall class 0 = 0.9253409906676239
# recall class 1 = 0.46559633027522934
# AUC of ROC = 0.8398891574517411
# AUC of PRC = 0.4822488928817731
# min(+P, Se) = 0.481651376146789
# f1_score = 0.47933884297520657
#
# Epoch 96 Batch 0: Train Loss = 0.1883
# Model Loss = 0.1877, Decov Loss = 0.0000
# Epoch 96 Batch 30: Train Loss = 0.1983
# Model Loss = 0.1974, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3531
# valid_model Loss = 0.3531
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2656  130]
#  [ 267  169]]
# accuracy = 0.8767846058348852
# precision class 0 = 0.9086554909339719
# precision class 1 = 0.5652173913043478
# recall class 0 = 0.9533381191672649
# recall class 1 = 0.3876146788990826
# AUC of ROC = 0.8374161106976561
# AUC of PRC = 0.49482402124886754
# min(+P, Se) = 0.5
# f1_score = 0.4598639455782313
#
# Epoch 97 Batch 0: Train Loss = 0.2096
# Model Loss = 0.2090, Decov Loss = 0.0000
# Epoch 97 Batch 30: Train Loss = 0.1866
# Model Loss = 0.1858, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3261
# valid_model Loss = 0.3261
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2652  134]
#  [ 263  173]]
# accuracy = 0.8767846058348852
# precision class 0 = 0.9097770154373928
# precision class 1 = 0.5635179153094463
# recall class 0 = 0.9519023689877961
# recall class 1 = 0.3967889908256881
# AUC of ROC = 0.8418336769035215
# AUC of PRC = 0.49208795342957073
# min(+P, Se) = 0.5011441647597255
# f1_score = 0.4656796769851952
#
# Epoch 98 Batch 0: Train Loss = 0.1968
# Model Loss = 0.1929, Decov Loss = 0.0000
# Epoch 98 Batch 30: Train Loss = 0.2006
# Model Loss = 0.1994, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3752
# valid_model Loss = 0.3752
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2691   95]
#  [ 294  142]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.9015075376884422
# precision class 1 = 0.5991561181434599
# recall class 0 = 0.9659009332376166
# recall class 1 = 0.3256880733944954
# AUC of ROC = 0.8402678530266009
# AUC of PRC = 0.48821488079002584
# min(+P, Se) = 0.5045871559633027
# f1_score = 0.4219910846953938
#
# Epoch 99 Batch 0: Train Loss = 0.1878
# Model Loss = 0.1872, Decov Loss = 0.0000
# Epoch 99 Batch 30: Train Loss = 0.1899
# Model Loss = 0.1889, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3493
# valid_model Loss = 0.3493
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2613  173]
#  [ 240  196]]
# accuracy = 0.8718187461204221
# precision class 0 = 0.9158780231335436
# precision class 1 = 0.5311653116531165
# recall class 0 = 0.9379038047379756
# recall class 1 = 0.44954128440366975
# AUC of ROC = 0.8420814755296798
# AUC of PRC = 0.503340140175853
# min(+P, Se) = 0.49311926605504586
# f1_score = 0.48695652173913045

# %% [markdown]
# ### Run for test

# %%
checkpoint = torch.load(file_name)
save_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['net'])
optimizer.load_state_dict(checkpoint['optimizer'])
model.eval()

test_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'test'),
                                            listfile=os.path.join(data_path, 'test_listfile.csv'),
                                            period_length=48.0)
test_raw = utils.load_data(test_reader, discretizer, normalizer, small_part, return_names=True)
test_dataset = Dataset(test_raw['data'][0], test_raw['data'][1], test_raw['names'])
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# C:\Users\alper\AppData\Local\Temp\ipykernel_77568\3123361523.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(file_name)

# %%
batch_loss = []
y_true = []
y_pred = []

with torch.no_grad():
    model.eval()
    for step, (batch_x, batch_y, batch_name) in enumerate(test_loader):
        batch_x = batch_x.float().to(device)
        batch_y = batch_y.float().to(device)

        # O(1) demographic lookup using the same key scheme as train/valid
        batch_demo = [demo_map[f"{bn.split('_', 2)[0]}_{bn.split('_', 2)[1]}"] for bn in batch_name]
        batch_demo = torch.stack(batch_demo).to(device)

        # If model returns (logits, decov_loss)
        output, _ = model(batch_x, batch_demo)

        loss = get_loss(output, batch_y.unsqueeze(-1))
        batch_loss.append(loss.item())

        # If get_loss uses BCEWithLogitsLoss, convert logits -> probs for metrics
        probs = output.detach().cpu().numpy().flatten()
        y_pred.extend(probs)
        y_true.extend(batch_y.cpu().numpy().flatten())

print("\n==>Predicting on test")
print('Test Loss = %.4f' % (np.mean(np.array(batch_loss))))

y_pred = np.array(y_pred)                                   # positive-class probs in [0, 1]
y_pred_prob = np.stack([1.0 - y_pred, y_pred], axis=1)      # shape (N, 2) = [P0, P1]
test_res = metrics.print_metrics_binary(y_true, y_pred_prob)
# Out:
# ==>Predicting on test
# Test Loss = 0.2768
# confusion matrix:
# [[2784   78]
#  [ 254  120]]
# accuracy = 0.8974042027194067
# precision class 0 = 0.9163923633969717
# precision class 1 = 0.6060606060606061
# recall class 0 = 0.9727463312368972
# recall class 1 = 0.32085561497326204
# AUC of ROC = 0.8480980728483503
# AUC of PRC = 0.4428800853605693
# min(+P, Se) = 0.4732620320855615
# f1_score = 0.4195804195804196

# %%
# Bootstrap evaluation
y_true_arr = np.asarray(y_true, dtype=int)
y_pred_arr = np.asarray(y_pred_prob, dtype=float)   # 1D positive-class probabilities

N = len(y_true_arr)
N_idx = np.arange(N)
K = 1000

auroc = []
auprc = []
minpse = []
for i in range(K):
    boot_idx = np.random.choice(N_idx, N, replace=True)
    boot_true = y_true_arr[boot_idx]
    boot_pred = y_pred_arr[boot_idx, :]  # 1D slice is correct

    test_ret = metrics.print_metrics_binary(boot_true, boot_pred, verbose=0)
    auroc.append(test_ret["auroc"])
    auprc.append(test_ret["auprc"])
    minpse.append(test_ret["minpse"])

    if (i + 1) % 50 == 0:
        print(f"{i+1}/{K}")

print("auroc %.4f(%.4f)" % (np.mean(auroc), np.std(auroc)))
print("auprc %.4f(%.4f)" % (np.mean(auprc), np.std(auprc)))
print("minpse %.4f(%.4f)" % (np.mean(minpse), np.std(minpse)))
# Out:
# 50/1000
# 100/1000
# 150/1000
# 200/1000
# 250/1000
# 300/1000
# 350/1000
# 400/1000
# 450/1000
# 500/1000
# 550/1000
# 600/1000
# 650/1000
# 700/1000
# 750/1000
# 800/1000
# 850/1000
# 900/1000
# 950/1000
# 1000/1000
# auroc 0.8484(0.0098)
# auprc 0.4451(0.0276)
# minpse 0.4748(0.0225)
