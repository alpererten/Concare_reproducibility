# %%
# Use external ConCare architecture from the uploaded file
import sys, os
sys.path.append('/mnt/data')  # Ensure the uploaded model file is importable
from ConCare_Model_v5 import ConCare  # noqa: F401
print('Imported ConCare from ConCare_Model_v5.py successfully')
# Out:
# Imported ConCare from ConCare_Model_v5.py successfully

# %%
# Quick sanity check of ConCare signature
try:
    _sig = ConCare.__init__.__code__.co_varnames
    print('ConCare init args:', _sig)
except Exception as e:
    print('Warning reading ConCare signature:', e)
# Out:
# ConCare init args: ('self', 'input_dim', 'hidden_dim', 'd_model', 'MHD_num_head', 'd_ff', 'output_dim', 'keep_prob', 'demographic_dim')

# %%
import numpy as np
import argparse
import os
import importlib
import re
import pickle
import datetime
import random
import math
import copy


import torch
from torch import nn
import torch.nn.utils.rnn as rnn_utils
from torch.utils import data
from torch.autograd import Variable
import torch.nn.functional as F


from utils import utils
from utils.readers import InHospitalMortalityReader
from utils.preprocessing import Discretizer, Normalizer
from utils import metrics
from utils import common_utils

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Prepare

# %%
data_path = './data/'
file_name = './model/concare_v1'
small_part = False
arg_timestep = 1.0
batch_size = 256
epochs = 100

# %%
# Build readers, discretizers, normalizers
train_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'train'),
                                         listfile=os.path.join(data_path, 'train_listfile.csv'),
                                         period_length=48.0)

val_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'train'),
                                       listfile=os.path.join(data_path, 'val_listfile.csv'),
                                       period_length=48.0)

discretizer = Discretizer(timestep=arg_timestep,
                          store_masks=True,
                          impute_strategy='previous',
                          start_time='zero')

# %%
discretizer_header = discretizer.transform(train_reader.read_example(0)["X"])[1].split(',')
cont_channels = [i for (i, x) in enumerate(discretizer_header) if x.find("->") == -1]

normalizer = Normalizer(fields=cont_channels)  # choose here which columns to standardize
normalizer_state = 'ihm_normalizer'
normalizer_state = os.path.join(os.path.dirname(data_path), normalizer_state)
normalizer.load_params(normalizer_state)

# %%
n_trained_chunks = 0
train_raw = utils.load_data(train_reader, discretizer, normalizer, small_part, return_names=True)
val_raw = utils.load_data(val_reader, discretizer, normalizer, small_part, return_names=True)

# %%
demographic_data = []
diagnosis_data = []
idx_list = []

demo_path = data_path + 'demographic/'
for cur_name in os.listdir(demo_path):
    cur_id, cur_episode = cur_name.split('_', 1)
    cur_episode = cur_episode[:-4]
    cur_file = demo_path + cur_name

    with open(cur_file, "r") as tsfile:
        header = tsfile.readline().strip().split(',')
        if header[0] != "Icustay":
            continue
        cur_data = tsfile.readline().strip().split(',')
        
    if len(cur_data) == 1:
        cur_demo = np.zeros(12)
        cur_diag = np.zeros(128)
    else:
        if cur_data[3] == '':
            cur_data[3] = 60.0
        if cur_data[4] == '':
            cur_data[4] = 160
        if cur_data[5] == '':
            cur_data[5] = 60

        cur_demo = np.zeros(12)
        cur_demo[int(cur_data[1])] = 1
        cur_demo[5 + int(cur_data[2])] = 1
        cur_demo[9:] = cur_data[3:6]
        cur_diag = np.array(cur_data[8:], dtype=int)

    demographic_data.append(cur_demo)
    diagnosis_data.append(cur_diag)
    idx_list.append(cur_id+'_'+cur_episode)

for each_idx in range(9,12):
    cur_val = []
    for i in range(len(demographic_data)):
        cur_val.append(demographic_data[i][each_idx])
    cur_val = np.array(cur_val)
    _mean = np.mean(cur_val)
    _std = np.std(cur_val)
    _std = _std if _std > 1e-7 else 1e-7
    for i in range(len(demographic_data)):
        demographic_data[i][each_idx] = (demographic_data[i][each_idx] - _mean) / _std

# %% [markdown]
# ### model

# %%
def get_loss(y_pred, y_true):
    loss = torch.nn.BCELoss()
    return loss(y_pred, y_true)

# %%
class Dataset(data.Dataset):
    def __init__(self, x, y, name):
        self.x = x
        self.y = y
        self.name = name

    def __getitem__(self, index):#返回的是tensor
        return self.x[index], self.y[index], self.name[index]

    def __len__(self):
        return len(self.x)

# %%
train_dataset = Dataset(train_raw['data'][0], train_raw['data'][1], train_raw['names'])
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_dataset = Dataset(val_raw['data'][0], val_raw['data'][1], val_raw['names'])
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Run

# %%
try:
    DEM_DIM = len(demographic_data[0])
except Exception:
    DEM_DIM = 12  # fallback; adjust if your demographics vector has a different size

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)  # numpy
random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)  # cpu
torch.cuda.manual_seed(RANDOM_SEED)  # gpu
torch.backends.cudnn.deterministic = True  # cudnn


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = ConCare(input_dim=76, hidden_dim=64, d_model=64, MHD_num_head=4, d_ff=256, output_dim=1, keep_prob=0.8, demographic_dim=DEM_DIM).to(device)
# input_dim, d_model, d_k, d_v, MHD_num_head, d_ff, output_dim
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

max_roc = 0
max_prc = 0
train_loss = []
train_model_loss = []
train_decov_loss = []
valid_loss = []
valid_model_loss = []
valid_decov_loss = []
history = []
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=2)
np.set_printoptions(suppress=True)

# Build once for O(1) demographic lookup
demo_map = {idx_list[i]: torch.tensor(demographic_data[i], dtype=torch.float32) for i in range(len(idx_list))}

for each_epoch in range(100):
    batch_loss = []
    model_batch_loss = []
    decov_batch_loss = []

    model.train()

    for step, (batch_x, batch_y, batch_name) in enumerate(train_loader):
        optimizer.zero_grad()
        batch_x = batch_x.float().to(device)
        batch_y = batch_y.float().to(device)

        # Fast demographic batch build
        batch_demo = [demo_map[f"{batch_name[i].split('_', 2)[0]}_{batch_name[i].split('_', 2)[1]}"] for i in range(len(batch_name))]
        batch_demo = torch.stack(batch_demo).to(device)

        output, decov_loss = model(batch_x, batch_demo)

        model_loss = get_loss(output, batch_y.unsqueeze(-1))
        loss = model_loss + 800 * decov_loss

        batch_loss.append(loss.item())
        model_batch_loss.append(model_loss.item())
        decov_batch_loss.append(decov_loss.item())
        loss.backward()
        optimizer.step()

        if step % 30 == 0:
            print('Epoch %d Batch %d: Train Loss = %.4f' % (each_epoch, step, np.mean(np.array(batch_loss))))
            print('Model Loss = %.4f, Decov Loss = %.4f' % (np.mean(np.array(model_batch_loss)), np.mean(np.array(decov_batch_loss))))
    train_loss.append(np.mean(np.array(batch_loss)))
    train_model_loss.append(np.mean(np.array(model_batch_loss)))
    train_decov_loss.append(np.mean(np.array(decov_batch_loss)))

    batch_loss = []
    model_batch_loss = []
    decov_batch_loss = []

    y_true = []
    y_pred = []
    with torch.no_grad():
        model.eval()
        for step, (batch_x, batch_y, batch_name) in enumerate(valid_loader):
            batch_x = batch_x.float().to(device)
            batch_y = batch_y.float().to(device)

            # Fast demographic batch build
            batch_demo = [demo_map[f"{batch_name[i].split('_', 2)[0]}_{batch_name[i].split('_', 2)[1]}"] for i in range(len(batch_name))]
            batch_demo = torch.stack(batch_demo).to(device)

            output, decov_loss = model(batch_x, batch_demo)

            model_loss = get_loss(output, batch_y.unsqueeze(-1))

            loss = model_loss + 10 * decov_loss
            batch_loss.append(loss.item())
            model_batch_loss.append(model_loss.item())
            decov_batch_loss.append(decov_loss.item())
            y_pred += list(output.cpu().detach().numpy().flatten())
            y_true += list(batch_y.cpu().numpy().flatten())

    valid_loss.append(np.mean(np.array(batch_loss)))
    valid_model_loss.append(np.mean(np.array(model_batch_loss)))
    valid_decov_loss.append(np.mean(np.array(decov_batch_loss)))

    print("\n==>Predicting on validation")
    print('Valid Loss = %.4f' % (valid_loss[-1]))
    print('valid_model Loss = %.4f' % (valid_model_loss[-1]))
    print('valid_decov Loss = %.4f' % (valid_decov_loss[-1]))
    y_pred = np.array(y_pred)
    y_pred = np.stack([1 - y_pred, y_pred], axis=1)
    ret = metrics.print_metrics_binary(y_true, y_pred)
    history.append(ret)
    print()

    cur_auroc = ret['auroc']

    if cur_auroc > max_roc:
        max_roc = cur_auroc
        state = {
            'net': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epoch': each_epoch
        }
        # Ensure parent directory exists before saving
        import os
        os.makedirs(os.path.dirname(file_name), exist_ok=True)
        torch.save(state, file_name)
        print('\n------------ Save best model ------------\n')
# Out:
# Using device: cuda
# Epoch 0 Batch 0: Train Loss = 0.6632
# Model Loss = 0.6611, Decov Loss = 0.0000
# Epoch 0 Batch 30: Train Loss = 0.4867
# Model Loss = 0.4834, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3879
# valid_model Loss = 0.3879
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2786    0]
#  [ 436    0]]
# accuracy = 0.8646803227808815
# precision class 0 = 0.8646803227808815
# precision class 1 = 0.0
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.6414057509039298
# AUC of PRC = 0.21583696749572504
# min(+P, Se) = 0.2545871559633027
# f1_score = 0.0
#
#
# ------------ Save best model ------------
#
# Epoch 1 Batch 0: Train Loss = 0.3927
# Model Loss = 0.3922, Decov Loss = 0.0000
# Epoch 1 Batch 30: Train Loss = 0.3876
# Model Loss = 0.3871, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3482
# valid_model Loss = 0.3482
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2786    0]
#  [ 436    0]]
# accuracy = 0.8646803227808815
# precision class 0 = 0.8646803227808815
# precision class 1 = 0.0
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.7669318084524853
# AUC of PRC = 0.3782170279512667
# min(+P, Se) = 0.38073394495412843
# f1_score = 0.0
#
#
# ------------ Save best model ------------
#
# Epoch 2 Batch 0: Train Loss = 0.4052
# Model Loss = 0.4047, Decov Loss = 0.0000
# Epoch 2 Batch 30: Train Loss = 0.3536
# Model Loss = 0.3532, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3510
# valid_model Loss = 0.3510
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2744   42]
#  [ 382   54]]
# accuracy = 0.8684047175667288
# precision class 0 = 0.8777991042866283
# precision class 1 = 0.5625
# recall class 0 = 0.9849246231155779
# recall class 1 = 0.12385321100917432
# AUC of ROC = 0.7691776378616544
# AUC of PRC = 0.37222657101113826
# min(+P, Se) = 0.37100213219616207
# f1_score = 0.2030075187969925
#
#
# ------------ Save best model ------------
#
# Epoch 3 Batch 0: Train Loss = 0.3815
# Model Loss = 0.3813, Decov Loss = 0.0000
# Epoch 3 Batch 30: Train Loss = 0.3464
# Model Loss = 0.3462, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3323
# valid_model Loss = 0.3323
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2743   43]
#  [ 375   61]]
# accuracy = 0.8702669149596524
# precision class 0 = 0.8797305965362412
# precision class 1 = 0.5865384615384616
# recall class 0 = 0.9845656855707107
# recall class 1 = 0.13990825688073394
# AUC of ROC = 0.7814119746833775
# AUC of PRC = 0.39358702006338525
# min(+P, Se) = 0.4142538975501114
# f1_score = 0.22592592592592592
#
#
# ------------ Save best model ------------
#
# Epoch 4 Batch 0: Train Loss = 0.3332
# Model Loss = 0.3330, Decov Loss = 0.0000
# Epoch 4 Batch 30: Train Loss = 0.3473
# Model Loss = 0.3471, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3343
# valid_model Loss = 0.3343
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2718   68]
#  [ 359   77]]
# accuracy = 0.8674736188702669
# precision class 0 = 0.8833279168020799
# precision class 1 = 0.5310344827586206
# recall class 0 = 0.9755922469490309
# recall class 1 = 0.17660550458715596
# AUC of ROC = 0.7809246099435578
# AUC of PRC = 0.39159346279061635
# min(+P, Se) = 0.4053452115812918
# f1_score = 0.2650602409638554
#
# Epoch 5 Batch 0: Train Loss = 0.3303
# Model Loss = 0.3301, Decov Loss = 0.0000
# Epoch 5 Batch 30: Train Loss = 0.3392
# Model Loss = 0.3390, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3254
# valid_model Loss = 0.3254
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2732   54]
#  [ 367   69]]
# accuracy = 0.8693358162631906
# precision class 0 = 0.8815747015166182
# precision class 1 = 0.5609756097560976
# recall class 0 = 0.9806173725771715
# recall class 1 = 0.15825688073394495
# AUC of ROC = 0.7899873713258296
# AUC of PRC = 0.40928708339776015
# min(+P, Se) = 0.4315068493150685
# f1_score = 0.24686940966010734
#
#
# ------------ Save best model ------------
#
# Epoch 6 Batch 0: Train Loss = 0.2651
# Model Loss = 0.2649, Decov Loss = 0.0000
# Epoch 6 Batch 30: Train Loss = 0.3323
# Model Loss = 0.3320, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3177
# valid_model Loss = 0.3177
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2724   62]
#  [ 351   85]]
# accuracy = 0.8718187461204221
# precision class 0 = 0.8858536585365854
# precision class 1 = 0.5782312925170068
# recall class 0 = 0.9777458722182341
# recall class 1 = 0.19495412844036697
# AUC of ROC = 0.8068364430277205
# AUC of PRC = 0.4348007042758033
# min(+P, Se) = 0.44967880085653106
# f1_score = 0.2915951972555746
#
#
# ------------ Save best model ------------
#
# Epoch 7 Batch 0: Train Loss = 0.3059
# Model Loss = 0.3057, Decov Loss = 0.0000
# Epoch 7 Batch 30: Train Loss = 0.3288
# Model Loss = 0.3286, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3202
# valid_model Loss = 0.3202
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2695   91]
#  [ 328  108]]
# accuracy = 0.8699565487274985
# precision class 0 = 0.8914985114125041
# precision class 1 = 0.542713567839196
# recall class 0 = 0.9673366834170855
# recall class 1 = 0.24770642201834864
# AUC of ROC = 0.8023176169181424
# AUC of PRC = 0.4219640182729945
# min(+P, Se) = 0.44724770642201833
# f1_score = 0.3401574803149607
#
# Epoch 8 Batch 0: Train Loss = 0.3033
# Model Loss = 0.3030, Decov Loss = 0.0000
# Epoch 8 Batch 30: Train Loss = 0.3232
# Model Loss = 0.3229, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3111
# valid_model Loss = 0.3111
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2733   53]
#  [ 354   82]]
# accuracy = 0.8736809435133458
# precision class 0 = 0.8853255587949466
# precision class 1 = 0.6074074074074074
# recall class 0 = 0.9809763101220388
# recall class 1 = 0.18807339449541285
# AUC of ROC = 0.8158518674631348
# AUC of PRC = 0.45070806275753295
# min(+P, Se) = 0.48299319727891155
# f1_score = 0.28721541155866903
#
#
# ------------ Save best model ------------
#
# Epoch 9 Batch 0: Train Loss = 0.2953
# Model Loss = 0.2951, Decov Loss = 0.0000
# Epoch 9 Batch 30: Train Loss = 0.3171
# Model Loss = 0.3168, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3129
# valid_model Loss = 0.3129
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2779    7]
#  [ 415   21]]
# accuracy = 0.8690254500310366
# precision class 0 = 0.8700688791484033
# precision class 1 = 0.75
# recall class 0 = 0.9974874371859297
# recall class 1 = 0.0481651376146789
# AUC of ROC = 0.8138340786501314
# AUC of PRC = 0.4546487427228173
# min(+P, Se) = 0.463302752293578
# f1_score = 0.09051724137931036
#
# Epoch 10 Batch 0: Train Loss = 0.3066
# Model Loss = 0.3063, Decov Loss = 0.0000
# Epoch 10 Batch 30: Train Loss = 0.3236
# Model Loss = 0.3232, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3081
# valid_model Loss = 0.3081
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2748   38]
#  [ 369   67]]
# accuracy = 0.8736809435133458
# precision class 0 = 0.8816169393647738
# precision class 1 = 0.638095238095238
# recall class 0 = 0.9863603732950467
# recall class 1 = 0.1536697247706422
# AUC of ROC = 0.8205872086513828
# AUC of PRC = 0.4537891020548908
# min(+P, Se) = 0.4553376906318083
# f1_score = 0.24768946395563768
#
#
# ------------ Save best model ------------
#
# Epoch 11 Batch 0: Train Loss = 0.3766
# Model Loss = 0.3763, Decov Loss = 0.0000
# Epoch 11 Batch 30: Train Loss = 0.3135
# Model Loss = 0.3132, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3102
# valid_model Loss = 0.3102
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2726   60]
#  [ 351   85]]
# accuracy = 0.87243947858473
# precision class 0 = 0.8859278518037049
# precision class 1 = 0.5862068965517241
# recall class 0 = 0.9784637473079684
# recall class 1 = 0.19495412844036697
# AUC of ROC = 0.8189670501919822
# AUC of PRC = 0.4348149436987992
# min(+P, Se) = 0.44724770642201833
# f1_score = 0.29259896729776247
#
# Epoch 12 Batch 0: Train Loss = 0.3593
# Model Loss = 0.3589, Decov Loss = 0.0000
# Epoch 12 Batch 30: Train Loss = 0.3214
# Model Loss = 0.3210, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3068
# valid_model Loss = 0.3068
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2718   68]
#  [ 339   97]]
# accuracy = 0.8736809435133458
# precision class 0 = 0.8891069676153092
# precision class 1 = 0.5878787878787879
# recall class 0 = 0.9755922469490309
# recall class 1 = 0.22247706422018348
# AUC of ROC = 0.8229598187530048
# AUC of PRC = 0.44761283507723343
# min(+P, Se) = 0.4634703196347032
# f1_score = 0.3227953410981697
#
#
# ------------ Save best model ------------
#
# Epoch 13 Batch 0: Train Loss = 0.3165
# Model Loss = 0.3159, Decov Loss = 0.0000
# Epoch 13 Batch 30: Train Loss = 0.3138
# Model Loss = 0.3132, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3139
# valid_model Loss = 0.3139
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2745   41]
#  [ 359   77]]
# accuracy = 0.8758535071384234
# precision class 0 = 0.8843427835051546
# precision class 1 = 0.652542372881356
# recall class 0 = 0.9852835606604451
# recall class 1 = 0.17660550458715596
# AUC of ROC = 0.8273761500819958
# AUC of PRC = 0.46014397893138204
# min(+P, Se) = 0.45879732739420936
# f1_score = 0.2779783393501805
#
#
# ------------ Save best model ------------
#
# Epoch 14 Batch 0: Train Loss = 0.4308
# Model Loss = 0.4305, Decov Loss = 0.0000
# Epoch 14 Batch 30: Train Loss = 0.3075
# Model Loss = 0.3069, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3048
# valid_model Loss = 0.3048
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2712   74]
#  [ 330  106]]
# accuracy = 0.8746120422098076
# precision class 0 = 0.8915187376725838
# precision class 1 = 0.5888888888888889
# recall class 0 = 0.9734386216798278
# recall class 1 = 0.24311926605504589
# AUC of ROC = 0.8287859678470993
# AUC of PRC = 0.4553572873350043
# min(+P, Se) = 0.4604966139954853
# f1_score = 0.3441558441558442
#
#
# ------------ Save best model ------------
#
# Epoch 15 Batch 0: Train Loss = 0.3298
# Model Loss = 0.3295, Decov Loss = 0.0000
# Epoch 15 Batch 30: Train Loss = 0.3100
# Model Loss = 0.3095, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3096
# valid_model Loss = 0.3096
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2763   23]
#  [ 390   46]]
# accuracy = 0.8718187461204221
# precision class 0 = 0.8763082778306375
# precision class 1 = 0.6666666666666666
# recall class 0 = 0.9917444364680545
# recall class 1 = 0.10550458715596331
# AUC of ROC = 0.8334554489353716
# AUC of PRC = 0.45779775286880053
# min(+P, Se) = 0.46559633027522934
# f1_score = 0.18217821782178217
#
#
# ------------ Save best model ------------
#
# Epoch 16 Batch 0: Train Loss = 0.2976
# Model Loss = 0.2971, Decov Loss = 0.0000
# Epoch 16 Batch 30: Train Loss = 0.3117
# Model Loss = 0.3113, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3058
# valid_model Loss = 0.3058
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2762   24]
#  [ 395   41]]
# accuracy = 0.8699565487274985
# precision class 0 = 0.874881216344631
# precision class 1 = 0.6307692307692307
# recall class 0 = 0.9913854989231874
# recall class 1 = 0.09403669724770643
# AUC of ROC = 0.8279734188636498
# AUC of PRC = 0.44498136209942213
# min(+P, Se) = 0.4624145785876993
# f1_score = 0.16367265469061876
#
# Epoch 17 Batch 0: Train Loss = 0.3249
# Model Loss = 0.3243, Decov Loss = 0.0000
# Epoch 17 Batch 30: Train Loss = 0.3057
# Model Loss = 0.3050, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3121
# valid_model Loss = 0.3121
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2711   75]
#  [ 327  109]]
# accuracy = 0.8752327746741154
# precision class 0 = 0.8923633969716919
# precision class 1 = 0.592391304347826
# recall class 0 = 0.9730796841349605
# recall class 1 = 0.25
# AUC of ROC = 0.8283451168028874
# AUC of PRC = 0.45807784625728737
# min(+P, Se) = 0.4701834862385321
# f1_score = 0.35161290322580646
#
# Epoch 18 Batch 0: Train Loss = 0.2798
# Model Loss = 0.2789, Decov Loss = 0.0000
# Epoch 18 Batch 30: Train Loss = 0.3096
# Model Loss = 0.3087, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3013
# valid_model Loss = 0.3013
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2719   67]
#  [ 331  105]]
# accuracy = 0.8764742396027312
# precision class 0 = 0.8914754098360655
# precision class 1 = 0.6104651162790697
# recall class 0 = 0.9759511844938981
# recall class 1 = 0.2408256880733945
# AUC of ROC = 0.835572851149588
# AUC of PRC = 0.4726066837848014
# min(+P, Se) = 0.481651376146789
# f1_score = 0.34539473684210525
#
#
# ------------ Save best model ------------
#
# Epoch 19 Batch 0: Train Loss = 0.2588
# Model Loss = 0.2577, Decov Loss = 0.0000
# Epoch 19 Batch 30: Train Loss = 0.2995
# Model Loss = 0.2987, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2978
# valid_model Loss = 0.2978
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2697   89]
#  [ 309  127]]
# accuracy = 0.8764742396027312
# precision class 0 = 0.8972055888223552
# precision class 1 = 0.5879629629629629
# recall class 0 = 0.9680545585068198
# recall class 1 = 0.29128440366972475
# AUC of ROC = 0.8399690128229614
# AUC of PRC = 0.47134883068586314
# min(+P, Se) = 0.4772727272727273
# f1_score = 0.38957055214723924
#
#
# ------------ Save best model ------------
#
# Epoch 20 Batch 0: Train Loss = 0.2689
# Model Loss = 0.2684, Decov Loss = 0.0000
# Epoch 20 Batch 30: Train Loss = 0.2992
# Model Loss = 0.2983, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2998
# valid_model Loss = 0.2998
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2686  100]
#  [ 302  134]]
# accuracy = 0.8752327746741154
# precision class 0 = 0.8989290495314591
# precision class 1 = 0.5726495726495726
# recall class 0 = 0.9641062455132807
# recall class 1 = 0.3073394495412844
# AUC of ROC = 0.8391070687645305
# AUC of PRC = 0.4735853984884936
# min(+P, Se) = 0.4683257918552036
# f1_score = 0.39999999999999997
#
# Epoch 21 Batch 0: Train Loss = 0.3107
# Model Loss = 0.3102, Decov Loss = 0.0000
# Epoch 21 Batch 30: Train Loss = 0.2959
# Model Loss = 0.2951, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2955
# valid_model Loss = 0.2955
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2756   30]
#  [ 376   60]]
# accuracy = 0.8739913097454997
# precision class 0 = 0.879948914431673
# precision class 1 = 0.6666666666666666
# recall class 0 = 0.9892318736539842
# recall class 1 = 0.13761467889908258
# AUC of ROC = 0.8419374065609833
# AUC of PRC = 0.4833340501585247
# min(+P, Se) = 0.5
# f1_score = 0.2281368821292776
#
#
# ------------ Save best model ------------
#
# Epoch 22 Batch 0: Train Loss = 0.2912
# Model Loss = 0.2906, Decov Loss = 0.0000
# Epoch 22 Batch 30: Train Loss = 0.2938
# Model Loss = 0.2926, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2994
# valid_model Loss = 0.2994
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2729   57]
#  [ 343   93]]
# accuracy = 0.8758535071384234
# precision class 0 = 0.8883463541666666
# precision class 1 = 0.62
# recall class 0 = 0.9795405599425699
# recall class 1 = 0.21330275229357798
# AUC of ROC = 0.8373296693164382
# AUC of PRC = 0.4749983825508071
# min(+P, Se) = 0.48394495412844035
# f1_score = 0.3174061433447099
#
# Epoch 23 Batch 0: Train Loss = 0.2600
# Model Loss = 0.2594, Decov Loss = 0.0000
# Epoch 23 Batch 30: Train Loss = 0.2949
# Model Loss = 0.2942, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2973
# valid_model Loss = 0.2973
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2679  107]
#  [ 293  143]]
# accuracy = 0.8758535071384234
# precision class 0 = 0.9014131897711979
# precision class 1 = 0.572
# recall class 0 = 0.9615936826992103
# recall class 1 = 0.32798165137614677
# AUC of ROC = 0.8417036032060697
# AUC of PRC = 0.4792780187928419
# min(+P, Se) = 0.5034324942791762
# f1_score = 0.4169096209912536
#
# Epoch 24 Batch 0: Train Loss = 0.2277
# Model Loss = 0.2265, Decov Loss = 0.0000
# Epoch 24 Batch 30: Train Loss = 0.2942
# Model Loss = 0.2930, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2958
# valid_model Loss = 0.2958
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2713   73]
#  [ 328  108]]
# accuracy = 0.8755431409062694
# precision class 0 = 0.8921407431765866
# precision class 1 = 0.5966850828729282
# recall class 0 = 0.9737975592246949
# recall class 1 = 0.24770642201834864
# AUC of ROC = 0.8400463984404328
# AUC of PRC = 0.48206976879010205
# min(+P, Se) = 0.4875283446712018
# f1_score = 0.35008103727714746
#
# Epoch 25 Batch 0: Train Loss = 0.3452
# Model Loss = 0.3445, Decov Loss = 0.0000
# Epoch 25 Batch 30: Train Loss = 0.2846
# Model Loss = 0.2834, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3032
# valid_model Loss = 0.3032
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2676  110]
#  [ 275  161]]
# accuracy = 0.8805090006207325
# precision class 0 = 0.9068112504235852
# precision class 1 = 0.5940959409594095
# recall class 0 = 0.9605168700646087
# recall class 1 = 0.36926605504587157
# AUC of ROC = 0.8414887346298991
# AUC of PRC = 0.49262421945561125
# min(+P, Se) = 0.4954128440366973
# f1_score = 0.45544554455445546
#
# Epoch 26 Batch 0: Train Loss = 0.3175
# Model Loss = 0.3163, Decov Loss = 0.0000
# Epoch 26 Batch 30: Train Loss = 0.2937
# Model Loss = 0.2927, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2948
# valid_model Loss = 0.2948
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2717   69]
#  [ 324  112]]
# accuracy = 0.8780260707635009
# precision class 0 = 0.8934560999671161
# precision class 1 = 0.6187845303867403
# recall class 0 = 0.9752333094041636
# recall class 1 = 0.25688073394495414
# AUC of ROC = 0.8439148560627514
# AUC of PRC = 0.48871593037853056
# min(+P, Se) = 0.49311926605504586
# f1_score = 0.36304700162074555
#
#
# ------------ Save best model ------------
#
# Epoch 27 Batch 0: Train Loss = 0.2365
# Model Loss = 0.2355, Decov Loss = 0.0000
# Epoch 27 Batch 30: Train Loss = 0.2861
# Model Loss = 0.2852, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2969
# valid_model Loss = 0.2969
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2687   99]
#  [ 300  136]]
# accuracy = 0.8761638733705773
# precision class 0 = 0.8995647807164379
# precision class 1 = 0.5787234042553191
# recall class 0 = 0.9644651830581479
# recall class 1 = 0.3119266055045872
# AUC of ROC = 0.842345739180832
# AUC of PRC = 0.4849231768179498
# min(+P, Se) = 0.48394495412844035
# f1_score = 0.40536512667660207
#
# Epoch 28 Batch 0: Train Loss = 0.2899
# Model Loss = 0.2888, Decov Loss = 0.0000
# Epoch 28 Batch 30: Train Loss = 0.2771
# Model Loss = 0.2761, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2969
# valid_model Loss = 0.2969
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2707   79]
#  [ 310  126]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.8972489227709646
# precision class 1 = 0.6146341463414634
# recall class 0 = 0.9716439339554918
# recall class 1 = 0.2889908256880734
# AUC of ROC = 0.837719067157544
# AUC of PRC = 0.48805576531278577
# min(+P, Se) = 0.4954545454545455
# f1_score = 0.39313572542901715
#
# Epoch 29 Batch 0: Train Loss = 0.3209
# Model Loss = 0.3197, Decov Loss = 0.0000
# Epoch 29 Batch 30: Train Loss = 0.2792
# Model Loss = 0.2779, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2917
# valid_model Loss = 0.2917
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2742   44]
#  [ 349   87]]
# accuracy = 0.8780260707635009
# precision class 0 = 0.887091556130702
# precision class 1 = 0.6641221374045801
# recall class 0 = 0.9842067480258435
# recall class 1 = 0.19954128440366972
# AUC of ROC = 0.8497607631868386
# AUC of PRC = 0.5079374661492394
# min(+P, Se) = 0.518348623853211
# f1_score = 0.3068783068783069
#
#
# ------------ Save best model ------------
#
# Epoch 30 Batch 0: Train Loss = 0.2797
# Model Loss = 0.2790, Decov Loss = 0.0000
# Epoch 30 Batch 30: Train Loss = 0.2830
# Model Loss = 0.2816, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2911
# valid_model Loss = 0.2911
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2692   94]
#  [ 303  133]]
# accuracy = 0.8767846058348852
# precision class 0 = 0.8988313856427379
# precision class 1 = 0.5859030837004405
# recall class 0 = 0.9662598707824839
# recall class 1 = 0.30504587155963303
# AUC of ROC = 0.8467402543517061
# AUC of PRC = 0.4950827934354383
# min(+P, Se) = 0.5022935779816514
# f1_score = 0.40120663650075417
#
# Epoch 31 Batch 0: Train Loss = 0.2998
# Model Loss = 0.2992, Decov Loss = 0.0000
# Epoch 31 Batch 30: Train Loss = 0.2876
# Model Loss = 0.2865, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3030
# valid_model Loss = 0.3030
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2747   39]
#  [ 356   80]]
# accuracy = 0.8774053382991931
# precision class 0 = 0.8852723171124718
# precision class 1 = 0.6722689075630253
# recall class 0 = 0.9860014357501795
# recall class 1 = 0.1834862385321101
# AUC of ROC = 0.8386279365372077
# AUC of PRC = 0.48789810262853267
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.2882882882882883
#
# Epoch 32 Batch 0: Train Loss = 0.3344
# Model Loss = 0.3330, Decov Loss = 0.0000
# Epoch 32 Batch 30: Train Loss = 0.2911
# Model Loss = 0.2897, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2974
# valid_model Loss = 0.2974
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2669  117]
#  [ 278  158]]
# accuracy = 0.8774053382991931
# precision class 0 = 0.9056667797760435
# precision class 1 = 0.5745454545454546
# recall class 0 = 0.9580043072505384
# recall class 1 = 0.3623853211009174
# AUC of ROC = 0.8453168529409828
# AUC of PRC = 0.5008075640402132
# min(+P, Se) = 0.5045871559633027
# f1_score = 0.4444444444444444
#
# Epoch 33 Batch 0: Train Loss = 0.3183
# Model Loss = 0.3179, Decov Loss = 0.0000
# Epoch 33 Batch 30: Train Loss = 0.2831
# Model Loss = 0.2819, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2939
# valid_model Loss = 0.2939
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2718   68]
#  [ 321  115]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.8943731490621916
# precision class 1 = 0.6284153005464481
# recall class 0 = 0.9755922469490309
# recall class 1 = 0.26376146788990823
# AUC of ROC = 0.8439206188214994
# AUC of PRC = 0.48793886103002043
# min(+P, Se) = 0.4988610478359909
# f1_score = 0.3715670436187399
#
# Epoch 34 Batch 0: Train Loss = 0.2582
# Model Loss = 0.2577, Decov Loss = 0.0000
# Epoch 34 Batch 30: Train Loss = 0.2883
# Model Loss = 0.2868, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2908
# valid_model Loss = 0.2908
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2669  117]
#  [ 260  176]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9112325025606008
# precision class 1 = 0.6006825938566553
# recall class 0 = 0.9580043072505384
# recall class 1 = 0.4036697247706422
# AUC of ROC = 0.8503765551216107
# AUC of PRC = 0.5150711061407987
# min(+P, Se) = 0.49770642201834864
# f1_score = 0.4828532235939644
#
#
# ------------ Save best model ------------
#
# Epoch 35 Batch 0: Train Loss = 0.3061
# Model Loss = 0.3053, Decov Loss = 0.0000
# Epoch 35 Batch 30: Train Loss = 0.2840
# Model Loss = 0.2828, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2911
# valid_model Loss = 0.2911
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2718   68]
#  [ 319  117]]
# accuracy = 0.8798882681564246
# precision class 0 = 0.8949621336845571
# precision class 1 = 0.6324324324324324
# recall class 0 = 0.9755922469490309
# recall class 1 = 0.268348623853211
# AUC of ROC = 0.8515439253936787
# AUC of PRC = 0.5082568741107653
# min(+P, Se) = 0.5159817351598174
# f1_score = 0.37681159420289856
#
#
# ------------ Save best model ------------
#
# Epoch 36 Batch 0: Train Loss = 0.2397
# Model Loss = 0.2387, Decov Loss = 0.0000
# Epoch 36 Batch 30: Train Loss = 0.2802
# Model Loss = 0.2792, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2870
# valid_model Loss = 0.2869
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2702   84]
#  [ 288  148]]
# accuracy = 0.8845437616387337
# precision class 0 = 0.9036789297658863
# precision class 1 = 0.6379310344827587
# recall class 0 = 0.9698492462311558
# recall class 1 = 0.3394495412844037
# AUC of ROC = 0.8546829824087673
# AUC of PRC = 0.5099696492871065
# min(+P, Se) = 0.5215419501133787
# f1_score = 0.44311377245508987
#
#
# ------------ Save best model ------------
#
# Epoch 37 Batch 0: Train Loss = 0.2646
# Model Loss = 0.2636, Decov Loss = 0.0000
# Epoch 37 Batch 30: Train Loss = 0.2826
# Model Loss = 0.2813, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2865
# valid_model Loss = 0.2864
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2695   91]
#  [ 284  152]]
# accuracy = 0.8836126629422719
# precision class 0 = 0.9046659953004363
# precision class 1 = 0.6255144032921811
# recall class 0 = 0.9673366834170855
# recall class 1 = 0.3486238532110092
# AUC of ROC = 0.8548764464524459
# AUC of PRC = 0.5271258724565484
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.4477172312223859
#
#
# ------------ Save best model ------------
#
# Epoch 38 Batch 0: Train Loss = 0.2593
# Model Loss = 0.2582, Decov Loss = 0.0000
# Epoch 38 Batch 30: Train Loss = 0.2831
# Model Loss = 0.2813, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2868
# valid_model Loss = 0.2868
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2709   77]
#  [ 286  150]]
# accuracy = 0.8873370577281192
# precision class 0 = 0.9045075125208681
# precision class 1 = 0.6607929515418502
# recall class 0 = 0.9723618090452262
# recall class 1 = 0.3440366972477064
# AUC of ROC = 0.854505160138833
# AUC of PRC = 0.5292710922467351
# min(+P, Se) = 0.5168539325842697
# f1_score = 0.45248868778280543
#
# Epoch 39 Batch 0: Train Loss = 0.2662
# Model Loss = 0.2622, Decov Loss = 0.0000
# Epoch 39 Batch 30: Train Loss = 0.2753
# Model Loss = 0.2738, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2908
# valid_model Loss = 0.2908
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2666  120]
#  [ 265  171]]
# accuracy = 0.8805090006207325
# precision class 0 = 0.9095871716137837
# precision class 1 = 0.5876288659793815
# recall class 0 = 0.9569274946159368
# recall class 1 = 0.3922018348623853
# AUC of ROC = 0.8509166079414108
# AUC of PRC = 0.5067110862198788
# min(+P, Se) = 0.5114678899082569
# f1_score = 0.47042640990371387
#
# Epoch 40 Batch 0: Train Loss = 0.2548
# Model Loss = 0.2534, Decov Loss = 0.0000
# Epoch 40 Batch 30: Train Loss = 0.2741
# Model Loss = 0.2723, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2896
# valid_model Loss = 0.2896
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2653  133]
#  [ 244  192]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9157749395926821
# precision class 1 = 0.5907692307692308
# recall class 0 = 0.9522613065326633
# recall class 1 = 0.44036697247706424
# AUC of ROC = 0.8557293347471302
# AUC of PRC = 0.5151948867265811
# min(+P, Se) = 0.5170842824601367
# f1_score = 0.5045992115637321
#
#
# ------------ Save best model ------------
#
# Epoch 41 Batch 0: Train Loss = 0.2977
# Model Loss = 0.2950, Decov Loss = 0.0000
# Epoch 41 Batch 30: Train Loss = 0.2768
# Model Loss = 0.2751, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2889
# valid_model Loss = 0.2889
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2659  127]
#  [ 255  181]]
# accuracy = 0.8814400993171942
# precision class 0 = 0.9124914207275223
# precision class 1 = 0.5876623376623377
# recall class 0 = 0.9544149318018664
# recall class 1 = 0.4151376146788991
# AUC of ROC = 0.8553119463635347
# AUC of PRC = 0.5282552987263278
# min(+P, Se) = 0.5168539325842697
# f1_score = 0.48655913978494625
#
# Epoch 42 Batch 0: Train Loss = 0.2916
# Model Loss = 0.2908, Decov Loss = 0.0000
# Epoch 42 Batch 30: Train Loss = 0.2736
# Model Loss = 0.2724, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2876
# valid_model Loss = 0.2876
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2707   79]
#  [ 291  145]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.9029352901934623
# precision class 1 = 0.6473214285714286
# recall class 0 = 0.9716439339554918
# recall class 1 = 0.33256880733944955
# AUC of ROC = 0.8572877493628035
# AUC of PRC = 0.5155460844074337
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.43939393939393945
#
#
# ------------ Save best model ------------
#
# Epoch 43 Batch 0: Train Loss = 0.3111
# Model Loss = 0.3093, Decov Loss = 0.0000
# Epoch 43 Batch 30: Train Loss = 0.2785
# Model Loss = 0.2772, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2841
# valid_model Loss = 0.2841
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2729   57]
#  [ 305  131]]
# accuracy = 0.8876474239602731
# precision class 0 = 0.8994726433750824
# precision class 1 = 0.6968085106382979
# recall class 0 = 0.9795405599425699
# recall class 1 = 0.30045871559633025
# AUC of ROC = 0.8552337374948135
# AUC of PRC = 0.5204839662361348
# min(+P, Se) = 0.528604118993135
# f1_score = 0.4198717948717949
#
# Epoch 44 Batch 0: Train Loss = 0.2607
# Model Loss = 0.2585, Decov Loss = 0.0000
# Epoch 44 Batch 30: Train Loss = 0.2728
# Model Loss = 0.2711, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2900
# valid_model Loss = 0.2900
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2681  105]
#  [ 263  173]]
# accuracy = 0.8857852265673495
# precision class 0 = 0.9106657608695652
# precision class 1 = 0.6223021582733813
# recall class 0 = 0.9623115577889447
# recall class 1 = 0.3967889908256881
# AUC of ROC = 0.8514747722887044
# AUC of PRC = 0.5111846934710668
# min(+P, Se) = 0.518348623853211
# f1_score = 0.484593837535014
#
# Epoch 45 Batch 0: Train Loss = 0.2661
# Model Loss = 0.2656, Decov Loss = 0.0000
# Epoch 45 Batch 30: Train Loss = 0.2796
# Model Loss = 0.2787, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2839
# valid_model Loss = 0.2839
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2679  107]
#  [ 273  163]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.907520325203252
# precision class 1 = 0.6037037037037037
# recall class 0 = 0.9615936826992103
# recall class 1 = 0.3738532110091743
# AUC of ROC = 0.8572457635490691
# AUC of PRC = 0.5209619543103792
# min(+P, Se) = 0.5298165137614679
# f1_score = 0.46175637393767704
#
# Epoch 46 Batch 0: Train Loss = 0.2875
# Model Loss = 0.2863, Decov Loss = 0.0000
# Epoch 46 Batch 30: Train Loss = 0.2653
# Model Loss = 0.2639, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2889
# valid_model Loss = 0.2888
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2731   55]
#  [ 333  103]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.8913185378590078
# precision class 1 = 0.6518987341772152
# recall class 0 = 0.9802584350323044
# recall class 1 = 0.23623853211009174
# AUC of ROC = 0.8544203652601144
# AUC of PRC = 0.49479789435567284
# min(+P, Se) = 0.5114155251141552
# f1_score = 0.34680134680134683
#
# Epoch 47 Batch 0: Train Loss = 0.2863
# Model Loss = 0.2856, Decov Loss = 0.0000
# Epoch 47 Batch 30: Train Loss = 0.2582
# Model Loss = 0.2565, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2836
# valid_model Loss = 0.2836
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2695   91]
#  [ 273  163]]
# accuracy = 0.8870266914959652
# precision class 0 = 0.9080188679245284
# precision class 1 = 0.6417322834645669
# recall class 0 = 0.9673366834170855
# recall class 1 = 0.3738532110091743
# AUC of ROC = 0.8573449653246572
# AUC of PRC = 0.523678164369805
# min(+P, Se) = 0.518348623853211
# f1_score = 0.472463768115942
#
#
# ------------ Save best model ------------
#
# Epoch 48 Batch 0: Train Loss = 0.2850
# Model Loss = 0.2837, Decov Loss = 0.0000
# Epoch 48 Batch 30: Train Loss = 0.2654
# Model Loss = 0.2640, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2881
# valid_model Loss = 0.2880
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2712   74]
#  [ 296  140]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.901595744680851
# precision class 1 = 0.6542056074766355
# recall class 0 = 0.9734386216798278
# recall class 1 = 0.3211009174311927
# AUC of ROC = 0.8557672043046161
# AUC of PRC = 0.5272809952337123
# min(+P, Se) = 0.5298165137614679
# f1_score = 0.4307692307692308
#
# Epoch 49 Batch 0: Train Loss = 0.2372
# Model Loss = 0.2358, Decov Loss = 0.0000
# Epoch 49 Batch 30: Train Loss = 0.2680
# Model Loss = 0.2663, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2883
# valid_model Loss = 0.2883
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2694   92]
#  [ 270  166]]
# accuracy = 0.8876474239602731
# precision class 0 = 0.9089068825910931
# precision class 1 = 0.6434108527131783
# recall class 0 = 0.9669777458722182
# recall class 1 = 0.38073394495412843
# AUC of ROC = 0.8532200649380586
# AUC of PRC = 0.5295590264107556
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.478386167146974
#
# Epoch 50 Batch 0: Train Loss = 0.2323
# Model Loss = 0.2312, Decov Loss = 0.0000
# Epoch 50 Batch 30: Train Loss = 0.2674
# Model Loss = 0.2658, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2837
# valid_model Loss = 0.2837
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2684  102]
#  [ 262  174]]
# accuracy = 0.8870266914959652
# precision class 0 = 0.9110658520027155
# precision class 1 = 0.6304347826086957
# recall class 0 = 0.9633883704235463
# recall class 1 = 0.39908256880733944
# AUC of ROC = 0.8561409603719778
# AUC of PRC = 0.5327546201724687
# min(+P, Se) = 0.5272727272727272
# f1_score = 0.4887640449438202
#
# Epoch 51 Batch 0: Train Loss = 0.2115
# Model Loss = 0.2088, Decov Loss = 0.0000
# Epoch 51 Batch 30: Train Loss = 0.2696
# Model Loss = 0.2679, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2887
# valid_model Loss = 0.2887
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2668  118]
#  [ 255  181]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9127608621279507
# precision class 1 = 0.6053511705685619
# recall class 0 = 0.9576453697056713
# recall class 1 = 0.4151376146788991
# AUC of ROC = 0.8573182096590423
# AUC of PRC = 0.5226464661631578
# min(+P, Se) = 0.5298165137614679
# f1_score = 0.4925170068027211
#
# Epoch 52 Batch 0: Train Loss = 0.2755
# Model Loss = 0.2746, Decov Loss = 0.0000
# Epoch 52 Batch 30: Train Loss = 0.2655
# Model Loss = 0.2640, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2935
# valid_model Loss = 0.2935
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2730   56]
#  [ 307  129]]
# accuracy = 0.8873370577281192
# precision class 0 = 0.8989134013829437
# precision class 1 = 0.6972972972972973
# recall class 0 = 0.9798994974874372
# recall class 1 = 0.2958715596330275
# AUC of ROC = 0.852751223351357
# AUC of PRC = 0.5250357491360959
# min(+P, Se) = 0.53125
# f1_score = 0.41545893719806765
#
# Epoch 53 Batch 0: Train Loss = 0.2667
# Model Loss = 0.2654, Decov Loss = 0.0000
# Epoch 53 Batch 30: Train Loss = 0.2630
# Model Loss = 0.2612, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2862
# valid_model Loss = 0.2862
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2645  141]
#  [ 236  200]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9180839986115932
# precision class 1 = 0.5865102639296188
# recall class 0 = 0.9493898061737258
# recall class 1 = 0.45871559633027525
# AUC of ROC = 0.8578031046451129
# AUC of PRC = 0.543410802349608
# min(+P, Se) = 0.5389908256880734
# f1_score = 0.5148005148005148
#
#
# ------------ Save best model ------------
#
# Epoch 54 Batch 0: Train Loss = 0.3026
# Model Loss = 0.3014, Decov Loss = 0.0000
# Epoch 54 Batch 30: Train Loss = 0.2681
# Model Loss = 0.2663, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2899
# valid_model Loss = 0.2899
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2648  138]
#  [ 240  196]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9168975069252078
# precision class 1 = 0.5868263473053892
# recall class 0 = 0.9504666188083274
# recall class 1 = 0.44954128440366975
# AUC of ROC = 0.8536744996278904
# AUC of PRC = 0.5266403009181646
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.509090909090909
#
# Epoch 55 Batch 0: Train Loss = 0.2769
# Model Loss = 0.2754, Decov Loss = 0.0000
# Epoch 55 Batch 30: Train Loss = 0.2669
# Model Loss = 0.2651, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2875
# valid_model Loss = 0.2875
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2683  103]
#  [ 265  171]]
# accuracy = 0.8857852265673495
# precision class 0 = 0.9101085481682497
# precision class 1 = 0.6240875912408759
# recall class 0 = 0.9630294328786791
# recall class 1 = 0.3922018348623853
# AUC of ROC = 0.8562990246119195
# AUC of PRC = 0.534355538429836
# min(+P, Se) = 0.5217391304347826
# f1_score = 0.48169014084507045
#
# Epoch 56 Batch 0: Train Loss = 0.2379
# Model Loss = 0.2348, Decov Loss = 0.0000
# Epoch 56 Batch 30: Train Loss = 0.2590
# Model Loss = 0.2569, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3065
# valid_model Loss = 0.3065
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2746   40]
#  [ 348   88]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.8875242404654169
# precision class 1 = 0.6875
# recall class 0 = 0.9856424982053122
# recall class 1 = 0.2018348623853211
# AUC of ROC = 0.8550501524661314
# AUC of PRC = 0.5281857637545722
# min(+P, Se) = 0.530751708428246
# f1_score = 0.3120567375886525
#
# Epoch 57 Batch 0: Train Loss = 0.2550
# Model Loss = 0.2542, Decov Loss = 0.0000
# Epoch 57 Batch 30: Train Loss = 0.2616
# Model Loss = 0.2601, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2838
# valid_model Loss = 0.2838
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2716   70]
#  [ 291  145]]
# accuracy = 0.887957790192427
# precision class 0 = 0.9032258064516129
# precision class 1 = 0.6744186046511628
# recall class 0 = 0.9748743718592965
# recall class 1 = 0.33256880733944955
# AUC of ROC = 0.8547010939362606
# AUC of PRC = 0.5373455856394629
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.445468509984639
#
# Epoch 58 Batch 0: Train Loss = 0.2523
# Model Loss = 0.2508, Decov Loss = 0.0000
# Epoch 58 Batch 30: Train Loss = 0.2576
# Model Loss = 0.2563, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2937
# valid_model Loss = 0.2937
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2739   47]
#  [ 324  112]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.8942213516160626
# precision class 1 = 0.7044025157232704
# recall class 0 = 0.9831299353912419
# recall class 1 = 0.25688073394495414
# AUC of ROC = 0.8551843424198318
# AUC of PRC = 0.5277399187032543
# min(+P, Se) = 0.5331807780320366
# f1_score = 0.3764705882352941
#
# Epoch 59 Batch 0: Train Loss = 0.2409
# Model Loss = 0.2390, Decov Loss = 0.0000
# Epoch 59 Batch 30: Train Loss = 0.2592
# Model Loss = 0.2577, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2831
# valid_model Loss = 0.2831
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2716   70]
#  [ 289  147]]
# accuracy = 0.888578522656735
# precision class 0 = 0.9038269550748752
# precision class 1 = 0.6774193548387096
# recall class 0 = 0.9748743718592965
# recall class 1 = 0.33715596330275227
# AUC of ROC = 0.8549373670449232
# AUC of PRC = 0.5302847580949498
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.4502297090352221
#
# Epoch 60 Batch 0: Train Loss = 0.2299
# Model Loss = 0.2289, Decov Loss = 0.0000
# Epoch 60 Batch 30: Train Loss = 0.2522
# Model Loss = 0.2504, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2856
# valid_model Loss = 0.2856
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2677  109]
#  [ 265  171]]
# accuracy = 0.8839230291744258
# precision class 0 = 0.9099252209381373
# precision class 1 = 0.6107142857142858
# recall class 0 = 0.960875807609476
# recall class 1 = 0.3922018348623853
# AUC of ROC = 0.8555432799646989
# AUC of PRC = 0.5460513683645377
# min(+P, Se) = 0.5296803652968036
# f1_score = 0.4776536312849162
#
# Epoch 61 Batch 0: Train Loss = 0.2682
# Model Loss = 0.2672, Decov Loss = 0.0000
# Epoch 61 Batch 30: Train Loss = 0.2612
# Model Loss = 0.2590, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2907
# valid_model Loss = 0.2907
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2702   84]
#  [ 282  154]]
# accuracy = 0.8864059590316573
# precision class 0 = 0.9054959785522788
# precision class 1 = 0.6470588235294118
# recall class 0 = 0.9698492462311558
# recall class 1 = 0.3532110091743119
# AUC of ROC = 0.8561590718994713
# AUC of PRC = 0.5294169430585289
# min(+P, Se) = 0.5240274599542334
# f1_score = 0.456973293768546
#
# Epoch 62 Batch 0: Train Loss = 0.2827
# Model Loss = 0.2817, Decov Loss = 0.0000
# Epoch 62 Batch 30: Train Loss = 0.2619
# Model Loss = 0.2602, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2824
# valid_model Loss = 0.2824
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2707   79]
#  [ 281  155]]
# accuracy = 0.888268156424581
# precision class 0 = 0.9059571619812584
# precision class 1 = 0.6623931623931624
# recall class 0 = 0.9716439339554918
# recall class 1 = 0.3555045871559633
# AUC of ROC = 0.8598571165131029
# AUC of PRC = 0.5549306474545788
# min(+P, Se) = 0.5389908256880734
# f1_score = 0.4626865671641791
#
#
# ------------ Save best model ------------
#
# Epoch 63 Batch 0: Train Loss = 0.2815
# Model Loss = 0.2803, Decov Loss = 0.0000
# Epoch 63 Batch 30: Train Loss = 0.2566
# Model Loss = 0.2550, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2887
# valid_model Loss = 0.2887
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2662  124]
#  [ 241  195]]
# accuracy = 0.8867163252638113
# precision class 0 = 0.9169824319669307
# precision class 1 = 0.6112852664576802
# recall class 0 = 0.955491744436468
# recall class 1 = 0.44724770642201833
# AUC of ROC = 0.8566258553580486
# AUC of PRC = 0.5343404559383798
# min(+P, Se) = 0.5258426966292135
# f1_score = 0.5165562913907285
#
# Epoch 64 Batch 0: Train Loss = 0.2877
# Model Loss = 0.2861, Decov Loss = 0.0000
# Epoch 64 Batch 30: Train Loss = 0.2622
# Model Loss = 0.2602, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2856
# valid_model Loss = 0.2856
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2698   88]
#  [ 275  161]]
# accuracy = 0.8873370577281192
# precision class 0 = 0.9075008409014463
# precision class 1 = 0.6465863453815262
# recall class 0 = 0.968413496051687
# recall class 1 = 0.36926605504587157
# AUC of ROC = 0.8583563294849081
# AUC of PRC = 0.5317020569504011
# min(+P, Se) = 0.5412844036697247
# f1_score = 0.47007299270073
#
# Epoch 65 Batch 0: Train Loss = 0.2560
# Model Loss = 0.2547, Decov Loss = 0.0000
# Epoch 65 Batch 30: Train Loss = 0.2496
# Model Loss = 0.2473, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2846
# valid_model Loss = 0.2846
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2662  124]
#  [ 268  168]]
# accuracy = 0.8783364369956549
# precision class 0 = 0.9085324232081912
# precision class 1 = 0.5753424657534246
# recall class 0 = 0.955491744436468
# recall class 1 = 0.3853211009174312
# AUC of ROC = 0.8587473738285136
# AUC of PRC = 0.5358666779879389
# min(+P, Se) = 0.5435779816513762
# f1_score = 0.4615384615384615
#
# Epoch 66 Batch 0: Train Loss = 0.1705
# Model Loss = 0.1690, Decov Loss = 0.0000
# Epoch 66 Batch 30: Train Loss = 0.2519
# Model Loss = 0.2496, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2848
# valid_model Loss = 0.2848
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2635  151]
#  [ 218  218]]
# accuracy = 0.8854748603351955
# precision class 0 = 0.9235892043463021
# precision class 1 = 0.5907859078590786
# recall class 0 = 0.9458004307250538
# recall class 1 = 0.5
# AUC of ROC = 0.8611652627488691
# AUC of PRC = 0.5459426553990099
# min(+P, Se) = 0.5412844036697247
# f1_score = 0.5416149068322982
#
#
# ------------ Save best model ------------
#
# Epoch 67 Batch 0: Train Loss = 0.2371
# Model Loss = 0.2355, Decov Loss = 0.0000
# Epoch 67 Batch 30: Train Loss = 0.2501
# Model Loss = 0.2486, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2889
# valid_model Loss = 0.2889
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2675  111]
#  [ 269  167]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.9086277173913043
# precision class 1 = 0.6007194244604317
# recall class 0 = 0.9601579325197416
# recall class 1 = 0.3830275229357798
# AUC of ROC = 0.8557392137621265
# AUC of PRC = 0.5270183758678846
# min(+P, Se) = 0.5298165137614679
# f1_score = 0.4677871148459384
#
# Epoch 68 Batch 0: Train Loss = 0.3234
# Model Loss = 0.3228, Decov Loss = 0.0000
# Epoch 68 Batch 30: Train Loss = 0.2482
# Model Loss = 0.2467, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2981
# valid_model Loss = 0.2981
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2745   41]
#  [ 333  103]]
# accuracy = 0.8839230291744258
# precision class 0 = 0.8918128654970761
# precision class 1 = 0.7152777777777778
# recall class 0 = 0.9852835606604451
# recall class 1 = 0.23623853211009174
# AUC of ROC = 0.8576203428676806
# AUC of PRC = 0.5220070088582168
# min(+P, Se) = 0.5354691075514875
# f1_score = 0.35517241379310344
#
# Epoch 69 Batch 0: Train Loss = 0.2835
# Model Loss = 0.2824, Decov Loss = 0.0000
# Epoch 69 Batch 30: Train Loss = 0.2526
# Model Loss = 0.2509, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2887
# valid_model Loss = 0.2887
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2681  105]
#  [ 266  170]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.9097387173396675
# precision class 1 = 0.6181818181818182
# recall class 0 = 0.9623115577889447
# recall class 1 = 0.38990825688073394
# AUC of ROC = 0.8549447763061704
# AUC of PRC = 0.5363245366537427
# min(+P, Se) = 0.5240274599542334
# f1_score = 0.4781997187060478
#
# Epoch 70 Batch 0: Train Loss = 0.2390
# Model Loss = 0.2373, Decov Loss = 0.0000
# Epoch 70 Batch 30: Train Loss = 0.2467
# Model Loss = 0.2450, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2895
# valid_model Loss = 0.2895
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2637  149]
#  [ 242  194]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.9159430357763112
# precision class 1 = 0.565597667638484
# recall class 0 = 0.9465183058147882
# recall class 1 = 0.44495412844036697
# AUC of ROC = 0.8569765603904187
# AUC of PRC = 0.5328571707534119
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.49807445442875486
#
# Epoch 71 Batch 0: Train Loss = 0.2162
# Model Loss = 0.2148, Decov Loss = 0.0000
# Epoch 71 Batch 30: Train Loss = 0.2506
# Model Loss = 0.2488, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2906
# valid_model Loss = 0.2906
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2722   64]
#  [ 307  129]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.8986464179597227
# precision class 1 = 0.6683937823834197
# recall class 0 = 0.9770279971284996
# recall class 1 = 0.2958715596330275
# AUC of ROC = 0.8558198923845965
# AUC of PRC = 0.5249249341914787
# min(+P, Se) = 0.5374149659863946
# f1_score = 0.4101748807631161
#
# Epoch 72 Batch 0: Train Loss = 0.2796
# Model Loss = 0.2777, Decov Loss = 0.0000
# Epoch 72 Batch 30: Train Loss = 0.2492
# Model Loss = 0.2477, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2806
# valid_model Loss = 0.2806
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2687   99]
#  [ 261  175]]
# accuracy = 0.888268156424581
# precision class 0 = 0.9114654002713705
# precision class 1 = 0.6386861313868614
# recall class 0 = 0.9644651830581479
# recall class 1 = 0.4013761467889908
# AUC of ROC = 0.8606235634265693
# AUC of PRC = 0.5490560071248661
# min(+P, Se) = 0.5321100917431193
# f1_score = 0.49295774647887325
#
# Epoch 73 Batch 0: Train Loss = 0.2575
# Model Loss = 0.2565, Decov Loss = 0.0000
# Epoch 73 Batch 30: Train Loss = 0.2437
# Model Loss = 0.2420, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3132
# valid_model Loss = 0.3131
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2529  257]
#  [ 182  254]]
# accuracy = 0.8637492240844196
# precision class 0 = 0.932866101069716
# precision class 1 = 0.49706457925636005
# recall class 0 = 0.9077530509691314
# recall class 1 = 0.5825688073394495
# AUC of ROC = 0.8581299353912419
# AUC of PRC = 0.5400300973246438
# min(+P, Se) = 0.540045766590389
# f1_score = 0.5364308342133052
#
# Epoch 74 Batch 0: Train Loss = 0.2897
# Model Loss = 0.2884, Decov Loss = 0.0000
# Epoch 74 Batch 30: Train Loss = 0.2492
# Model Loss = 0.2475, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2954
# valid_model Loss = 0.2954
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2603  183]
#  [ 221  215]]
# accuracy = 0.8746120422098076
# precision class 0 = 0.921742209631728
# precision class 1 = 0.5402010050251256
# recall class 0 = 0.9343144292893036
# recall class 1 = 0.49311926605504586
# AUC of ROC = 0.8597772611418824
# AUC of PRC = 0.5187610255412477
# min(+P, Se) = 0.5239179954441914
# f1_score = 0.5155875299760192
#
# Epoch 75 Batch 0: Train Loss = 0.2756
# Model Loss = 0.2738, Decov Loss = 0.0000
# Epoch 75 Batch 30: Train Loss = 0.2510
# Model Loss = 0.2494, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2892
# valid_model Loss = 0.2892
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2680  106]
#  [ 261  175]]
# accuracy = 0.8860955927995035
# precision class 0 = 0.9112546752805168
# precision class 1 = 0.6227758007117438
# recall class 0 = 0.9619526202440776
# recall class 1 = 0.4013761467889908
# AUC of ROC = 0.85983818173436
# AUC of PRC = 0.5269300909363572
# min(+P, Se) = 0.5331807780320366
# f1_score = 0.4881450488145049
#
# Epoch 76 Batch 0: Train Loss = 0.2222
# Model Loss = 0.2213, Decov Loss = 0.0000
# Epoch 76 Batch 30: Train Loss = 0.2437
# Model Loss = 0.2424, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2834
# valid_model Loss = 0.2834
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2671  115]
#  [ 255  181]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.9128503075871497
# precision class 1 = 0.6114864864864865
# recall class 0 = 0.9587221823402728
# recall class 1 = 0.4151376146788991
# AUC of ROC = 0.8598217167093659
# AUC of PRC = 0.5323368779524328
# min(+P, Se) = 0.5412844036697247
# f1_score = 0.4945355191256831
#
# Epoch 77 Batch 0: Train Loss = 0.2820
# Model Loss = 0.2808, Decov Loss = 0.0000
# Epoch 77 Batch 30: Train Loss = 0.2515
# Model Loss = 0.2499, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3034
# valid_model Loss = 0.3034
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2724   62]
#  [ 304  132]]
# accuracy = 0.8864059590316573
# precision class 0 = 0.8996036988110965
# precision class 1 = 0.6804123711340206
# recall class 0 = 0.9777458722182341
# recall class 1 = 0.30275229357798167
# AUC of ROC = 0.8546640476300243
# AUC of PRC = 0.5287188122293182
# min(+P, Se) = 0.5321100917431193
# f1_score = 0.4190476190476191
#
# Epoch 78 Batch 0: Train Loss = 0.2383
# Model Loss = 0.2371, Decov Loss = 0.0000
# Epoch 78 Batch 30: Train Loss = 0.2396
# Model Loss = 0.2380, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2888
# valid_model Loss = 0.2888
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2710   76]
#  [ 297  139]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9012304622547389
# precision class 1 = 0.6465116279069767
# recall class 0 = 0.9727207465900933
# recall class 1 = 0.31880733944954126
# AUC of ROC = 0.8527804487707211
# AUC of PRC = 0.5054194292217951
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.4270353302611367
#
# Epoch 79 Batch 0: Train Loss = 0.2256
# Model Loss = 0.2246, Decov Loss = 0.0000
# Epoch 79 Batch 30: Train Loss = 0.2473
# Model Loss = 0.2457, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2826
# valid_model Loss = 0.2825
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2701   85]
#  [ 284  152]]
# accuracy = 0.8854748603351955
# precision class 0 = 0.904857621440536
# precision class 1 = 0.6413502109704642
# recall class 0 = 0.9694903086862886
# recall class 1 = 0.3486238532110092
# AUC of ROC = 0.8602819141579457
# AUC of PRC = 0.5392406536887212
# min(+P, Se) = 0.5412844036697247
# f1_score = 0.4517087667161962
#
# Epoch 80 Batch 0: Train Loss = 0.2664
# Model Loss = 0.2650, Decov Loss = 0.0000
# Epoch 80 Batch 30: Train Loss = 0.2485
# Model Loss = 0.2468, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2921
# valid_model Loss = 0.2921
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2670  116]
#  [ 260  176]]
# accuracy = 0.883302296710118
# precision class 0 = 0.9112627986348123
# precision class 1 = 0.6027397260273972
# recall class 0 = 0.9583632447954056
# recall class 1 = 0.4036697247706422
# AUC of ROC = 0.8543306308738977
# AUC of PRC = 0.5164283404039551
# min(+P, Se) = 0.5344036697247706
# f1_score = 0.4835164835164835
#
# Epoch 81 Batch 0: Train Loss = 0.2808
# Model Loss = 0.2795, Decov Loss = 0.0000
# Epoch 81 Batch 30: Train Loss = 0.2545
# Model Loss = 0.2532, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2909
# valid_model Loss = 0.2909
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2650  136]
#  [ 242  194]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9163208852005532
# precision class 1 = 0.5878787878787879
# recall class 0 = 0.9511844938980617
# recall class 1 = 0.44495412844036697
# AUC of ROC = 0.8576853797164066
# AUC of PRC = 0.5305823769919932
# min(+P, Se) = 0.5389908256880734
# f1_score = 0.5065274151436031
#
# Epoch 82 Batch 0: Train Loss = 0.2205
# Model Loss = 0.2193, Decov Loss = 0.0000
# Epoch 82 Batch 30: Train Loss = 0.2394
# Model Loss = 0.2379, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2878
# valid_model Loss = 0.2878
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2688   98]
#  [ 267  169]]
# accuracy = 0.8867163252638113
# precision class 0 = 0.9096446700507614
# precision class 1 = 0.6329588014981273
# recall class 0 = 0.964824120603015
# recall class 1 = 0.3876146788990826
# AUC of ROC = 0.8576647984351641
# AUC of PRC = 0.523097127620969
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.48079658605974396
#
# Epoch 83 Batch 0: Train Loss = 0.2592
# Model Loss = 0.2582, Decov Loss = 0.0000
# Epoch 83 Batch 30: Train Loss = 0.2396
# Model Loss = 0.2384, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2870
# valid_model Loss = 0.2870
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2699   87]
#  [ 274  162]]
# accuracy = 0.887957790192427
# precision class 0 = 0.9078372014799866
# precision class 1 = 0.6506024096385542
# recall class 0 = 0.9687724335965542
# recall class 1 = 0.37155963302752293
# AUC of ROC = 0.8550863755211181
# AUC of PRC = 0.5253564407552266
# min(+P, Se) = 0.5344036697247706
# f1_score = 0.472992700729927
#
# Epoch 84 Batch 0: Train Loss = 0.2612
# Model Loss = 0.2602, Decov Loss = 0.0000
# Epoch 84 Batch 30: Train Loss = 0.2450
# Model Loss = 0.2437, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2940
# valid_model Loss = 0.2940
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2675  111]
#  [ 262  174]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9107933265236636
# precision class 1 = 0.6105263157894737
# recall class 0 = 0.9601579325197416
# recall class 1 = 0.39908256880733944
# AUC of ROC = 0.8545808992538051
# AUC of PRC = 0.5233945358812652
# min(+P, Se) = 0.5308924485125858
# f1_score = 0.48266296809986126
#
# Epoch 85 Batch 0: Train Loss = 0.2253
# Model Loss = 0.2231, Decov Loss = 0.0000
# Epoch 85 Batch 30: Train Loss = 0.2397
# Model Loss = 0.2384, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2899
# valid_model Loss = 0.2899
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2681  105]
#  [ 269  167]]
# accuracy = 0.8839230291744258
# precision class 0 = 0.9088135593220339
# precision class 1 = 0.6139705882352942
# recall class 0 = 0.9623115577889447
# recall class 1 = 0.3830275229357798
# AUC of ROC = 0.855083905767369
# AUC of PRC = 0.5067932978198416
# min(+P, Se) = 0.5298165137614679
# f1_score = 0.4717514124293785
#
# Epoch 86 Batch 0: Train Loss = 0.2334
# Model Loss = 0.2327, Decov Loss = 0.0000
# Epoch 86 Batch 30: Train Loss = 0.2376
# Model Loss = 0.2366, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2995
# valid_model Loss = 0.2994
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2632  154]
#  [ 239  197]]
# accuracy = 0.8780260707635009
# precision class 0 = 0.9167537443399513
# precision class 1 = 0.5612535612535613
# recall class 0 = 0.9447236180904522
# recall class 1 = 0.4518348623853211
# AUC of ROC = 0.8503954899003537
# AUC of PRC = 0.5157242423593583
# min(+P, Se) = 0.5233853006681515
# f1_score = 0.5006353240152478
#
# Epoch 87 Batch 0: Train Loss = 0.2396
# Model Loss = 0.2388, Decov Loss = 0.0000
# Epoch 87 Batch 30: Train Loss = 0.2394
# Model Loss = 0.2383, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2891
# valid_model Loss = 0.2891
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2688   98]
#  [ 276  160]]
# accuracy = 0.8839230291744258
# precision class 0 = 0.9068825910931174
# precision class 1 = 0.6201550387596899
# recall class 0 = 0.964824120603015
# recall class 1 = 0.3669724770642202
# AUC of ROC = 0.8556173725771716
# AUC of PRC = 0.5243370202962742
# min(+P, Se) = 0.5344036697247706
# f1_score = 0.46109510086455335
#
# Epoch 88 Batch 0: Train Loss = 0.2347
# Model Loss = 0.2335, Decov Loss = 0.0000
# Epoch 88 Batch 30: Train Loss = 0.2376
# Model Loss = 0.2367, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2977
# valid_model Loss = 0.2977
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2690   96]
#  [ 279  157]]
# accuracy = 0.8836126629422719
# precision class 0 = 0.906028965981812
# precision class 1 = 0.6205533596837944
# recall class 0 = 0.9655419956927495
# recall class 1 = 0.36009174311926606
# AUC of ROC = 0.8515719159361684
# AUC of PRC = 0.5309545976974448
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.45573294629898403
#
# Epoch 89 Batch 0: Train Loss = 0.2276
# Model Loss = 0.2269, Decov Loss = 0.0000
# Epoch 89 Batch 30: Train Loss = 0.2361
# Model Loss = 0.2349, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3004
# valid_model Loss = 0.3004
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2623  163]
#  [ 224  212]]
# accuracy = 0.8798882681564246
# precision class 0 = 0.9213206884439761
# precision class 1 = 0.5653333333333334
# recall class 0 = 0.9414931801866475
# recall class 1 = 0.48623853211009177
# AUC of ROC = 0.8542441894926798
# AUC of PRC = 0.5291084302010123
# min(+P, Se) = 0.5251141552511416
# f1_score = 0.5228113440197287
#
# Epoch 90 Batch 0: Train Loss = 0.2640
# Model Loss = 0.2620, Decov Loss = 0.0000
# Epoch 90 Batch 30: Train Loss = 0.2375
# Model Loss = 0.2362, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2895
# valid_model Loss = 0.2895
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2657  129]
#  [ 253  183]]
# accuracy = 0.8814400993171942
# precision class 0 = 0.9130584192439862
# precision class 1 = 0.5865384615384616
# recall class 0 = 0.9536970567121321
# recall class 1 = 0.4197247706422018
# AUC of ROC = 0.8572383542878218
# AUC of PRC = 0.5332700752447994
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.48930481283422467
#
# Epoch 91 Batch 0: Train Loss = 0.1764
# Model Loss = 0.1756, Decov Loss = 0.0000
# Epoch 91 Batch 30: Train Loss = 0.2376
# Model Loss = 0.2362, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2856
# valid_model Loss = 0.2856
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2682  104]
#  [ 268  168]]
# accuracy = 0.8845437616387337
# precision class 0 = 0.9091525423728813
# precision class 1 = 0.6176470588235294
# recall class 0 = 0.9626704953338119
# recall class 1 = 0.3853211009174312
# AUC of ROC = 0.8561574253969718
# AUC of PRC = 0.5242381432551061
# min(+P, Se) = 0.5344036697247706
# f1_score = 0.47457627118644075
#
# Epoch 92 Batch 0: Train Loss = 0.1959
# Model Loss = 0.1951, Decov Loss = 0.0000
# Epoch 92 Batch 30: Train Loss = 0.2385
# Model Loss = 0.2375, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2890
# valid_model Loss = 0.2890
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2694   92]
#  [ 270  166]]
# accuracy = 0.8876474239602731
# precision class 0 = 0.9089068825910931
# precision class 1 = 0.6434108527131783
# recall class 0 = 0.9669777458722182
# recall class 1 = 0.38073394495412843
# AUC of ROC = 0.8534571612979707
# AUC of PRC = 0.5178525256581832
# min(+P, Se) = 0.5344036697247706
# f1_score = 0.478386167146974
#
# Epoch 93 Batch 0: Train Loss = 0.2205
# Model Loss = 0.2199, Decov Loss = 0.0000
# Epoch 93 Batch 30: Train Loss = 0.2390
# Model Loss = 0.2380, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2852
# valid_model Loss = 0.2852
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2729   57]
#  [ 312  124]]
# accuracy = 0.8854748603351955
# precision class 0 = 0.8974021703387044
# precision class 1 = 0.6850828729281768
# recall class 0 = 0.9795405599425699
# recall class 1 = 0.28440366972477066
# AUC of ROC = 0.8550806127623701
# AUC of PRC = 0.5256996957918
# min(+P, Se) = 0.5194508009153318
# f1_score = 0.4019448946515397
#
# Epoch 94 Batch 0: Train Loss = 0.3057
# Model Loss = 0.3048, Decov Loss = 0.0000
# Epoch 94 Batch 30: Train Loss = 0.2505
# Model Loss = 0.2493, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2941
# valid_model Loss = 0.2941
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2661  125]
#  [ 260  176]]
# accuracy = 0.8805090006207325
# precision class 0 = 0.9109893871961657
# precision class 1 = 0.584717607973422
# recall class 0 = 0.9551328068916008
# recall class 1 = 0.4036697247706422
# AUC of ROC = 0.857700198238901
# AUC of PRC = 0.5321501772921422
# min(+P, Se) = 0.5240274599542334
# f1_score = 0.4776119402985075
#
# Epoch 95 Batch 0: Train Loss = 0.1651
# Model Loss = 0.1643, Decov Loss = 0.0000
# Epoch 95 Batch 30: Train Loss = 0.2318
# Model Loss = 0.2304, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2960
# valid_model Loss = 0.2960
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2611  175]
#  [ 221  215]]
# accuracy = 0.8770949720670391
# precision class 0 = 0.9219632768361582
# precision class 1 = 0.5512820512820513
# recall class 0 = 0.9371859296482412
# recall class 1 = 0.49311926605504586
# AUC of ROC = 0.8568934120141994
# AUC of PRC = 0.5415162402416579
# min(+P, Se) = 0.5298165137614679
# f1_score = 0.5205811138014528
#
# Epoch 96 Batch 0: Train Loss = 0.2057
# Model Loss = 0.2048, Decov Loss = 0.0000
# Epoch 96 Batch 30: Train Loss = 0.2340
# Model Loss = 0.2329, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2854
# valid_model Loss = 0.2854
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2711   75]
#  [ 286  150]]
# accuracy = 0.887957790192427
# precision class 0 = 0.9045712379045713
# precision class 1 = 0.6666666666666666
# recall class 0 = 0.9730796841349605
# recall class 1 = 0.3440366972477064
# AUC of ROC = 0.8630809684069101
# AUC of PRC = 0.5523889315171073
# min(+P, Se) = 0.5481651376146789
# f1_score = 0.45385779122541603
#
#
# ------------ Save best model ------------
#
# Epoch 97 Batch 0: Train Loss = 0.2543
# Model Loss = 0.2534, Decov Loss = 0.0000
# Epoch 97 Batch 30: Train Loss = 0.2255
# Model Loss = 0.2245, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2940
# valid_model Loss = 0.2940
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2645  141]
#  [ 248  188]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.9142758382302109
# precision class 1 = 0.5714285714285714
# recall class 0 = 0.9493898061737258
# recall class 1 = 0.43119266055045874
# AUC of ROC = 0.8549505390649184
# AUC of PRC = 0.5373834204406434
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.4915032679738562
#
# Epoch 98 Batch 0: Train Loss = 0.2341
# Model Loss = 0.2335, Decov Loss = 0.0000
# Epoch 98 Batch 30: Train Loss = 0.2315
# Model Loss = 0.2305, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2937
# valid_model Loss = 0.2937
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2681  105]
#  [ 278  158]]
# accuracy = 0.8811297330850404
# precision class 0 = 0.9060493409935789
# precision class 1 = 0.6007604562737643
# recall class 0 = 0.9623115577889447
# recall class 1 = 0.3623853211009174
# AUC of ROC = 0.8521844148659417
# AUC of PRC = 0.5168377046439941
# min(+P, Se) = 0.518348623853211
# f1_score = 0.4520743919885551
#
# Epoch 99 Batch 0: Train Loss = 0.2467
# Model Loss = 0.2460, Decov Loss = 0.0000
# Epoch 99 Batch 30: Train Loss = 0.2261
# Model Loss = 0.2253, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2925
# valid_model Loss = 0.2925
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2692   94]
#  [ 287  149]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.9036589459550185
# precision class 1 = 0.6131687242798354
# recall class 0 = 0.9662598707824839
# recall class 1 = 0.34174311926605505
# AUC of ROC = 0.8532340602093034
# AUC of PRC = 0.5209216659489412
# min(+P, Se) = 0.5091743119266054
# f1_score = 0.43888070692194403

# %% [markdown]
# ### Run for test

# %%
checkpoint = torch.load(file_name)
save_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['net'])
optimizer.load_state_dict(checkpoint['optimizer'])
model.eval()

test_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'test'),
                                            listfile=os.path.join(data_path, 'test_listfile.csv'),
                                            period_length=48.0)
test_raw = utils.load_data(test_reader, discretizer, normalizer, small_part, return_names=True)
test_dataset = Dataset(test_raw['data'][0], test_raw['data'][1], test_raw['names'])
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
batch_loss = []
y_true = []
y_pred = []

with torch.no_grad():
    model.eval()
    for step, (batch_x, batch_y, batch_name) in enumerate(test_loader):
        batch_x = batch_x.float().to(device)
        batch_y = batch_y.float().to(device)

        # O(1) demographic lookup using the same key scheme as train/valid
        batch_demo = [demo_map[f"{bn.split('_', 2)[0]}_{bn.split('_', 2)[1]}"] for bn in batch_name]
        batch_demo = torch.stack(batch_demo).to(device)

        # If model returns (logits, decov_loss)
        output, _ = model(batch_x, batch_demo)

        loss = get_loss(output, batch_y.unsqueeze(-1))
        batch_loss.append(loss.item())

        # If get_loss uses BCEWithLogitsLoss, convert logits -> probs for metrics
        probs = output.detach().cpu().numpy().flatten()
        y_pred.extend(probs)
        y_true.extend(batch_y.cpu().numpy().flatten())

print("\n==>Predicting on test")
print('Test Loss = %.4f' % (np.mean(np.array(batch_loss))))

y_pred = np.array(y_pred)                                   # positive-class probs in [0, 1]
y_pred_prob = np.stack([1.0 - y_pred, y_pred], axis=1)      # shape (N, 2) = [P0, P1]
test_res = metrics.print_metrics_binary(y_true, y_pred_prob)
# Out:
# ==>Predicting on test
# Test Loss = 0.2806
# confusion matrix:
# [[2799   63]
#  [ 259  115]]
# accuracy = 0.9004944375772559
# precision class 0 = 0.9153041203400916
# precision class 1 = 0.6460674157303371
# recall class 0 = 0.9779874213836478
# recall class 1 = 0.3074866310160428
# AUC of ROC = 0.840879195207719
# AUC of PRC = 0.47489169946328347
# min(+P, Se) = 0.48812664907651715
# f1_score = 0.4166666666666667

# %%
# Bootstrap evaluation
y_true_arr = np.asarray(y_true, dtype=int)
y_pred_arr = np.asarray(y_pred_prob, dtype=float)   # 1D positive-class probabilities

N = len(y_true_arr)
N_idx = np.arange(N)
K = 1000

auroc = []
auprc = []
minpse = []
for i in range(K):
    boot_idx = np.random.choice(N_idx, N, replace=True)
    boot_true = y_true_arr[boot_idx]
    boot_pred = y_pred_arr[boot_idx, :]  # 1D slice is correct

    test_ret = metrics.print_metrics_binary(boot_true, boot_pred, verbose=0)
    auroc.append(test_ret["auroc"])
    auprc.append(test_ret["auprc"])
    minpse.append(test_ret["minpse"])

    if (i + 1) % 50 == 0:
        print(f"{i+1}/{K}")

print("auroc %.4f(%.4f)" % (np.mean(auroc), np.std(auroc)))
print("auprc %.4f(%.4f)" % (np.mean(auprc), np.std(auprc)))
print("minpse %.4f(%.4f)" % (np.mean(minpse), np.std(minpse)))
# Out:
# 50/1000
# 100/1000
# 150/1000
# 200/1000
# 250/1000
# 300/1000
# 350/1000
# 400/1000
# 450/1000
# 500/1000
# 550/1000
# 600/1000
# 650/1000
# 700/1000
# 750/1000
# 800/1000
# 850/1000
# 900/1000
# 950/1000
# 1000/1000
# auroc 0.8416(0.0105)
# auprc 0.4788(0.0283)
# minpse 0.4876(0.0220)
