# %%
# Use external ConCare architecture from the uploaded file
import sys, os
sys.path.append('/mnt/data')  # Ensure the uploaded model file is importable
from ConCare_Model_v3 import ConCare  # noqa: F401
print('Imported ConCare from ConCare_Model_v2.py successfully')
# Out:
# Imported ConCare from ConCare_Model_v2.py successfully

# %%
# Quick sanity check of ConCare signature
try:
    _sig = ConCare.__init__.__code__.co_varnames
    print('ConCare init args:', _sig)
except Exception as e:
    print('Warning reading ConCare signature:', e)
# Out:
# ConCare init args: ('self', 'input_dim', 'hidden_dim', 'd_model', 'MHD_num_head', 'd_ff', 'output_dim', 'keep_prob', 'demographic_dim')

# %%
import numpy as np
import argparse
import os
import importlib
import re
import pickle
import datetime
import random
import math
import copy


import torch
from torch import nn
import torch.nn.utils.rnn as rnn_utils
from torch.utils import data
from torch.autograd import Variable
import torch.nn.functional as F


from utils import utils
from utils.readers import InHospitalMortalityReader
from utils.preprocessing import Discretizer, Normalizer
from utils import metrics
from utils import common_utils

# %%
# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Prepare

# %%
data_path = './data/'
file_name = './model/concare_v1'
small_part = False
arg_timestep = 1.0
batch_size = 256
epochs = 100

# %%
# Build readers, discretizers, normalizers
train_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'train'),
                                         listfile=os.path.join(data_path, 'train_listfile.csv'),
                                         period_length=48.0)

val_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'train'),
                                       listfile=os.path.join(data_path, 'val_listfile.csv'),
                                       period_length=48.0)

discretizer = Discretizer(timestep=arg_timestep,
                          store_masks=True,
                          impute_strategy='previous',
                          start_time='zero')

# %%
discretizer_header = discretizer.transform(train_reader.read_example(0)["X"])[1].split(',')
cont_channels = [i for (i, x) in enumerate(discretizer_header) if x.find("->") == -1]

normalizer = Normalizer(fields=cont_channels)  # choose here which columns to standardize
normalizer_state = 'ihm_normalizer'
normalizer_state = os.path.join(os.path.dirname(data_path), normalizer_state)
normalizer.load_params(normalizer_state)

# %%
n_trained_chunks = 0
train_raw = utils.load_data(train_reader, discretizer, normalizer, small_part, return_names=True)
val_raw = utils.load_data(val_reader, discretizer, normalizer, small_part, return_names=True)

# %%
demographic_data = []
diagnosis_data = []
idx_list = []

demo_path = data_path + 'demographic/'
for cur_name in os.listdir(demo_path):
    cur_id, cur_episode = cur_name.split('_', 1)
    cur_episode = cur_episode[:-4]
    cur_file = demo_path + cur_name

    with open(cur_file, "r") as tsfile:
        header = tsfile.readline().strip().split(',')
        if header[0] != "Icustay":
            continue
        cur_data = tsfile.readline().strip().split(',')
        
    if len(cur_data) == 1:
        cur_demo = np.zeros(12)
        cur_diag = np.zeros(128)
    else:
        if cur_data[3] == '':
            cur_data[3] = 60.0
        if cur_data[4] == '':
            cur_data[4] = 160
        if cur_data[5] == '':
            cur_data[5] = 60

        cur_demo = np.zeros(12)
        cur_demo[int(cur_data[1])] = 1
        cur_demo[5 + int(cur_data[2])] = 1
        cur_demo[9:] = cur_data[3:6]
        cur_diag = np.array(cur_data[8:], dtype=int)

    demographic_data.append(cur_demo)
    diagnosis_data.append(cur_diag)
    idx_list.append(cur_id+'_'+cur_episode)

for each_idx in range(9,12):
    cur_val = []
    for i in range(len(demographic_data)):
        cur_val.append(demographic_data[i][each_idx])
    cur_val = np.array(cur_val)
    _mean = np.mean(cur_val)
    _std = np.std(cur_val)
    _std = _std if _std > 1e-7 else 1e-7
    for i in range(len(demographic_data)):
        demographic_data[i][each_idx] = (demographic_data[i][each_idx] - _mean) / _std

# %% [markdown]
# ### model

# %%
def get_loss(y_pred, y_true):
    loss = torch.nn.BCELoss()
    return loss(y_pred, y_true)

# %%
class Dataset(data.Dataset):
    def __init__(self, x, y, name):
        self.x = x
        self.y = y
        self.name = name

    def __getitem__(self, index):#返回的是tensor
        return self.x[index], self.y[index], self.name[index]

    def __len__(self):
        return len(self.x)

# %%
train_dataset = Dataset(train_raw['data'][0], train_raw['data'][1], train_raw['names'])
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_dataset = Dataset(val_raw['data'][0], val_raw['data'][1], val_raw['names'])
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Run

# %%
try:
    DEM_DIM = len(demographic_data[0])
except Exception:
    DEM_DIM = 12  # fallback; adjust if your demographics vector has a different size

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)  # numpy
random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)  # cpu
torch.cuda.manual_seed(RANDOM_SEED)  # gpu
torch.backends.cudnn.deterministic = True  # cudnn


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = ConCare(input_dim=76, hidden_dim=64, d_model=64, MHD_num_head=4, d_ff=256, output_dim=1, keep_prob=0.8, demographic_dim=DEM_DIM).to(device)
# input_dim, d_model, d_k, d_v, MHD_num_head, d_ff, output_dim
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

max_roc = 0
max_prc = 0
train_loss = []
train_model_loss = []
train_decov_loss = []
valid_loss = []
valid_model_loss = []
valid_decov_loss = []
history = []
np.set_printoptions(threshold=np.inf)
np.set_printoptions(precision=2)
np.set_printoptions(suppress=True)

# Build once for O(1) demographic lookup
demo_map = {idx_list[i]: torch.tensor(demographic_data[i], dtype=torch.float32) for i in range(len(idx_list))}

for each_epoch in range(100):
    batch_loss = []
    model_batch_loss = []
    decov_batch_loss = []

    model.train()

    for step, (batch_x, batch_y, batch_name) in enumerate(train_loader):
        optimizer.zero_grad()
        batch_x = batch_x.float().to(device)
        batch_y = batch_y.float().to(device)

        # Fast demographic batch build
        batch_demo = [demo_map[f"{batch_name[i].split('_', 2)[0]}_{batch_name[i].split('_', 2)[1]}"] for i in range(len(batch_name))]
        batch_demo = torch.stack(batch_demo).to(device)

        output, decov_loss = model(batch_x, batch_demo)

        model_loss = get_loss(output, batch_y.unsqueeze(-1))
        loss = model_loss + 800 * decov_loss

        batch_loss.append(loss.item())
        model_batch_loss.append(model_loss.item())
        decov_batch_loss.append(decov_loss.item())
        loss.backward()
        optimizer.step()

        if step % 30 == 0:
            print('Epoch %d Batch %d: Train Loss = %.4f' % (each_epoch, step, np.mean(np.array(batch_loss))))
            print('Model Loss = %.4f, Decov Loss = %.4f' % (np.mean(np.array(model_batch_loss)), np.mean(np.array(decov_batch_loss))))
    train_loss.append(np.mean(np.array(batch_loss)))
    train_model_loss.append(np.mean(np.array(model_batch_loss)))
    train_decov_loss.append(np.mean(np.array(decov_batch_loss)))

    batch_loss = []
    model_batch_loss = []
    decov_batch_loss = []

    y_true = []
    y_pred = []
    with torch.no_grad():
        model.eval()
        for step, (batch_x, batch_y, batch_name) in enumerate(valid_loader):
            batch_x = batch_x.float().to(device)
            batch_y = batch_y.float().to(device)

            # Fast demographic batch build
            batch_demo = [demo_map[f"{batch_name[i].split('_', 2)[0]}_{batch_name[i].split('_', 2)[1]}"] for i in range(len(batch_name))]
            batch_demo = torch.stack(batch_demo).to(device)

            output, decov_loss = model(batch_x, batch_demo)

            model_loss = get_loss(output, batch_y.unsqueeze(-1))

            loss = model_loss + 10 * decov_loss
            batch_loss.append(loss.item())
            model_batch_loss.append(model_loss.item())
            decov_batch_loss.append(decov_loss.item())
            y_pred += list(output.cpu().detach().numpy().flatten())
            y_true += list(batch_y.cpu().numpy().flatten())

    valid_loss.append(np.mean(np.array(batch_loss)))
    valid_model_loss.append(np.mean(np.array(model_batch_loss)))
    valid_decov_loss.append(np.mean(np.array(decov_batch_loss)))

    print("\n==>Predicting on validation")
    print('Valid Loss = %.4f' % (valid_loss[-1]))
    print('valid_model Loss = %.4f' % (valid_model_loss[-1]))
    print('valid_decov Loss = %.4f' % (valid_decov_loss[-1]))
    y_pred = np.array(y_pred)
    y_pred = np.stack([1 - y_pred, y_pred], axis=1)
    ret = metrics.print_metrics_binary(y_true, y_pred)
    history.append(ret)
    print()

    cur_auroc = ret['auroc']

    if cur_auroc > max_roc:
        max_roc = cur_auroc
        state = {
            'net': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'epoch': each_epoch
        }
        # Ensure parent directory exists before saving
        import os
        os.makedirs(os.path.dirname(file_name), exist_ok=True)
        torch.save(state, file_name)
        print('\n------------ Save best model ------------\n')
# Out:
# Using device: cuda
# Epoch 0 Batch 0: Train Loss = 0.6620
# Model Loss = 0.6611, Decov Loss = 0.0000
# Epoch 0 Batch 30: Train Loss = 0.4856
# Model Loss = 0.4839, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3900
# valid_model Loss = 0.3900
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2786    0]
#  [ 436    0]]
# accuracy = 0.8646803227808815
# precision class 0 = 0.8646803227808815
# precision class 1 = 0.0
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.6510995343690932
# AUC of PRC = 0.2244916866896534
# min(+P, Se) = 0.26280623608017817
# f1_score = 0.0
#
#
# ------------ Save best model ------------
#
# Epoch 1 Batch 0: Train Loss = 0.3936
# Model Loss = 0.3930, Decov Loss = 0.0000
# Epoch 1 Batch 30: Train Loss = 0.3889
# Model Loss = 0.3884, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3396
# valid_model Loss = 0.3396
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2786    0]
#  [ 436    0]]
# accuracy = 0.8646803227808815
# precision class 0 = 0.8646803227808815
# precision class 1 = 0.0
# recall class 0 = 1.0
# recall class 1 = 0.0
# AUC of ROC = 0.7694246132365629
# AUC of PRC = 0.3849795156490996
# min(+P, Se) = 0.3894736842105263
# f1_score = 0.0
#
#
# ------------ Save best model ------------
#
# Epoch 2 Batch 0: Train Loss = 0.3906
# Model Loss = 0.3902, Decov Loss = 0.0000
# Epoch 2 Batch 30: Train Loss = 0.3565
# Model Loss = 0.3561, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3498
# valid_model Loss = 0.3498
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2746   40]
#  [ 384   52]]
# accuracy = 0.8684047175667288
# precision class 0 = 0.8773162939297124
# precision class 1 = 0.5652173913043478
# recall class 0 = 0.9856424982053122
# recall class 1 = 0.11926605504587157
# AUC of ROC = 0.7656088436942248
# AUC of PRC = 0.3677194051739112
# min(+P, Se) = 0.3761261261261261
# f1_score = 0.19696969696969696
#
# Epoch 3 Batch 0: Train Loss = 0.3812
# Model Loss = 0.3810, Decov Loss = 0.0000
# Epoch 3 Batch 30: Train Loss = 0.3474
# Model Loss = 0.3472, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3327
# valid_model Loss = 0.3327
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2743   43]
#  [ 376   60]]
# accuracy = 0.8699565487274985
# precision class 0 = 0.8794485411991023
# precision class 1 = 0.5825242718446602
# recall class 0 = 0.9845656855707107
# recall class 1 = 0.13761467889908258
# AUC of ROC = 0.7800503171163814
# AUC of PRC = 0.3911136255765294
# min(+P, Se) = 0.41002277904328016
# f1_score = 0.22263450834879406
#
#
# ------------ Save best model ------------
#
# Epoch 4 Batch 0: Train Loss = 0.3352
# Model Loss = 0.3350, Decov Loss = 0.0000
# Epoch 4 Batch 30: Train Loss = 0.3475
# Model Loss = 0.3473, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3335
# valid_model Loss = 0.3335
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2713   73]
#  [ 355   81]]
# accuracy = 0.867163252638113
# precision class 0 = 0.8842894393741851
# precision class 1 = 0.525974025974026
# recall class 0 = 0.9737975592246949
# recall class 1 = 0.18577981651376146
# AUC of ROC = 0.7830469516652727
# AUC of PRC = 0.39504539281134865
# min(+P, Se) = 0.41743119266055045
# f1_score = 0.2745762711864407
#
#
# ------------ Save best model ------------
#
# Epoch 5 Batch 0: Train Loss = 0.3299
# Model Loss = 0.3297, Decov Loss = 0.0000
# Epoch 5 Batch 30: Train Loss = 0.3394
# Model Loss = 0.3393, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3256
# valid_model Loss = 0.3256
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2737   49]
#  [ 375   61]]
# accuracy = 0.8684047175667288
# precision class 0 = 0.8794987146529563
# precision class 1 = 0.5545454545454546
# recall class 0 = 0.9824120603015075
# recall class 1 = 0.13990825688073394
# AUC of ROC = 0.7897704446215349
# AUC of PRC = 0.4047889006465318
# min(+P, Se) = 0.4327354260089686
# f1_score = 0.22344322344322345
#
#
# ------------ Save best model ------------
#
# Epoch 6 Batch 0: Train Loss = 0.2708
# Model Loss = 0.2707, Decov Loss = 0.0000
# Epoch 6 Batch 30: Train Loss = 0.3333
# Model Loss = 0.3331, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3213
# valid_model Loss = 0.3213
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2729   57]
#  [ 358   78]]
# accuracy = 0.8711980136561143
# precision class 0 = 0.8840298023971493
# precision class 1 = 0.5777777777777777
# recall class 0 = 0.9795405599425699
# recall class 1 = 0.17889908256880735
# AUC of ROC = 0.7993078103492561
# AUC of PRC = 0.41712239457553213
# min(+P, Se) = 0.4406392694063927
# f1_score = 0.27320490367775835
#
#
# ------------ Save best model ------------
#
# Epoch 7 Batch 0: Train Loss = 0.3117
# Model Loss = 0.3115, Decov Loss = 0.0000
# Epoch 7 Batch 30: Train Loss = 0.3325
# Model Loss = 0.3323, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3200
# valid_model Loss = 0.3200
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2702   84]
#  [ 341   95]]
# accuracy = 0.8680943513345748
# precision class 0 = 0.8879395333552416
# precision class 1 = 0.5307262569832403
# recall class 0 = 0.9698492462311558
# recall class 1 = 0.21788990825688073
# AUC of ROC = 0.804067025823745
# AUC of PRC = 0.4195736508627436
# min(+P, Se) = 0.44130434782608696
# f1_score = 0.3089430894308943
#
#
# ------------ Save best model ------------
#
# Epoch 8 Batch 0: Train Loss = 0.3048
# Model Loss = 0.3046, Decov Loss = 0.0000
# Epoch 8 Batch 30: Train Loss = 0.3239
# Model Loss = 0.3237, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3130
# valid_model Loss = 0.3130
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2729   57]
#  [ 357   79]]
# accuracy = 0.8715083798882681
# precision class 0 = 0.8843162670123137
# precision class 1 = 0.5808823529411765
# recall class 0 = 0.9795405599425699
# recall class 1 = 0.1811926605504587
# AUC of ROC = 0.8138612459413712
# AUC of PRC = 0.44180529036508165
# min(+P, Se) = 0.4840182648401826
# f1_score = 0.27622377622377625
#
#
# ------------ Save best model ------------
#
# Epoch 9 Batch 0: Train Loss = 0.2979
# Model Loss = 0.2976, Decov Loss = 0.0000
# Epoch 9 Batch 30: Train Loss = 0.3191
# Model Loss = 0.3187, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3126
# valid_model Loss = 0.3126
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2782    4]
#  [ 422   14]]
# accuracy = 0.8677839851024208
# precision class 0 = 0.8682896379525593
# precision class 1 = 0.7777777777777778
# recall class 0 = 0.9985642498205313
# recall class 1 = 0.03211009174311927
# AUC of ROC = 0.8156246501182189
# AUC of PRC = 0.45451378921243
# min(+P, Se) = 0.46559633027522934
# f1_score = 0.06167400881057269
#
#
# ------------ Save best model ------------
#
# Epoch 10 Batch 0: Train Loss = 0.3044
# Model Loss = 0.3039, Decov Loss = 0.0000
# Epoch 10 Batch 30: Train Loss = 0.3245
# Model Loss = 0.3240, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3078
# valid_model Loss = 0.3078
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2741   45]
#  [ 371   65]]
# accuracy = 0.8708876474239603
# precision class 0 = 0.8807840616966581
# precision class 1 = 0.5909090909090909
# recall class 0 = 0.9838478104809764
# recall class 1 = 0.14908256880733944
# AUC of ROC = 0.8229425304767611
# AUC of PRC = 0.4528754733240223
# min(+P, Se) = 0.4701834862385321
# f1_score = 0.23809523809523808
#
#
# ------------ Save best model ------------
#
# Epoch 11 Batch 0: Train Loss = 0.3670
# Model Loss = 0.3667, Decov Loss = 0.0000
# Epoch 11 Batch 30: Train Loss = 0.3114
# Model Loss = 0.3109, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3075
# valid_model Loss = 0.3075
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2724   62]
#  [ 349   87]]
# accuracy = 0.87243947858473
# precision class 0 = 0.8864301985030915
# precision class 1 = 0.5838926174496645
# recall class 0 = 0.9777458722182341
# recall class 1 = 0.19954128440366972
# AUC of ROC = 0.8230182695917332
# AUC of PRC = 0.44698845742652893
# min(+P, Se) = 0.46255506607929514
# f1_score = 0.29743589743589743
#
#
# ------------ Save best model ------------
#
# Epoch 12 Batch 0: Train Loss = 0.3681
# Model Loss = 0.3676, Decov Loss = 0.0000
# Epoch 12 Batch 30: Train Loss = 0.3205
# Model Loss = 0.3199, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3052
# valid_model Loss = 0.3052
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2719   67]
#  [ 341   95]]
# accuracy = 0.8733705772811918
# precision class 0 = 0.8885620915032679
# precision class 1 = 0.5864197530864198
# recall class 0 = 0.9759511844938981
# recall class 1 = 0.21788990825688073
# AUC of ROC = 0.8254196934870947
# AUC of PRC = 0.45358581167754164
# min(+P, Se) = 0.4701834862385321
# f1_score = 0.3177257525083612
#
#
# ------------ Save best model ------------
#
# Epoch 13 Batch 0: Train Loss = 0.3131
# Model Loss = 0.3126, Decov Loss = 0.0000
# Epoch 13 Batch 30: Train Loss = 0.3120
# Model Loss = 0.3113, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3076
# valid_model Loss = 0.3076
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2738   48]
#  [ 355   81]]
# accuracy = 0.8749224084419616
# precision class 0 = 0.8852247009376011
# precision class 1 = 0.627906976744186
# recall class 0 = 0.9827709978463748
# recall class 1 = 0.18577981651376146
# AUC of ROC = 0.8307156687763854
# AUC of PRC = 0.4664684745959453
# min(+P, Se) = 0.4805491990846682
# f1_score = 0.2867256637168142
#
#
# ------------ Save best model ------------
#
# Epoch 14 Batch 0: Train Loss = 0.4176
# Model Loss = 0.4172, Decov Loss = 0.0000
# Epoch 14 Batch 30: Train Loss = 0.3049
# Model Loss = 0.3044, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3039
# valid_model Loss = 0.3039
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2719   67]
#  [ 338   98]]
# accuracy = 0.8743016759776536
# precision class 0 = 0.8894340857049395
# precision class 1 = 0.593939393939394
# recall class 0 = 0.9759511844938981
# recall class 1 = 0.22477064220183487
# AUC of ROC = 0.829981328661657
# AUC of PRC = 0.4554242111871638
# min(+P, Se) = 0.46559633027522934
# f1_score = 0.3261231281198004
#
# Epoch 15 Batch 0: Train Loss = 0.3329
# Model Loss = 0.3324, Decov Loss = 0.0000
# Epoch 15 Batch 30: Train Loss = 0.3098
# Model Loss = 0.3093, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3042
# valid_model Loss = 0.3042
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2747   39]
#  [ 362   74]]
# accuracy = 0.8755431409062694
# precision class 0 = 0.8835638468961081
# precision class 1 = 0.6548672566371682
# recall class 0 = 0.9860014357501795
# recall class 1 = 0.16972477064220184
# AUC of ROC = 0.8330446465617736
# AUC of PRC = 0.46264878719688185
# min(+P, Se) = 0.4759725400457666
# f1_score = 0.26958105646630237
#
#
# ------------ Save best model ------------
#
# Epoch 16 Batch 0: Train Loss = 0.2988
# Model Loss = 0.2982, Decov Loss = 0.0000
# Epoch 16 Batch 30: Train Loss = 0.3110
# Model Loss = 0.3107, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3053
# valid_model Loss = 0.3053
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2760   26]
#  [ 380   56]]
# accuracy = 0.8739913097454997
# precision class 0 = 0.8789808917197452
# precision class 1 = 0.6829268292682927
# recall class 0 = 0.990667623833453
# recall class 1 = 0.12844036697247707
# AUC of ROC = 0.8282689660622904
# AUC of PRC = 0.45358989719575005
# min(+P, Se) = 0.46788990825688076
# f1_score = 0.2162162162162162
#
# Epoch 17 Batch 0: Train Loss = 0.3265
# Model Loss = 0.3260, Decov Loss = 0.0000
# Epoch 17 Batch 30: Train Loss = 0.3042
# Model Loss = 0.3035, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3103
# valid_model Loss = 0.3103
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2700   86]
#  [ 322  114]]
# accuracy = 0.8733705772811918
# precision class 0 = 0.8934480476505625
# precision class 1 = 0.57
# recall class 0 = 0.9691313711414213
# recall class 1 = 0.26146788990825687
# AUC of ROC = 0.8326997042881512
# AUC of PRC = 0.4618164697118581
# min(+P, Se) = 0.48299319727891155
# f1_score = 0.3584905660377358
#
# Epoch 18 Batch 0: Train Loss = 0.2756
# Model Loss = 0.2741, Decov Loss = 0.0000
# Epoch 18 Batch 30: Train Loss = 0.3088
# Model Loss = 0.3078, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2983
# valid_model Loss = 0.2983
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2721   65]
#  [ 344   92]]
# accuracy = 0.8730602110490379
# precision class 0 = 0.8877650897226753
# precision class 1 = 0.5859872611464968
# recall class 0 = 0.9766690595836325
# recall class 1 = 0.21100917431192662
# AUC of ROC = 0.8382451247060994
# AUC of PRC = 0.4728673146583797
# min(+P, Se) = 0.4823008849557522
# f1_score = 0.31028667790893766
#
#
# ------------ Save best model ------------
#
# Epoch 19 Batch 0: Train Loss = 0.2528
# Model Loss = 0.2522, Decov Loss = 0.0000
# Epoch 19 Batch 30: Train Loss = 0.2985
# Model Loss = 0.2977, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2961
# valid_model Loss = 0.2961
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2721   65]
#  [ 340   96]]
# accuracy = 0.8743016759776536
# precision class 0 = 0.8889251878471088
# precision class 1 = 0.5962732919254659
# recall class 0 = 0.9766690595836325
# recall class 1 = 0.22018348623853212
# AUC of ROC = 0.8409223377701088
# AUC of PRC = 0.4792146847690517
# min(+P, Se) = 0.4793577981651376
# f1_score = 0.32160804020100503
#
#
# ------------ Save best model ------------
#
# Epoch 20 Batch 0: Train Loss = 0.2685
# Model Loss = 0.2680, Decov Loss = 0.0000
# Epoch 20 Batch 30: Train Loss = 0.3008
# Model Loss = 0.3000, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2983
# valid_model Loss = 0.2983
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2682  104]
#  [ 290  146]]
# accuracy = 0.877715704531347
# precision class 0 = 0.9024226110363391
# precision class 1 = 0.584
# recall class 0 = 0.9626704953338119
# recall class 1 = 0.3348623853211009
# AUC of ROC = 0.8425927145557407
# AUC of PRC = 0.4745932448467362
# min(+P, Se) = 0.46952595936794583
# f1_score = 0.42565597667638483
#
#
# ------------ Save best model ------------
#
# Epoch 21 Batch 0: Train Loss = 0.3039
# Model Loss = 0.3035, Decov Loss = 0.0000
# Epoch 21 Batch 30: Train Loss = 0.2953
# Model Loss = 0.2949, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2939
# valid_model Loss = 0.2939
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2750   36]
#  [ 364   72]]
# accuracy = 0.8758535071384234
# precision class 0 = 0.8831085420680796
# precision class 1 = 0.6666666666666666
# recall class 0 = 0.9870782483847811
# recall class 1 = 0.1651376146788991
# AUC of ROC = 0.8451291516560524
# AUC of PRC = 0.48632882165802394
# min(+P, Se) = 0.5102974828375286
# f1_score = 0.2647058823529412
#
#
# ------------ Save best model ------------
#
# Epoch 22 Batch 0: Train Loss = 0.2984
# Model Loss = 0.2979, Decov Loss = 0.0000
# Epoch 22 Batch 30: Train Loss = 0.2962
# Model Loss = 0.2951, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2980
# valid_model Loss = 0.2980
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2711   75]
#  [ 328  108]]
# accuracy = 0.8749224084419616
# precision class 0 = 0.8920697597894044
# precision class 1 = 0.5901639344262295
# recall class 0 = 0.9730796841349605
# recall class 1 = 0.24770642201834864
# AUC of ROC = 0.8389259534895974
# AUC of PRC = 0.4732444696998963
# min(+P, Se) = 0.482837528604119
# f1_score = 0.34894991922455576
#
# Epoch 23 Batch 0: Train Loss = 0.2623
# Model Loss = 0.2618, Decov Loss = 0.0000
# Epoch 23 Batch 30: Train Loss = 0.2954
# Model Loss = 0.2946, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2976
# valid_model Loss = 0.2976
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2683  103]
#  [ 289  147]]
# accuracy = 0.8783364369956549
# precision class 0 = 0.9027590847913862
# precision class 1 = 0.588
# recall class 0 = 0.9630294328786791
# recall class 1 = 0.33715596330275227
# AUC of ROC = 0.8408712961926277
# AUC of PRC = 0.4821043763057507
# min(+P, Se) = 0.49311926605504586
# f1_score = 0.4285714285714286
#
# Epoch 24 Batch 0: Train Loss = 0.2280
# Model Loss = 0.2270, Decov Loss = 0.0000
# Epoch 24 Batch 30: Train Loss = 0.2915
# Model Loss = 0.2906, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2934
# valid_model Loss = 0.2934
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2706   80]
#  [ 329  107]]
# accuracy = 0.8730602110490379
# precision class 0 = 0.8915980230642504
# precision class 1 = 0.5721925133689839
# recall class 0 = 0.9712849964106246
# recall class 1 = 0.24541284403669725
# AUC of ROC = 0.8443207189288514
# AUC of PRC = 0.4865554369450639
# min(+P, Se) = 0.4954337899543379
# f1_score = 0.34349919743178164
#
# Epoch 25 Batch 0: Train Loss = 0.3192
# Model Loss = 0.3186, Decov Loss = 0.0000
# Epoch 25 Batch 30: Train Loss = 0.2830
# Model Loss = 0.2819, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2968
# valid_model Loss = 0.2968
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2685  101]
#  [ 284  152]]
# accuracy = 0.8805090006207325
# precision class 0 = 0.9043448972718087
# precision class 1 = 0.6007905138339921
# recall class 0 = 0.9637473079684135
# recall class 1 = 0.3486238532110092
# AUC of ROC = 0.8473749810652212
# AUC of PRC = 0.49077210287055767
# min(+P, Se) = 0.4908256880733945
# f1_score = 0.4412191582002903
#
#
# ------------ Save best model ------------
#
# Epoch 26 Batch 0: Train Loss = 0.3027
# Model Loss = 0.3017, Decov Loss = 0.0000
# Epoch 26 Batch 30: Train Loss = 0.2926
# Model Loss = 0.2916, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2955
# valid_model Loss = 0.2955
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2700   86]
#  [ 306  130]]
# accuracy = 0.8783364369956549
# precision class 0 = 0.8982035928143712
# precision class 1 = 0.6018518518518519
# recall class 0 = 0.9691313711414213
# recall class 1 = 0.2981651376146789
# AUC of ROC = 0.8446697774587222
# AUC of PRC = 0.48247740592299254
# min(+P, Se) = 0.48853211009174313
# f1_score = 0.3987730061349693
#
# Epoch 27 Batch 0: Train Loss = 0.2395
# Model Loss = 0.2385, Decov Loss = 0.0000
# Epoch 27 Batch 30: Train Loss = 0.2889
# Model Loss = 0.2876, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2973
# valid_model Loss = 0.2973
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2719   67]
#  [ 328  108]]
# accuracy = 0.8774053382991931
# precision class 0 = 0.8923531342303905
# precision class 1 = 0.6171428571428571
# recall class 0 = 0.9759511844938981
# recall class 1 = 0.24770642201834864
# AUC of ROC = 0.8394824713343915
# AUC of PRC = 0.49013627932100406
# min(+P, Se) = 0.4931506849315068
# f1_score = 0.353518821603928
#
# Epoch 28 Batch 0: Train Loss = 0.2848
# Model Loss = 0.2839, Decov Loss = 0.0000
# Epoch 28 Batch 30: Train Loss = 0.2781
# Model Loss = 0.2771, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2945
# valid_model Loss = 0.2945
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2723   63]
#  [ 325  111]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.8933727034120735
# precision class 1 = 0.6379310344827587
# recall class 0 = 0.9773869346733668
# recall class 1 = 0.2545871559633027
# AUC of ROC = 0.8407049994401892
# AUC of PRC = 0.4920937514364188
# min(+P, Se) = 0.4988814317673378
# f1_score = 0.3639344262295082
#
# Epoch 29 Batch 0: Train Loss = 0.3120
# Model Loss = 0.3110, Decov Loss = 0.0000
# Epoch 29 Batch 30: Train Loss = 0.2798
# Model Loss = 0.2787, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2944
# valid_model Loss = 0.2944
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2744   42]
#  [ 353   83]]
# accuracy = 0.8774053382991931
# precision class 0 = 0.8860187278010978
# precision class 1 = 0.664
# recall class 0 = 0.9849246231155779
# recall class 1 = 0.19036697247706422
# AUC of ROC = 0.8470769641128315
# AUC of PRC = 0.5062911171238196
# min(+P, Se) = 0.5091324200913242
# f1_score = 0.29590017825311943
#
# Epoch 30 Batch 0: Train Loss = 0.2860
# Model Loss = 0.2853, Decov Loss = 0.0000
# Epoch 30 Batch 30: Train Loss = 0.2867
# Model Loss = 0.2855, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2904
# valid_model Loss = 0.2904
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2698   88]
#  [ 298  138]]
# accuracy = 0.8801986343885785
# precision class 0 = 0.9005340453938585
# precision class 1 = 0.6106194690265486
# recall class 0 = 0.968413496051687
# recall class 1 = 0.3165137614678899
# AUC of ROC = 0.8478458807800471
# AUC of PRC = 0.49917381948019157
# min(+P, Se) = 0.510250569476082
# f1_score = 0.4169184290030211
#
#
# ------------ Save best model ------------
#
# Epoch 31 Batch 0: Train Loss = 0.3030
# Model Loss = 0.3023, Decov Loss = 0.0000
# Epoch 31 Batch 30: Train Loss = 0.2887
# Model Loss = 0.2876, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2994
# valid_model Loss = 0.2994
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2760   26]
#  [ 363   73]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.8837656099903939
# precision class 1 = 0.7373737373737373
# recall class 0 = 0.990667623833453
# recall class 1 = 0.16743119266055045
# AUC of ROC = 0.8466529897192383
# AUC of PRC = 0.5037041805315593
# min(+P, Se) = 0.5034324942791762
# f1_score = 0.27289719626168224
#
# Epoch 32 Batch 0: Train Loss = 0.3464
# Model Loss = 0.3445, Decov Loss = 0.0000
# Epoch 32 Batch 30: Train Loss = 0.2901
# Model Loss = 0.2887, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2965
# valid_model Loss = 0.2965
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2683  103]
#  [ 280  156]]
# accuracy = 0.8811297330850404
# precision class 0 = 0.9055011812352346
# precision class 1 = 0.6023166023166023
# recall class 0 = 0.9630294328786791
# recall class 1 = 0.3577981651376147
# AUC of ROC = 0.8437765498528027
# AUC of PRC = 0.4992068857616105
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.4489208633093526
#
# Epoch 33 Batch 0: Train Loss = 0.3197
# Model Loss = 0.3192, Decov Loss = 0.0000
# Epoch 33 Batch 30: Train Loss = 0.2815
# Model Loss = 0.2804, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2908
# valid_model Loss = 0.2908
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2713   73]
#  [ 315  121]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.8959709379128138
# precision class 1 = 0.6237113402061856
# recall class 0 = 0.9737975592246949
# recall class 1 = 0.2775229357798165
# AUC of ROC = 0.8478771643275356
# AUC of PRC = 0.49662193185846826
# min(+P, Se) = 0.49435665914221216
# f1_score = 0.3841269841269841
#
#
# ------------ Save best model ------------
#
# Epoch 34 Batch 0: Train Loss = 0.2465
# Model Loss = 0.2457, Decov Loss = 0.0000
# Epoch 34 Batch 30: Train Loss = 0.2828
# Model Loss = 0.2814, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2980
# valid_model Loss = 0.2980
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2625  161]
#  [ 230  206]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.9194395796847635
# precision class 1 = 0.5613079019073569
# recall class 0 = 0.9422110552763819
# recall class 1 = 0.4724770642201835
# AUC of ROC = 0.8498850741255426
# AUC of PRC = 0.5046563229724776
# min(+P, Se) = 0.5217391304347826
# f1_score = 0.5130759651307596
#
#
# ------------ Save best model ------------
#
# Epoch 35 Batch 0: Train Loss = 0.3135
# Model Loss = 0.3125, Decov Loss = 0.0000
# Epoch 35 Batch 30: Train Loss = 0.2835
# Model Loss = 0.2823, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2904
# valid_model Loss = 0.2903
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2716   70]
#  [ 314  122]]
# accuracy = 0.8808193668528864
# precision class 0 = 0.8963696369636963
# precision class 1 = 0.6354166666666666
# recall class 0 = 0.9748743718592965
# recall class 1 = 0.2798165137614679
# AUC of ROC = 0.8501040589579614
# AUC of PRC = 0.5029604831219308
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.3885350318471337
#
#
# ------------ Save best model ------------
#
# Epoch 36 Batch 0: Train Loss = 0.2276
# Model Loss = 0.2259, Decov Loss = 0.0000
# Epoch 36 Batch 30: Train Loss = 0.2815
# Model Loss = 0.2804, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2924
# valid_model Loss = 0.2924
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2685  101]
#  [ 274  162]]
# accuracy = 0.8836126629422719
# precision class 0 = 0.9074011490368368
# precision class 1 = 0.6159695817490495
# recall class 0 = 0.9637473079684135
# recall class 1 = 0.37155963302752293
# AUC of ROC = 0.8476614725001154
# AUC of PRC = 0.493609543442516
# min(+P, Se) = 0.517162471395881
# f1_score = 0.463519313304721
#
# Epoch 37 Batch 0: Train Loss = 0.2545
# Model Loss = 0.2538, Decov Loss = 0.0000
# Epoch 37 Batch 30: Train Loss = 0.2825
# Model Loss = 0.2813, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2877
# valid_model Loss = 0.2877
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2690   96]
#  [ 281  155]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9054190508246381
# precision class 1 = 0.6175298804780877
# recall class 0 = 0.9655419956927495
# recall class 1 = 0.3555045871559633
# AUC of ROC = 0.8536629741103946
# AUC of PRC = 0.5163362451218265
# min(+P, Se) = 0.518348623853211
# f1_score = 0.4512372634643377
#
#
# ------------ Save best model ------------
#
# Epoch 38 Batch 0: Train Loss = 0.2598
# Model Loss = 0.2570, Decov Loss = 0.0000
# Epoch 38 Batch 30: Train Loss = 0.2832
# Model Loss = 0.2817, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2888
# valid_model Loss = 0.2888
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2708   78]
#  [ 291  145]]
# accuracy = 0.8854748603351955
# precision class 0 = 0.9029676558852952
# precision class 1 = 0.6502242152466368
# recall class 0 = 0.9720028715003589
# recall class 1 = 0.33256880733944955
# AUC of ROC = 0.8530463589243727
# AUC of PRC = 0.5190387716537387
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.4400606980273141
#
# Epoch 39 Batch 0: Train Loss = 0.2646
# Model Loss = 0.2633, Decov Loss = 0.0000
# Epoch 39 Batch 30: Train Loss = 0.2770
# Model Loss = 0.2757, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2926
# valid_model Loss = 0.2926
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2680  106]
#  [ 282  154]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.9047940580688724
# precision class 1 = 0.5923076923076923
# recall class 0 = 0.9619526202440776
# recall class 1 = 0.3532110091743119
# AUC of ROC = 0.8509594170063949
# AUC of PRC = 0.5009671599256451
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.4425287356321839
#
# Epoch 40 Batch 0: Train Loss = 0.2383
# Model Loss = 0.2366, Decov Loss = 0.0000
# Epoch 40 Batch 30: Train Loss = 0.2716
# Model Loss = 0.2701, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2922
# valid_model Loss = 0.2922
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2656  130]
#  [ 258  178]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.911461908030199
# precision class 1 = 0.577922077922078
# recall class 0 = 0.9533381191672649
# recall class 1 = 0.40825688073394495
# AUC of ROC = 0.8500579568879785
# AUC of PRC = 0.48433869984373723
# min(+P, Se) = 0.518348623853211
# f1_score = 0.47849462365591394
#
# Epoch 41 Batch 0: Train Loss = 0.3000
# Model Loss = 0.2985, Decov Loss = 0.0000
# Epoch 41 Batch 30: Train Loss = 0.2741
# Model Loss = 0.2727, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2934
# valid_model Loss = 0.2934
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2645  141]
#  [ 248  188]]
# accuracy = 0.8792675356921167
# precision class 0 = 0.9142758382302109
# precision class 1 = 0.5714285714285714
# recall class 0 = 0.9493898061737258
# recall class 1 = 0.43119266055045874
# AUC of ROC = 0.8521127920072182
# AUC of PRC = 0.5163246910118507
# min(+P, Se) = 0.518348623853211
# f1_score = 0.4915032679738562
#
# Epoch 42 Batch 0: Train Loss = 0.2740
# Model Loss = 0.2734, Decov Loss = 0.0000
# Epoch 42 Batch 30: Train Loss = 0.2739
# Model Loss = 0.2727, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2895
# valid_model Loss = 0.2894
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2688   98]
#  [ 280  156]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9056603773584906
# precision class 1 = 0.6141732283464567
# recall class 0 = 0.964824120603015
# recall class 1 = 0.3577981651376147
# AUC of ROC = 0.8547809493074809
# AUC of PRC = 0.5108102387727825
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.45217391304347826
#
#
# ------------ Save best model ------------
#
# Epoch 43 Batch 0: Train Loss = 0.3152
# Model Loss = 0.3133, Decov Loss = 0.0000
# Epoch 43 Batch 30: Train Loss = 0.2783
# Model Loss = 0.2772, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2834
# valid_model Loss = 0.2834
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2711   75]
#  [ 295  141]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.9018629407850964
# precision class 1 = 0.6527777777777778
# recall class 0 = 0.9730796841349605
# recall class 1 = 0.32339449541284404
# AUC of ROC = 0.8569617418679242
# AUC of PRC = 0.5207429930012587
# min(+P, Se) = 0.5170068027210885
# f1_score = 0.4325153374233129
#
#
# ------------ Save best model ------------
#
# Epoch 44 Batch 0: Train Loss = 0.2581
# Model Loss = 0.2557, Decov Loss = 0.0000
# Epoch 44 Batch 30: Train Loss = 0.2721
# Model Loss = 0.2707, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2904
# valid_model Loss = 0.2904
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2643  143]
#  [ 240  196]]
# accuracy = 0.8811297330850404
# precision class 0 = 0.9167533818938606
# precision class 1 = 0.5781710914454278
# recall class 0 = 0.9486719310839914
# recall class 1 = 0.44954128440366975
# AUC of ROC = 0.8553827459710083
# AUC of PRC = 0.5141283710052447
# min(+P, Se) = 0.5275229357798165
# f1_score = 0.5058064516129033
#
# Epoch 45 Batch 0: Train Loss = 0.2689
# Model Loss = 0.2683, Decov Loss = 0.0000
# Epoch 45 Batch 30: Train Loss = 0.2777
# Model Loss = 0.2768, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2894
# valid_model Loss = 0.2894
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2685  101]
#  [ 279  157]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.9058704453441295
# precision class 1 = 0.6085271317829457
# recall class 0 = 0.9637473079684135
# recall class 1 = 0.36009174311926606
# AUC of ROC = 0.8488527170584244
# AUC of PRC = 0.498056522857298
# min(+P, Se) = 0.5252293577981652
# f1_score = 0.45244956772334294
#
# Epoch 46 Batch 0: Train Loss = 0.2864
# Model Loss = 0.2835, Decov Loss = 0.0000
# Epoch 46 Batch 30: Train Loss = 0.2633
# Model Loss = 0.2619, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2901
# valid_model Loss = 0.2901
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2718   68]
#  [ 316  120]]
# accuracy = 0.8808193668528864
# precision class 0 = 0.8958470665787739
# precision class 1 = 0.6382978723404256
# recall class 0 = 0.9755922469490309
# recall class 1 = 0.27522935779816515
# AUC of ROC = 0.8507766552289626
# AUC of PRC = 0.4933124503853261
# min(+P, Se) = 0.5114678899082569
# f1_score = 0.3846153846153846
#
# Epoch 47 Batch 0: Train Loss = 0.2616
# Model Loss = 0.2606, Decov Loss = 0.0000
# Epoch 47 Batch 30: Train Loss = 0.2543
# Model Loss = 0.2526, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2837
# valid_model Loss = 0.2837
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2699   87]
#  [ 290  146]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9029775844764135
# precision class 1 = 0.6266094420600858
# recall class 0 = 0.9687724335965542
# recall class 1 = 0.3348623853211009
# AUC of ROC = 0.8567765103367426
# AUC of PRC = 0.5102795886670666
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.43647234678624813
#
# Epoch 48 Batch 0: Train Loss = 0.2739
# Model Loss = 0.2730, Decov Loss = 0.0000
# Epoch 48 Batch 30: Train Loss = 0.2651
# Model Loss = 0.2640, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2876
# valid_model Loss = 0.2876
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2699   87]
#  [ 301  135]]
# accuracy = 0.8795779019242707
# precision class 0 = 0.8996666666666666
# precision class 1 = 0.6081081081081081
# recall class 0 = 0.9687724335965542
# recall class 1 = 0.30963302752293576
# AUC of ROC = 0.858067368296265
# AUC of PRC = 0.5044863017442427
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.41033434650455924
#
#
# ------------ Save best model ------------
#
# Epoch 49 Batch 0: Train Loss = 0.2378
# Model Loss = 0.2353, Decov Loss = 0.0000
# Epoch 49 Batch 30: Train Loss = 0.2699
# Model Loss = 0.2686, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2892
# valid_model Loss = 0.2891
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2667  119]
#  [ 257  179]]
# accuracy = 0.883302296710118
# precision class 0 = 0.9121067031463749
# precision class 1 = 0.6006711409395973
# recall class 0 = 0.957286432160804
# recall class 1 = 0.4105504587155963
# AUC of ROC = 0.8550098131548964
# AUC of PRC = 0.5011705617565184
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.48773841961852854
#
# Epoch 50 Batch 0: Train Loss = 0.2521
# Model Loss = 0.2510, Decov Loss = 0.0000
# Epoch 50 Batch 30: Train Loss = 0.2650
# Model Loss = 0.2636, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2834
# valid_model Loss = 0.2834
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2678  108]
#  [ 263  173]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.9105746344780686
# precision class 1 = 0.6156583629893239
# recall class 0 = 0.9612347451543432
# recall class 1 = 0.3967889908256881
# AUC of ROC = 0.8568571889592128
# AUC of PRC = 0.513961021014769
# min(+P, Se) = 0.518348623853211
# f1_score = 0.48256624825662486
#
# Epoch 51 Batch 0: Train Loss = 0.2027
# Model Loss = 0.1991, Decov Loss = 0.0000
# Epoch 51 Batch 30: Train Loss = 0.2704
# Model Loss = 0.2688, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2888
# valid_model Loss = 0.2888
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2674  112]
#  [ 266  170]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9095238095238095
# precision class 1 = 0.6028368794326241
# recall class 0 = 0.9597989949748744
# recall class 1 = 0.38990825688073394
# AUC of ROC = 0.8541017670264824
# AUC of PRC = 0.5109040202175992
# min(+P, Se) = 0.5091743119266054
# f1_score = 0.4735376044568245
#
# Epoch 52 Batch 0: Train Loss = 0.2799
# Model Loss = 0.2788, Decov Loss = 0.0000
# Epoch 52 Batch 30: Train Loss = 0.2695
# Model Loss = 0.2676, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2951
# valid_model Loss = 0.2951
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2722   64]
#  [ 312  124]]
# accuracy = 0.883302296710118
# precision class 0 = 0.8971654581410679
# precision class 1 = 0.6595744680851063
# recall class 0 = 0.9770279971284996
# recall class 1 = 0.28440366972477066
# AUC of ROC = 0.8512738989837787
# AUC of PRC = 0.5128583512819063
# min(+P, Se) = 0.5204545454545455
# f1_score = 0.3974358974358974
#
# Epoch 53 Batch 0: Train Loss = 0.2494
# Model Loss = 0.2481, Decov Loss = 0.0000
# Epoch 53 Batch 30: Train Loss = 0.2642
# Model Loss = 0.2627, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2849
# valid_model Loss = 0.2848
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2672  114]
#  [ 259  177]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9116342545206414
# precision class 1 = 0.6082474226804123
# recall class 0 = 0.95908111988514
# recall class 1 = 0.4059633027522936
# AUC of ROC = 0.8568341379242215
# AUC of PRC = 0.517486488910715
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.48693259972489683
#
# Epoch 54 Batch 0: Train Loss = 0.3143
# Model Loss = 0.3120, Decov Loss = 0.0000
# Epoch 54 Batch 30: Train Loss = 0.2685
# Model Loss = 0.2668, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2923
# valid_model Loss = 0.2923
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2660  126]
#  [ 254  182]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.91283459162663
# precision class 1 = 0.5909090909090909
# recall class 0 = 0.9547738693467337
# recall class 1 = 0.41743119266055045
# AUC of ROC = 0.8506021259640274
# AUC of PRC = 0.5056580101666847
# min(+P, Se) = 0.5148741418764302
# f1_score = 0.48924731182795705
#
# Epoch 55 Batch 0: Train Loss = 0.3113
# Model Loss = 0.3097, Decov Loss = 0.0000
# Epoch 55 Batch 30: Train Loss = 0.2662
# Model Loss = 0.2646, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2894
# valid_model Loss = 0.2894
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2660  126]
#  [ 249  187]]
# accuracy = 0.8836126629422719
# precision class 0 = 0.9144035751117222
# precision class 1 = 0.597444089456869
# recall class 0 = 0.9547738693467337
# recall class 1 = 0.4288990825688073
# AUC of ROC = 0.8551612913848403
# AUC of PRC = 0.5136067136258561
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.49933244325767684
#
# Epoch 56 Batch 0: Train Loss = 0.2362
# Model Loss = 0.2341, Decov Loss = 0.0000
# Epoch 56 Batch 30: Train Loss = 0.2564
# Model Loss = 0.2545, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3139
# valid_model Loss = 0.3139
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2736   50]
#  [ 332  104]]
# accuracy = 0.8814400993171942
# precision class 0 = 0.8917861799217731
# precision class 1 = 0.6753246753246753
# recall class 0 = 0.9820531227566404
# recall class 1 = 0.23853211009174313
# AUC of ROC = 0.8497591166843391
# AUC of PRC = 0.49482491035500126
# min(+P, Se) = 0.5182648401826484
# f1_score = 0.3525423728813559
#
# Epoch 57 Batch 0: Train Loss = 0.2757
# Model Loss = 0.2748, Decov Loss = 0.0000
# Epoch 57 Batch 30: Train Loss = 0.2592
# Model Loss = 0.2578, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2845
# valid_model Loss = 0.2844
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2701   85]
#  [ 286  150]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.9042517576163375
# precision class 1 = 0.6382978723404256
# recall class 0 = 0.9694903086862886
# recall class 1 = 0.3440366972477064
# AUC of ROC = 0.8560709840157537
# AUC of PRC = 0.5120485895454944
# min(+P, Se) = 0.5114678899082569
# f1_score = 0.4470938897168405
#
# Epoch 58 Batch 0: Train Loss = 0.2540
# Model Loss = 0.2524, Decov Loss = 0.0000
# Epoch 58 Batch 30: Train Loss = 0.2593
# Model Loss = 0.2577, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2955
# valid_model Loss = 0.2955
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2728   58]
#  [ 324  112]]
# accuracy = 0.8814400993171942
# precision class 0 = 0.8938401048492791
# precision class 1 = 0.6588235294117647
# recall class 0 = 0.9791816223977028
# recall class 1 = 0.25688073394495414
# AUC of ROC = 0.8538827821940633
# AUC of PRC = 0.49490476806326755
# min(+P, Se) = 0.5091743119266054
# f1_score = 0.36963696369636967
#
# Epoch 59 Batch 0: Train Loss = 0.2072
# Model Loss = 0.2056, Decov Loss = 0.0000
# Epoch 59 Batch 30: Train Loss = 0.2586
# Model Loss = 0.2572, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2831
# valid_model Loss = 0.2831
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2694   92]
#  [ 270  166]]
# accuracy = 0.8876474239602731
# precision class 0 = 0.9089068825910931
# precision class 1 = 0.6434108527131783
# recall class 0 = 0.9669777458722182
# recall class 1 = 0.38073394495412843
# AUC of ROC = 0.8563582987018974
# AUC of PRC = 0.5103795986116639
# min(+P, Se) = 0.5258426966292135
# f1_score = 0.478386167146974
#
# Epoch 60 Batch 0: Train Loss = 0.2409
# Model Loss = 0.2394, Decov Loss = 0.0000
# Epoch 60 Batch 30: Train Loss = 0.2533
# Model Loss = 0.2516, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2929
# valid_model Loss = 0.2929
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2668  118]
#  [ 264  172]]
# accuracy = 0.8814400993171942
# precision class 0 = 0.9099590723055935
# precision class 1 = 0.593103448275862
# recall class 0 = 0.9576453697056713
# recall class 1 = 0.3944954128440367
# AUC of ROC = 0.8505650796577909
# AUC of PRC = 0.5014645484376935
# min(+P, Se) = 0.5080091533180778
# f1_score = 0.47382920110192844
#
# Epoch 61 Batch 0: Train Loss = 0.2780
# Model Loss = 0.2770, Decov Loss = 0.0000
# Epoch 61 Batch 30: Train Loss = 0.2579
# Model Loss = 0.2561, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2886
# valid_model Loss = 0.2886
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2678  108]
#  [ 262  174]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.9108843537414966
# precision class 1 = 0.6170212765957447
# recall class 0 = 0.9612347451543432
# recall class 1 = 0.39908256880733944
# AUC of ROC = 0.8567847428492397
# AUC of PRC = 0.5085012075607437
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.4846796657381615
#
# Epoch 62 Batch 0: Train Loss = 0.2592
# Model Loss = 0.2582, Decov Loss = 0.0000
# Epoch 62 Batch 30: Train Loss = 0.2596
# Model Loss = 0.2580, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2880
# valid_model Loss = 0.2880
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2693   93]
#  [ 273  163]]
# accuracy = 0.8864059590316573
# precision class 0 = 0.9079568442346595
# precision class 1 = 0.63671875
# recall class 0 = 0.966618808327351
# recall class 1 = 0.3738532110091743
# AUC of ROC = 0.8561294348544821
# AUC of PRC = 0.5219233062343847
# min(+P, Se) = 0.5181818181818182
# f1_score = 0.4710982658959537
#
# Epoch 63 Batch 0: Train Loss = 0.2728
# Model Loss = 0.2715, Decov Loss = 0.0000
# Epoch 63 Batch 30: Train Loss = 0.2575
# Model Loss = 0.2561, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2967
# valid_model Loss = 0.2966
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2670  116]
#  [ 261  175]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9109518935516888
# precision class 1 = 0.6013745704467354
# recall class 0 = 0.9583632447954056
# recall class 1 = 0.4013761467889908
# AUC of ROC = 0.8527899161600928
# AUC of PRC = 0.5041097789991364
# min(+P, Se) = 0.517162471395881
# f1_score = 0.4814305364511692
#
# Epoch 64 Batch 0: Train Loss = 0.2576
# Model Loss = 0.2553, Decov Loss = 0.0000
# Epoch 64 Batch 30: Train Loss = 0.2578
# Model Loss = 0.2562, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2872
# valid_model Loss = 0.2872
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2706   80]
#  [ 289  147]]
# accuracy = 0.8854748603351955
# precision class 0 = 0.9035058430717863
# precision class 1 = 0.6475770925110133
# recall class 0 = 0.9712849964106246
# recall class 1 = 0.33715596330275227
# AUC of ROC = 0.8557828460783604
# AUC of PRC = 0.5040728432906043
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.4434389140271493
#
# Epoch 65 Batch 0: Train Loss = 0.2436
# Model Loss = 0.2424, Decov Loss = 0.0000
# Epoch 65 Batch 30: Train Loss = 0.2479
# Model Loss = 0.2457, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2978
# valid_model Loss = 0.2978
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2639  147]
#  [ 244  192]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.9153659382587582
# precision class 1 = 0.5663716814159292
# recall class 0 = 0.9472361809045227
# recall class 1 = 0.44036697247706424
# AUC of ROC = 0.8532472322292985
# AUC of PRC = 0.5002096658017354
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.49548387096774194
#
# Epoch 66 Batch 0: Train Loss = 0.1733
# Model Loss = 0.1720, Decov Loss = 0.0000
# Epoch 66 Batch 30: Train Loss = 0.2500
# Model Loss = 0.2482, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2964
# valid_model Loss = 0.2964
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2628  158]
#  [ 233  203]]
# accuracy = 0.8786468032278089
# precision class 0 = 0.9185599440754981
# precision class 1 = 0.5623268698060941
# recall class 0 = 0.9432878679109835
# recall class 1 = 0.46559633027522934
# AUC of ROC = 0.8538086895815908
# AUC of PRC = 0.5102097631372325
# min(+P, Se) = 0.5252293577981652
# f1_score = 0.5094102885821832
#
# Epoch 67 Batch 0: Train Loss = 0.2313
# Model Loss = 0.2289, Decov Loss = 0.0000
# Epoch 67 Batch 30: Train Loss = 0.2486
# Model Loss = 0.2469, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2905
# valid_model Loss = 0.2905
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2686  100]
#  [ 273  163]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9077391010476512
# precision class 1 = 0.6197718631178707
# recall class 0 = 0.9641062455132807
# recall class 1 = 0.3738532110091743
# AUC of ROC = 0.8510985464675935
# AUC of PRC = 0.5004956236743612
# min(+P, Se) = 0.5275229357798165
# f1_score = 0.46638054363376247
#
# Epoch 68 Batch 0: Train Loss = 0.3220
# Model Loss = 0.3212, Decov Loss = 0.0000
# Epoch 68 Batch 30: Train Loss = 0.2495
# Model Loss = 0.2479, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3001
# valid_model Loss = 0.3001
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2739   47]
#  [ 334  102]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.8913114220631305
# precision class 1 = 0.6845637583892618
# recall class 0 = 0.9831299353912419
# recall class 1 = 0.23394495412844038
# AUC of ROC = 0.8562092902257025
# AUC of PRC = 0.5076619312564717
# min(+P, Se) = 0.5252293577981652
# f1_score = 0.34871794871794876
#
# Epoch 69 Batch 0: Train Loss = 0.2778
# Model Loss = 0.2767, Decov Loss = 0.0000
# Epoch 69 Batch 30: Train Loss = 0.2506
# Model Loss = 0.2492, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2902
# valid_model Loss = 0.2902
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2696   90]
#  [ 270  166]]
# accuracy = 0.888268156424581
# precision class 0 = 0.908968307484828
# precision class 1 = 0.6484375
# recall class 0 = 0.9676956209619526
# recall class 1 = 0.38073394495412843
# AUC of ROC = 0.8520633969322364
# AUC of PRC = 0.5222938708447071
# min(+P, Se) = 0.5225225225225225
# f1_score = 0.4797687861271676
#
# Epoch 70 Batch 0: Train Loss = 0.2219
# Model Loss = 0.2202, Decov Loss = 0.0000
# Epoch 70 Batch 30: Train Loss = 0.2412
# Model Loss = 0.2399, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2872
# valid_model Loss = 0.2872
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2672  114]
#  [ 271  165]]
# accuracy = 0.8805090006207325
# precision class 0 = 0.90791709140333
# precision class 1 = 0.5913978494623656
# recall class 0 = 0.95908111988514
# recall class 1 = 0.37844036697247707
# AUC of ROC = 0.8551604681335907
# AUC of PRC = 0.5129213820287577
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.4615384615384615
#
# Epoch 71 Batch 0: Train Loss = 0.2146
# Model Loss = 0.2136, Decov Loss = 0.0000
# Epoch 71 Batch 30: Train Loss = 0.2441
# Model Loss = 0.2426, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2943
# valid_model Loss = 0.2943
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2719   67]
#  [ 306  130]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.8988429752066116
# precision class 1 = 0.6598984771573604
# recall class 0 = 0.9759511844938981
# recall class 1 = 0.2981651376146789
# AUC of ROC = 0.8550822592648695
# AUC of PRC = 0.5118678338644205
# min(+P, Se) = 0.5068807339449541
# f1_score = 0.4107424960505529
#
# Epoch 72 Batch 0: Train Loss = 0.2647
# Model Loss = 0.2621, Decov Loss = 0.0000
# Epoch 72 Batch 30: Train Loss = 0.2455
# Model Loss = 0.2443, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2828
# valid_model Loss = 0.2827
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2701   85]
#  [ 275  161]]
# accuracy = 0.888268156424581
# precision class 0 = 0.9075940860215054
# precision class 1 = 0.6544715447154471
# recall class 0 = 0.9694903086862886
# recall class 1 = 0.36926605504587157
# AUC of ROC = 0.8591433576796169
# AUC of PRC = 0.5185874364697676
# min(+P, Se) = 0.5137614678899083
# f1_score = 0.4721407624633431
#
#
# ------------ Save best model ------------
#
# Epoch 73 Batch 0: Train Loss = 0.2671
# Model Loss = 0.2664, Decov Loss = 0.0000
# Epoch 73 Batch 30: Train Loss = 0.2400
# Model Loss = 0.2385, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3057
# valid_model Loss = 0.3057
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2574  212]
#  [ 205  231]]
# accuracy = 0.8705772811918063
# precision class 0 = 0.9262324577186039
# precision class 1 = 0.5214446952595937
# recall class 0 = 0.923905240488155
# recall class 1 = 0.5298165137614679
# AUC of ROC = 0.8566324413680458
# AUC of PRC = 0.5063802806179298
# min(+P, Se) = 0.5238095238095238
# f1_score = 0.5255972696245734
#
# Epoch 74 Batch 0: Train Loss = 0.2701
# Model Loss = 0.2695, Decov Loss = 0.0000
# Epoch 74 Batch 30: Train Loss = 0.2398
# Model Loss = 0.2385, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3015
# valid_model Loss = 0.3015
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2615  171]
#  [ 233  203]]
# accuracy = 0.8746120422098076
# precision class 0 = 0.918188202247191
# precision class 1 = 0.5427807486631016
# recall class 0 = 0.9386216798277099
# recall class 1 = 0.46559633027522934
# AUC of ROC = 0.8537996338178441
# AUC of PRC = 0.5034533834875227
# min(+P, Se) = 0.5240274599542334
# f1_score = 0.5012345679012346
#
# Epoch 75 Batch 0: Train Loss = 0.2608
# Model Loss = 0.2592, Decov Loss = 0.0000
# Epoch 75 Batch 30: Train Loss = 0.2408
# Model Loss = 0.2397, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2935
# valid_model Loss = 0.2935
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2683  103]
#  [ 268  168]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.9091833276855303
# precision class 1 = 0.6199261992619927
# recall class 0 = 0.9630294328786791
# recall class 1 = 0.3853211009174312
# AUC of ROC = 0.8573239724177901
# AUC of PRC = 0.5200437995122156
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.47524752475247534
#
# Epoch 76 Batch 0: Train Loss = 0.2234
# Model Loss = 0.2225, Decov Loss = 0.0000
# Epoch 76 Batch 30: Train Loss = 0.2375
# Model Loss = 0.2361, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2913
# valid_model Loss = 0.2913
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2656  130]
#  [ 250  186]]
# accuracy = 0.8820608317815022
# precision class 0 = 0.9139710942876806
# precision class 1 = 0.5886075949367089
# recall class 0 = 0.9533381191672649
# recall class 1 = 0.42660550458715596
# AUC of ROC = 0.8551662308923385
# AUC of PRC = 0.5173369348208533
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.4946808510638298
#
# Epoch 77 Batch 0: Train Loss = 0.2866
# Model Loss = 0.2856, Decov Loss = 0.0000
# Epoch 77 Batch 30: Train Loss = 0.2470
# Model Loss = 0.2435, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3092
# valid_model Loss = 0.3092
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2738   48]
#  [ 323  113]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.8944789284547533
# precision class 1 = 0.7018633540372671
# recall class 0 = 0.9827709978463748
# recall class 1 = 0.2591743119266055
# AUC of ROC = 0.851286247752524
# AUC of PRC = 0.5201035190651171
# min(+P, Se) = 0.5206422018348624
# f1_score = 0.3785594639865996
#
# Epoch 78 Batch 0: Train Loss = 0.2279
# Model Loss = 0.2271, Decov Loss = 0.0000
# Epoch 78 Batch 30: Train Loss = 0.2411
# Model Loss = 0.2399, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2916
# valid_model Loss = 0.2916
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2692   94]
#  [ 270  166]]
# accuracy = 0.8870266914959652
# precision class 0 = 0.9088453747467927
# precision class 1 = 0.6384615384615384
# recall class 0 = 0.9662598707824839
# recall class 1 = 0.38073394495412843
# AUC of ROC = 0.8517670264823463
# AUC of PRC = 0.5128697522035532
# min(+P, Se) = 0.518348623853211
# f1_score = 0.4770114942528735
#
# Epoch 79 Batch 0: Train Loss = 0.2181
# Model Loss = 0.2173, Decov Loss = 0.0000
# Epoch 79 Batch 30: Train Loss = 0.2407
# Model Loss = 0.2396, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2901
# valid_model Loss = 0.2901
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2719   67]
#  [ 310  126]]
# accuracy = 0.882991930477964
# precision class 0 = 0.897655992076593
# precision class 1 = 0.6528497409326425
# recall class 0 = 0.9759511844938981
# recall class 1 = 0.2889908256880734
# AUC of ROC = 0.847802248463813
# AUC of PRC = 0.5135726758592615
# min(+P, Se) = 0.518348623853211
# f1_score = 0.40063593004769477
#
# Epoch 80 Batch 0: Train Loss = 0.2754
# Model Loss = 0.2735, Decov Loss = 0.0000
# Epoch 80 Batch 30: Train Loss = 0.2485
# Model Loss = 0.2471, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2897
# valid_model Loss = 0.2897
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2673  113]
#  [ 257  179]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.9122866894197952
# precision class 1 = 0.613013698630137
# recall class 0 = 0.9594400574300072
# recall class 1 = 0.4105504587155963
# AUC of ROC = 0.8539140657415518
# AUC of PRC = 0.5260045156371476
# min(+P, Se) = 0.5240274599542334
# f1_score = 0.49175824175824173
#
# Epoch 81 Batch 0: Train Loss = 0.2672
# Model Loss = 0.2665, Decov Loss = 0.0000
# Epoch 81 Batch 30: Train Loss = 0.2512
# Model Loss = 0.2502, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3037
# valid_model Loss = 0.3037
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2623  163]
#  [ 231  205]]
# accuracy = 0.877715704531347
# precision class 0 = 0.9190609670637702
# precision class 1 = 0.5570652173913043
# recall class 0 = 0.9414931801866475
# recall class 1 = 0.4701834862385321
# AUC of ROC = 0.8528002068007139
# AUC of PRC = 0.5177561452813826
# min(+P, Se) = 0.5160550458715596
# f1_score = 0.509950248756219
#
# Epoch 82 Batch 0: Train Loss = 0.2150
# Model Loss = 0.2143, Decov Loss = 0.0000
# Epoch 82 Batch 30: Train Loss = 0.2375
# Model Loss = 0.2361, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3009
# valid_model Loss = 0.3008
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2677  109]
#  [ 264  172]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9102346140768446
# precision class 1 = 0.6120996441281139
# recall class 0 = 0.960875807609476
# recall class 1 = 0.3944954128440367
# AUC of ROC = 0.849708075106858
# AUC of PRC = 0.5127375886190312
# min(+P, Se) = 0.5125858123569794
# f1_score = 0.4797768479776848
#
# Epoch 83 Batch 0: Train Loss = 0.2269
# Model Loss = 0.2255, Decov Loss = 0.0000
# Epoch 83 Batch 30: Train Loss = 0.2380
# Model Loss = 0.2364, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2847
# valid_model Loss = 0.2847
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2705   81]
#  [ 286  150]]
# accuracy = 0.8860955927995035
# precision class 0 = 0.9043798060849214
# precision class 1 = 0.6493506493506493
# recall class 0 = 0.9709260588657573
# recall class 1 = 0.3440366972477064
# AUC of ROC = 0.8556251934640436
# AUC of PRC = 0.5176286528081443
# min(+P, Se) = 0.5229357798165137
# f1_score = 0.44977511244377805
#
# Epoch 84 Batch 0: Train Loss = 0.2802
# Model Loss = 0.2795, Decov Loss = 0.0000
# Epoch 84 Batch 30: Train Loss = 0.2511
# Model Loss = 0.2503, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2861
# valid_model Loss = 0.2861
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2676  110]
#  [ 253  183]]
# accuracy = 0.8873370577281192
# precision class 0 = 0.9136223967224308
# precision class 1 = 0.6245733788395904
# recall class 0 = 0.9605168700646087
# recall class 1 = 0.4197247706422018
# AUC of ROC = 0.8594718349282453
# AUC of PRC = 0.5299028982917624
# min(+P, Se) = 0.5412844036697247
# f1_score = 0.5020576131687242
#
#
# ------------ Save best model ------------
#
# Epoch 85 Batch 0: Train Loss = 0.2272
# Model Loss = 0.2258, Decov Loss = 0.0000
# Epoch 85 Batch 30: Train Loss = 0.2356
# Model Loss = 0.2343, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2897
# valid_model Loss = 0.2897
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2682  104]
#  [ 268  168]]
# accuracy = 0.8845437616387337
# precision class 0 = 0.9091525423728813
# precision class 1 = 0.6176470588235294
# recall class 0 = 0.9626704953338119
# recall class 1 = 0.3853211009174312
# AUC of ROC = 0.8553275881372788
# AUC of PRC = 0.5235248865450681
# min(+P, Se) = 0.5252293577981652
# f1_score = 0.47457627118644075
#
# Epoch 86 Batch 0: Train Loss = 0.2369
# Model Loss = 0.2361, Decov Loss = 0.0000
# Epoch 86 Batch 30: Train Loss = 0.2330
# Model Loss = 0.2319, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3076
# valid_model Loss = 0.3076
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2655  131]
#  [ 240  196]]
# accuracy = 0.8848541278708877
# precision class 0 = 0.917098445595855
# precision class 1 = 0.599388379204893
# recall class 0 = 0.9529791816223977
# recall class 1 = 0.44954128440366975
# AUC of ROC = 0.8450731705710729
# AUC of PRC = 0.5091699638614041
# min(+P, Se) = 0.518348623853211
# f1_score = 0.5137614678899082
#
# Epoch 87 Batch 0: Train Loss = 0.2286
# Model Loss = 0.2278, Decov Loss = 0.0000
# Epoch 87 Batch 30: Train Loss = 0.2360
# Model Loss = 0.2350, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2938
# valid_model Loss = 0.2938
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2691   95]
#  [ 267  169]]
# accuracy = 0.8876474239602731
# precision class 0 = 0.90973630831643
# precision class 1 = 0.6401515151515151
# recall class 0 = 0.9659009332376166
# recall class 1 = 0.3876146788990826
# AUC of ROC = 0.8504070154178496
# AUC of PRC = 0.5266437308306207
# min(+P, Se) = 0.5273972602739726
# f1_score = 0.4828571428571428
#
# Epoch 88 Batch 0: Train Loss = 0.2274
# Model Loss = 0.2259, Decov Loss = 0.0000
# Epoch 88 Batch 30: Train Loss = 0.2308
# Model Loss = 0.2300, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3030
# valid_model Loss = 0.3030
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2676  110]
#  [ 263  173]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9105137801973461
# precision class 1 = 0.6113074204946997
# recall class 0 = 0.9605168700646087
# recall class 1 = 0.3967889908256881
# AUC of ROC = 0.851467363027457
# AUC of PRC = 0.52189000755392
# min(+P, Se) = 0.5143487858719646
# f1_score = 0.48122392211404735
#
# Epoch 89 Batch 0: Train Loss = 0.1954
# Model Loss = 0.1949, Decov Loss = 0.0000
# Epoch 89 Batch 30: Train Loss = 0.2342
# Model Loss = 0.2332, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3003
# valid_model Loss = 0.3003
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2659  127]
#  [ 243  193]]
# accuracy = 0.8851644941030415
# precision class 0 = 0.9162646450723639
# precision class 1 = 0.603125
# recall class 0 = 0.9544149318018664
# recall class 1 = 0.4426605504587156
# AUC of ROC = 0.8533114458267748
# AUC of PRC = 0.5173001839582183
# min(+P, Se) = 0.5191011235955056
# f1_score = 0.5105820105820106
#
# Epoch 90 Batch 0: Train Loss = 0.2601
# Model Loss = 0.2576, Decov Loss = 0.0000
# Epoch 90 Batch 30: Train Loss = 0.2284
# Model Loss = 0.2276, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2963
# valid_model Loss = 0.2963
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2683  103]
#  [ 251  185]]
# accuracy = 0.8901303538175046
# precision class 0 = 0.9144512610770279
# precision class 1 = 0.6423611111111112
# recall class 0 = 0.9630294328786791
# recall class 1 = 0.4243119266055046
# AUC of ROC = 0.8495479527387922
# AUC of PRC = 0.515975663423771
# min(+P, Se) = 0.5125858123569794
# f1_score = 0.511049723756906
#
# Epoch 91 Batch 0: Train Loss = 0.1681
# Model Loss = 0.1676, Decov Loss = 0.0000
# Epoch 91 Batch 30: Train Loss = 0.2324
# Model Loss = 0.2316, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3043
# valid_model Loss = 0.3043
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2711   75]
#  [ 301  135]]
# accuracy = 0.883302296710118
# precision class 0 = 0.900066401062417
# precision class 1 = 0.6428571428571429
# recall class 0 = 0.9730796841349605
# recall class 1 = 0.30963302752293576
# AUC of ROC = 0.8518748723960563
# AUC of PRC = 0.512412358239776
# min(+P, Se) = 0.5275229357798165
# f1_score = 0.41795665634674917
#
# Epoch 92 Batch 0: Train Loss = 0.1966
# Model Loss = 0.1959, Decov Loss = 0.0000
# Epoch 92 Batch 30: Train Loss = 0.2230
# Model Loss = 0.2221, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2979
# valid_model Loss = 0.2979
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2698   88]
#  [ 285  151]]
# accuracy = 0.8842333954065797
# precision class 0 = 0.9044585987261147
# precision class 1 = 0.6317991631799164
# recall class 0 = 0.968413496051687
# recall class 1 = 0.3463302752293578
# AUC of ROC = 0.8432142692492607
# AUC of PRC = 0.508247915517389
# min(+P, Se) = 0.510250569476082
# f1_score = 0.4474074074074074
#
# Epoch 93 Batch 0: Train Loss = 0.1935
# Model Loss = 0.1931, Decov Loss = 0.0000
# Epoch 93 Batch 30: Train Loss = 0.2282
# Model Loss = 0.2274, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2891
# valid_model Loss = 0.2891
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2728   58]
#  [ 306  130]]
# accuracy = 0.8870266914959652
# precision class 0 = 0.8991430454845089
# precision class 1 = 0.6914893617021277
# recall class 0 = 0.9791816223977028
# recall class 1 = 0.2981651376146789
# AUC of ROC = 0.8540095628865165
# AUC of PRC = 0.5252894355828747
# min(+P, Se) = 0.5080091533180778
# f1_score = 0.4166666666666667
#
# Epoch 94 Batch 0: Train Loss = 0.2376
# Model Loss = 0.2369, Decov Loss = 0.0000
# Epoch 94 Batch 30: Train Loss = 0.2347
# Model Loss = 0.2337, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3034
# valid_model Loss = 0.3034
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2655  131]
#  [ 250  186]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.9139414802065404
# precision class 1 = 0.5867507886435331
# recall class 0 = 0.9529791816223977
# recall class 1 = 0.42660550458715596
# AUC of ROC = 0.8544458860488549
# AUC of PRC = 0.5189737176345545
# min(+P, Se) = 0.5102974828375286
# f1_score = 0.4940239043824701
#
# Epoch 95 Batch 0: Train Loss = 0.1861
# Model Loss = 0.1856, Decov Loss = 0.0000
# Epoch 95 Batch 30: Train Loss = 0.2234
# Model Loss = 0.2225, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2919
# valid_model Loss = 0.2919
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2651  135]
#  [ 242  194]]
# accuracy = 0.882991930477964
# precision class 0 = 0.9163498098859315
# precision class 1 = 0.5896656534954408
# recall class 0 = 0.951543431442929
# recall class 1 = 0.44495412844036697
# AUC of ROC = 0.8551826959173324
# AUC of PRC = 0.5333522195087023
# min(+P, Se) = 0.5321100917431193
# f1_score = 0.5071895424836601
#
# Epoch 96 Batch 0: Train Loss = 0.1853
# Model Loss = 0.1846, Decov Loss = 0.0000
# Epoch 96 Batch 30: Train Loss = 0.2221
# Model Loss = 0.2212, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3071
# valid_model Loss = 0.3071
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2708   78]
#  [ 284  152]]
# accuracy = 0.8876474239602731
# precision class 0 = 0.9050802139037433
# precision class 1 = 0.6608695652173913
# recall class 0 = 0.9720028715003589
# recall class 1 = 0.3486238532110092
# AUC of ROC = 0.852575459209547
# AUC of PRC = 0.5323653313726703
# min(+P, Se) = 0.528604118993135
# f1_score = 0.45645645645645655
#
# Epoch 97 Batch 0: Train Loss = 0.2463
# Model Loss = 0.2456, Decov Loss = 0.0000
# Epoch 97 Batch 30: Train Loss = 0.2223
# Model Loss = 0.2213, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3003
# valid_model Loss = 0.3003
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2661  125]
#  [ 249  187]]
# accuracy = 0.8839230291744258
# precision class 0 = 0.9144329896907216
# precision class 1 = 0.5993589743589743
# recall class 0 = 0.9551328068916008
# recall class 1 = 0.4288990825688073
# AUC of ROC = 0.8443981045463227
# AUC of PRC = 0.5093367107483651
# min(+P, Se) = 0.5204545454545455
# f1_score = 0.5
#
# Epoch 98 Batch 0: Train Loss = 0.2002
# Model Loss = 0.1990, Decov Loss = 0.0000
# Epoch 98 Batch 30: Train Loss = 0.2237
# Model Loss = 0.2226, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.2972
# valid_model Loss = 0.2972
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2654  132]
#  [ 249  187]]
# accuracy = 0.8817504655493482
# precision class 0 = 0.9142266620737168
# precision class 1 = 0.5862068965517241
# recall class 0 = 0.9526202440775305
# recall class 1 = 0.4288990825688073
# AUC of ROC = 0.8525301803908139
# AUC of PRC = 0.5172978380541384
# min(+P, Se) = 0.5159817351598174
# f1_score = 0.49536423841059596
#
# Epoch 99 Batch 0: Train Loss = 0.2208
# Model Loss = 0.2204, Decov Loss = 0.0000
# Epoch 99 Batch 30: Train Loss = 0.2211
# Model Loss = 0.2199, Decov Loss = 0.0000
#
# ==>Predicting on validation
# Valid Loss = 0.3035
# valid_model Loss = 0.3035
# valid_decov Loss = 0.0000
# confusion matrix:
# [[2685  101]
#  [ 277  159]]
# accuracy = 0.88268156424581
# precision class 0 = 0.9064821066846726
# precision class 1 = 0.6115384615384616
# recall class 0 = 0.9637473079684135
# recall class 1 = 0.3646788990825688
# AUC of ROC = 0.8509635332626436
# AUC of PRC = 0.5224046062536907
# min(+P, Se) = 0.5090497737556561
# f1_score = 0.4568965517241379

# %% [markdown]
# ### Run for test

# %%
checkpoint = torch.load(file_name)
save_epoch = checkpoint['epoch']
model.load_state_dict(checkpoint['net'])
optimizer.load_state_dict(checkpoint['optimizer'])
model.eval()

test_reader = InHospitalMortalityReader(dataset_dir=os.path.join(data_path, 'test'),
                                            listfile=os.path.join(data_path, 'test_listfile.csv'),
                                            period_length=48.0)
test_raw = utils.load_data(test_reader, discretizer, normalizer, small_part, return_names=True)
test_dataset = Dataset(test_raw['data'][0], test_raw['data'][1], test_raw['names'])
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# C:\Users\alper\AppData\Local\Temp\ipykernel_77828\3123361523.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(file_name)

# %%
batch_loss = []
y_true = []
y_pred = []

with torch.no_grad():
    model.eval()
    for step, (batch_x, batch_y, batch_name) in enumerate(test_loader):
        batch_x = batch_x.float().to(device)
        batch_y = batch_y.float().to(device)

        # O(1) demographic lookup using the same key scheme as train/valid
        batch_demo = [demo_map[f"{bn.split('_', 2)[0]}_{bn.split('_', 2)[1]}"] for bn in batch_name]
        batch_demo = torch.stack(batch_demo).to(device)

        # If model returns (logits, decov_loss)
        output, _ = model(batch_x, batch_demo)

        loss = get_loss(output, batch_y.unsqueeze(-1))
        batch_loss.append(loss.item())

        # If get_loss uses BCEWithLogitsLoss, convert logits -> probs for metrics
        probs = output.detach().cpu().numpy().flatten()
        y_pred.extend(probs)
        y_true.extend(batch_y.cpu().numpy().flatten())

print("\n==>Predicting on test")
print('Test Loss = %.4f' % (np.mean(np.array(batch_loss))))

y_pred = np.array(y_pred)                                   # positive-class probs in [0, 1]
y_pred_prob = np.stack([1.0 - y_pred, y_pred], axis=1)      # shape (N, 2) = [P0, P1]
test_res = metrics.print_metrics_binary(y_true, y_pred_prob)
# Out:
# ==>Predicting on test
# Test Loss = 0.2652
# confusion matrix:
# [[2753  109]
#  [ 237  137]]
# accuracy = 0.8930778739184178
# precision class 0 = 0.9207357859531773
# precision class 1 = 0.556910569105691
# recall class 0 = 0.9619147449336128
# recall class 1 = 0.3663101604278075
# AUC of ROC = 0.8576245249386205
# AUC of PRC = 0.49949167811658524
# min(+P, Se) = 0.5053475935828877
# f1_score = 0.44193548387096776

# %%
# Bootstrap evaluation
y_true_arr = np.asarray(y_true, dtype=int)
y_pred_arr = np.asarray(y_pred_prob, dtype=float)   # 1D positive-class probabilities

N = len(y_true_arr)
N_idx = np.arange(N)
K = 1000

auroc = []
auprc = []
minpse = []
for i in range(K):
    boot_idx = np.random.choice(N_idx, N, replace=True)
    boot_true = y_true_arr[boot_idx]
    boot_pred = y_pred_arr[boot_idx, :]  # 1D slice is correct

    test_ret = metrics.print_metrics_binary(boot_true, boot_pred, verbose=0)
    auroc.append(test_ret["auroc"])
    auprc.append(test_ret["auprc"])
    minpse.append(test_ret["minpse"])

    if (i + 1) % 50 == 0:
        print(f"{i+1}/{K}")

print("auroc %.4f(%.4f)" % (np.mean(auroc), np.std(auroc)))
print("auprc %.4f(%.4f)" % (np.mean(auprc), np.std(auprc)))
print("minpse %.4f(%.4f)" % (np.mean(minpse), np.std(minpse)))
# Out:
# 50/1000
# 100/1000
# 150/1000
# 200/1000
# 250/1000
# 300/1000
# 350/1000
# 400/1000
# 450/1000
# 500/1000
# 550/1000
# 600/1000
# 650/1000
# 700/1000
# 750/1000
# 800/1000
# 850/1000
# 900/1000
# 950/1000
# 1000/1000
# auroc 0.8581(0.0098)
# auprc 0.5034(0.0285)
# minpse 0.5061(0.0222)
